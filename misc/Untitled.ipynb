# %% [markdown]
# abandoned: ഉപേക്ഷിക്കപ്പെട്ട<font color='red'><b>,</b></font> വിഷയലമ്പടത്വമുള്ള<font color='red'><b>,</b></font> തള്ളിപുറത്താക്കപ്പെട്ട<font color='red'><b>,</b></font> പരിത്യജിച്ച
#
# abashed: പരിഭ്രമിപ്പിക്കുക<font color='red'><b>,</b></font> നാണിപ്പിക്കുക<font color='red'><b>,</b></font> വിഷമിപ്പിക്കുക<font color='red'><b>,</b></font> ലജ്ജിതമായ<font color='red'><b>,</b></font> ലജ്ജിപ്പിക്കുക
#
# abbreviated: സംക്ഷിപ്‌തമായി<font color='red'><b>,</b></font> ചുരുക്കി
#
# abhorrence: ജുഗുപ്‌സ<font color='red'><b>,</b></font> വെറുപ്പ്‌<font color='red'><b>,</b></font> നീരസം<font color='red'><b>,</b></font> അറപ്പ്‌<font color='red'><b>,</b></font> അസഹ്യത
#
# abiding: ശാശ്വതമായ<font color='red'><b>,</b></font> സുസ്ഥിരമായ<font color='red'><b>,</b></font> നിലനില്‍ക്കുന്ന
#
# ability: പാടവം<font color='red'><b>,</b></font> പടുത്വം<font color='red'><b>,</b></font> ശേഷി<font color='red'><b>,</b></font> നൈപുണ്യം<font color='red'><b>,</b></font> ശക്തി<font color='red'><b>,</b></font> യോഗ്യത<font color='red'><b>,</b></font> കഴിവ്‌<font color='red'><b>,</b></font> കുശലത<font color='red'><b>,</b></font> പ്രാപ്‌തി<font color='red'><b>,</b></font> കരുത്ത്‌
#
# abject: ഹീനമായ<font color='red'><b>,</b></font> നിന്ദ്യമായ<font color='red'><b>,</b></font> നികൃഷ്‌ടമായ<font color='red'><b>,</b></font> നികൃഷടമായ<font color='red'><b>,</b></font> താണ<font color='red'><b>,</b></font> വിലകെട്ട<font color='red'><b>,</b></font> അധമമായ<font color='red'><b>,</b></font> വിലയില്ലാത്ത
#
# abjuration: ആണയിടല്‍<font color='red'><b>,</b></font> ആവര്‍ത്തിച്ചു പറയല്‍
#
# able: കഴിവുറ്റ<font color='red'><b>,</b></font> പ്രാപ്‌തിയുള്ള<font color='red'><b>,</b></font> ശക്തമായ<font color='red'><b>,</b></font> സമര്‍ത്ഥനായ<font color='red'><b>,</b></font> പ്രാപ്‌തിയുള്ള<font color='red'><b>,</b></font> പര്യാപ്‌തമായ<font color='red'><b>,</b></font> ശക്തമായ<font color='red'><b>,</b></font> കഴിവുള്ള<font color='red'><b>,</b></font> കഴിവുറ്റ<font color='red'><b>,</b></font> നിപുണമായ<font color='red'><b>,</b></font> സമര്‍ത്ഥനായ<font color='red'><b>,</b></font> കാര്യശേഷിയുള്ള<font color='red'><b>,</b></font> കഴിവുള്ള<font color='red'><b>,</b></font> നിപുണമായ<font color='red'><b>,</b></font> യോഗ്യമായ<font color='red'><b>,</b></font> പ്രാപ്തിയുള്ള
#
# ably: നിപുണമായി
#
# abnegation: ഉപേക്ഷ<font color='red'><b>,</b></font> നിഷേധം<font color='red'><b>,</b></font> ത്യാഗം<font color='red'><b>,</b></font> സ്വമേധയാ ഉള്ള ത്യാഗം
#
# abnormal: വിപരീതമായ<font color='red'><b>,</b></font> വിലക്ഷണമായ<font color='red'><b>,</b></font> അസാധാരണമായ<font color='red'><b>,</b></font> വിചിത്രമായ<font color='red'><b>,</b></font> ക്രമവിരുദ്ധമായ<font color='red'><b>,</b></font> പതിവില്ലാത്ത
#
# abominable: വെറുക്കത്തക്ക<font color='red'><b>,</b></font> വെറുപ്പുവരുത്തുന്ന<font color='red'><b>,</b></font> അറയ്‌ക്കത്തക്ക<font color='red'><b>,</b></font> വളരെ മോശമായ<font color='red'><b>,</b></font> അറയ്ക്കത്തക്ക<font color='red'><b>,</b></font> വളരെ മോശമായ
#
# abounding: സമൃദ്ധമായ<font color='red'><b>,</b></font> സമ്പുഷ്‌ടമായ<font color='red'><b>,</b></font> നിറഞ്ഞ
#
# abridged: വലിപ്പംകുറച്ച<font color='red'><b>,</b></font> സംക്ഷിപ്‌തമായ<font color='red'><b>,</b></font> ചുരുക്കിയ<font color='red'><b>,</b></font> സംഗ്രഹിച്ചതായ
#
# abrupt: നിര്‍മ്മര്യാദമായ<font color='red'><b>,</b></font> പരുഷമായ<font color='red'><b>,</b></font> കിഴുക്കാന്‍ തൂക്കായ<font color='red'><b>,</b></font> ആകസ്‌മികമായ<font color='red'><b>,</b></font> പെട്ടെന്നുള്ള<font color='red'><b>,</b></font> അപ്രതീക്ഷിതമായ<font color='red'><b>,</b></font> അവിചാരിതമായ<font color='red'><b>,</b></font> ഇടമുറിഞ്ഞ<font color='red'><b>,</b></font> കീഴുക്കാം തൂക്കായ<font color='red'><b>,</b></font> പാറ നിറഞ്ഞ
#
# absolute: അന്യനിരപേക്ഷാസ്‌തിത്വമുള്ള എന്തും<font color='red'><b>,</b></font> പരിപൂര്‍ണമായ<font color='red'><b>,</b></font> വ്യക്തമായ.<font color='red'><b>,</b></font> സമ്പൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> അഖണ്‌ഡമായ<font color='red'><b>,</b></font> പരമമായ<font color='red'><b>,</b></font> അനിയന്ത്രിതമായ<font color='red'><b>,</b></font> കലര്‍പ്പില്ലാത്ത<font color='red'><b>,</b></font> അപരിമിതമായ<font color='red'><b>,</b></font> നിരുപാധികമായ<font color='red'><b>,</b></font> സ്വതന്ത്രമായ<font color='red'><b>,</b></font> കേവലമായ<font color='red'><b>,</b></font> വാസ്‌തവമായ<font color='red'><b>,</b></font> പരിപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> സംശയരഹിതമായ<font color='red'><b>,</b></font> സ്വയാധിപത്യമുള്ള<font color='red'><b>,</b></font> ഉപാധിയില്ലാത്ത
#
# absolutely: പൂര്‍ണ്ണമായി<font color='red'><b>,</b></font> നിരുപാധികമായി<font color='red'><b>,</b></font> തീര്‍ച്ചയായും<font color='red'><b>,</b></font> ഉപാധിയില്ലാതെ
#
# absorbed: ഉള്‍ക്കൊണ്ട<font color='red'><b>,</b></font> വലിച്ചെടുക്കപ്പെട്ട
#
# abstemious: മിതഭോജിയായ<font color='red'><b>,</b></font> ഇന്ദ്രിയനിഗ്രഹമുള്ള<font color='red'><b>,</b></font> സംയമിയായ<font color='red'><b>,</b></font> മിതത്വം പാലിക്കുന്ന<font color='red'><b>,</b></font> മിതഭോജിയായ
#
# abstinence: സുഖാനുഭവ വര്‍ജ്ജനം<font color='red'><b>,</b></font> ഭാഗികോപവാസം<font color='red'><b>,</b></font> ലഹരിപദാര്‍ത്ഥ വര്‍ജ്ജനം<font color='red'><b>,</b></font> സംയമനം<font color='red'><b>,</b></font> സമ്പൂര്‍ണ്ണമദ്യപരിവര്‍ജ്ജനം<font color='red'><b>,</b></font> വര്‍ജനം<font color='red'><b>,</b></font> വിട്ടൊഴിയല്‍<font color='red'><b>,</b></font> സന്പൂര്‍ണ്ണമദ്യപരിവര്‍ജ്ജനം<font color='red'><b>,</b></font> വിട്ടൊഴിയല്‍
#
# abstract: സംഗ്രഹം<font color='red'><b>,</b></font> ചുരുക്കം<font color='red'><b>,</b></font> ഗുണം<font color='red'><b>,</b></font> സാരാംശം<font color='red'><b>,</b></font> സംക്ഷേപം<font color='red'><b>,</b></font> അമൂര്‍ത്തമായ ആശയം<font color='red'><b>,</b></font> മോഷ്ടിക്കുക<font color='red'><b>,</b></font> സംക്ഷിപ്തം<font color='red'><b>,</b></font> പ്രത്യക്ഷമായ യാഥാര്‍ത്ഥ്യത്തെ കുറിച്ചുള്ള അടിയുറച്ച വിശ്വാസം<font color='red'><b>,</b></font> മാറ്റുക<font color='red'><b>,</b></font> സംഗ്രഹിക്കുക<font color='red'><b>,</b></font> സംക്ഷേപിക്കുക<font color='red'><b>,</b></font> വേര്‍തിരിച്ചെടുക്കുക<font color='red'><b>,</b></font> അപഹരിക്കുക<font color='red'><b>,</b></font> വേര്‍പ്പെടുത്തുക<font color='red'><b>,</b></font> സാരമെടുക്കുക<font color='red'><b>,</b></font> നിഗൂഢമായ<font color='red'><b>,</b></font> പ്രയാസമുള്ള<font color='red'><b>,</b></font> അമൂര്‍ത്തമായ<font color='red'><b>,</b></font> കേവലമായ<font color='red'><b>,</b></font> രൂപമില്ലാത്ത<font color='red'><b>,</b></font> ഗുണാത്മകമായ<font color='red'><b>,</b></font> ആകാരമില്ലാത്ത
#
# abstraction: വേര്‍തിരിക്കല്‍<font color='red'><b>,</b></font> സംഗ്രഹം<font color='red'><b>,</b></font> ശ്രദ്ധയില്ലായ്‌മ<font color='red'><b>,</b></font> അപഹരണം<font color='red'><b>,</b></font> മനോലയം<font color='red'><b>,</b></font> അമൂര്‍ത്തീകരണം<font color='red'><b>,</b></font> അന്യമനസ്‌കത<font color='red'><b>,</b></font> മോഷണം<font color='red'><b>,</b></font> അന്യമനസ്കത<font color='red'><b>,</b></font> ശ്രദ്ധയില്ലായ്മ<font color='red'><b>,</b></font> അമൂര്‍ത്തഗുണം
#
# abstruse: അഗാധമായ<font color='red'><b>,</b></font> ഗഹനമായ<font color='red'><b>,</b></font> നിഗൂഢമായ<font color='red'><b>,</b></font> ദുര്‍ഗ്രഹമായ<font color='red'><b>,</b></font> മനസ്സിലാക്കാന്‍ പ്രയാസമുള്ള
#
# absurd: അസംഗതമായ<font color='red'><b>,</b></font> ബുദ്ധിശൂന്യമായ<font color='red'><b>,</b></font> അയുക്തമായ<font color='red'><b>,</b></font> അബദ്ധമായ<font color='red'><b>,</b></font> അസംബന്ധമായ<font color='red'><b>,</b></font> യുക്തിഹീനമായ<font color='red'><b>,</b></font> പരിഹാസ്യമായ<font color='red'><b>,</b></font> പ്രച്ഛന്നമായ
#
# absurdity: അബദ്ധപ്രസ്‌താവം<font color='red'><b>,</b></font> അസംബന്ധം<font color='red'><b>,</b></font> അബദ്ധം<font color='red'><b>,</b></font> മണ്ടത്തരം<font color='red'><b>,</b></font> മണ്ടന്‍പ്രവൃത്തി<font color='red'><b>,</b></font> മണ്ടന്‍ പ്രവൃത്തി<font color='red'><b>,</b></font> യുക്തിരാഹിത്യം<font color='red'><b>,</b></font> അബദ്ധ പ്രസ്‌താവം<font color='red'><b>,</b></font> യുക്തി രാഹിത്യം<font color='red'><b>,</b></font> അബദ്ധ പ്രസ്താവം
#
# absurdly: ജീവിതത്തിന്റെ അസംബന്ധ സ്വഭാവം ഊന്നികാണിക്കുന്നതരം നാടകം
#
# abundance: ആധിക്യം<font color='red'><b>,</b></font> ഹൃദയം കവിഞ്ഞൊഴുകല്‍<font color='red'><b>,</b></font> സുലഭത<font color='red'><b>,</b></font> സമൃദ്ധി<font color='red'><b>,</b></font> പ്രാചുര്യം<font color='red'><b>,</b></font> ധാരാളിത്തം<font color='red'><b>,</b></font> ധാരാളത<font color='red'><b>,</b></font> ബഹുലത
#
# abundant: സമൃദ്ധമായ<font color='red'><b>,</b></font> യഥേഷ്‌ടമുള്ള<font color='red'><b>,</b></font> സമ്പുഷ്‌ടമായ<font color='red'><b>,</b></font> ധാരാളമായ
#
# abundantly: ധാരാളമായി
#
# abuse: അധിക്ഷേപം<font color='red'><b>,</b></font> നിന്ദ<font color='red'><b>,</b></font> ദൂഷണം<font color='red'><b>,</b></font> ദുരാചാരം<font color='red'><b>,</b></font> അസഭ്യം<font color='red'><b>,</b></font> ദുരുപയോഗം<font color='red'><b>,</b></font> മോശമായ പെരുമാറ്റം<font color='red'><b>,</b></font> ദുര്‍വ്വിനിയോഗം<font color='red'><b>,</b></font> ദുര്‍വ്വിനിയോഗം<font color='red'><b>,</b></font> ദുരുപയോഗം<font color='red'><b>,</b></font> മോശമായ പെരുമാറ്റം<font color='red'><b>,</b></font> ശകാരിക്കുക<font color='red'><b>,</b></font> ദുര്‍വിനിയോഗം ചെയ്യുക<font color='red'><b>,</b></font> അധാര്‍മ്മികമായ  രീതിയില്‍ ഉപയോഗിക്കുക<font color='red'><b>,</b></font> അധിക്ഷേപിക്കുക<font color='red'><b>,</b></font> അപമാനിക്കുക<font color='red'><b>,</b></font> ചീത്തപറയുക<font color='red'><b>,</b></font> ദുര്‍വിനിയോഗം ചെയ്യുക<font color='red'><b>,</b></font> മോശമായി പെരുമാറുക
#
# abusive: മര്യാദകെട്ട<font color='red'><b>,</b></font> അസഭ്യമായ<font color='red'><b>,</b></font> അധിക്ഷേപിക്കുന്ന<font color='red'><b>,</b></font> അവഹേളനപരമായ
#
# abyss: കുഴി<font color='red'><b>,</b></font> അഗാധത<font color='red'><b>,</b></font> പാതാളം<font color='red'><b>,</b></font> അടികാണാത്ത ഗര്‍ത്തം<font color='red'><b>,</b></font> പടുകുഴി<font color='red'><b>,</b></font> അടി കാണാത്ത ഗര്‍ത്തം<font color='red'><b>,</b></font> അഗാധമായ കുഴി
#
# academic: ഉന്നതശ്രണിയിലെ പണ്‌ഡിതന്‍<font color='red'><b>,</b></font> സര്‍വ്വകലാശാലാ അദ്ധ്യാപകന്‍<font color='red'><b>,</b></font> പണ്‌ഡിതോചിതമായ<font color='red'><b>,</b></font> സര്‍വ്വകലാശാല സംബന്ധിയായ<font color='red'><b>,</b></font> പാണ്‌ഡിത്യപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> വിദ്വദ്‌പരിഷദ്‌ സംബന്ധിയായ<font color='red'><b>,</b></font> ഉന്നത വിദ്യാഭ്യാസത്തിനായുള്ള<font color='red'><b>,</b></font> ശുദ്ധസൈദ്ധാന്തികമായ<font color='red'><b>,</b></font> പാണ്ഡിത്യപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> വിദ്വദ്പരിഷദ് സംബന്ധിയായ
#
# accelerated: ത്വരിതപ്പെടുത്തിയ<font color='red'><b>,</b></font> ദ്രുതഗതിയിലുള്ള<font color='red'><b>,</b></font> ത്വരിതപ്പെട്ട<font color='red'><b>,</b></font> ത്വരിതപ്പെടുത്തപ്പെട്ട
#
# acceleration: വേഗം വര്‍ദ്ധിപ്പിക്കല്‍<font color='red'><b>,</b></font> ത്വരിതപ്പെടുത്തല്‍<font color='red'><b>,</b></font> വേഗവര്‍ദ്ധന<font color='red'><b>,</b></font> വേഗം കൂട്ടല്‍<font color='red'><b>,</b></font> ത്വരണം
#
# accent: സ്വരഭാരം<font color='red'><b>,</b></font> ഉച്ചാരണചിഹ്നം<font color='red'><b>,</b></font> സ്വരബലം<font color='red'><b>,</b></font> സ്വരാഘാതം<font color='red'><b>,</b></font> സ്വരബലചിഹ്നം<font color='red'><b>,</b></font> സ്വരങ്ങളിലെ ഊന്നല്‍<font color='red'><b>,</b></font> ഉച്ചാരണഭേദം<font color='red'><b>,</b></font> ഭാഷ്യരീതി<font color='red'><b>,</b></font> ഊന്നിപ്പറയുക<font color='red'><b>,</b></font> സ്വരാഘാതത്തോടുകൂടി ഉച്ചരിക്കുക<font color='red'><b>,</b></font> എടുത്തുച്ചരിക്കുക<font color='red'><b>,</b></font> ശബ്ദക്രമീകരണം<font color='red'><b>,</b></font> ഒരു സംഗതിക്കു കൊടുക്കുന്ന സവിശേഷ ഊന്നല്‍
#
# acceptable: തൃപ്‌തികരമായ<font color='red'><b>,</b></font> സ്വീകാര്യമായ<font color='red'><b>,</b></font> ഹിതകരമായ<font color='red'><b>,</b></font> അംഗീകാരയോഗ്യമായ<font color='red'><b>,</b></font> തൃപ്തികരമായ<font color='red'><b>,</b></font> അംഗീകാരയോഗ്യമായ
#
# acceptance: കൈക്കൊള്ളല്‍<font color='red'><b>,</b></font> സമ്മതം<font color='red'><b>,</b></font> അംഗീകാരം<font color='red'><b>,</b></font> സ്വീകരണം<font color='red'><b>,</b></font> സ്വീകാരം<font color='red'><b>,</b></font> സമ്മതപത്രം<font color='red'><b>,</b></font> അംഗീകരണം<font color='red'><b>,</b></font> സന്നദ്ധത<font color='red'><b>,</b></font> സ്വീകരിക്കല്‍
#
# accepted: അംഗീകരിച്ചു<font color='red'><b>,</b></font> സ്വീകരിച്ചു<font color='red'><b>,</b></font> മൊത്തത്തില്‍ അംഗീകരിക്കപ്പെട്ട
#
# accessible: എത്താവുന്ന<font color='red'><b>,</b></font> മനസ്സിലാക്കാവുന്ന<font color='red'><b>,</b></font> പ്രാപ്യമായ<font color='red'><b>,</b></font> ലഭ്യമായ<font color='red'><b>,</b></font> സമീപിക്കാവുന്ന<font color='red'><b>,</b></font> സ്വാധീനിക്കാന്‍ കഴിയുന്ന<font color='red'><b>,</b></font> അഭിഗമ്യമായ
#
# accessory: പ്രധാന വസ്‌തുവിന്റെ  കൂടെയുള്ള അപ്രധാന വസ്‌തു<font color='red'><b>,</b></font> വേഷത്തിന്റെ  ഭാഗമായ ചെറിയ വസ്‌തു<font color='red'><b>,</b></font> കൂട്ടുപ്രവൃത്തിക്കാത്ത<font color='red'><b>,</b></font> വേഷത്തിന്‍റെ ഭാഗമായ ചെറിയ വസ്തുക്കള്‍<font color='red'><b>,</b></font> പ്രധാന വസ്തുവിന്‍റെ  കൂടെയുള്ള അപ്രധാന വസ്തു<font color='red'><b>,</b></font> വേഷത്തിന്‍റെ  ഭാഗമായ ചെറിയ വസ്തു<font color='red'><b>,</b></font> സഹകരിക്കുന്ന<font color='red'><b>,</b></font> സംബന്ധമുള്ള<font color='red'><b>,</b></font> കൂട്ടാളി<font color='red'><b>,</b></font> കുറ്റക്യത്യത്തില്‍ സഹായിക്കുന്നവന്‍
#
# accident: അത്യാഹിതം<font color='red'><b>,</b></font> ആകസ്മികസംഭവം<font color='red'><b>,</b></font> ആകസ്‌മിക സംഭവം<font color='red'><b>,</b></font> അപകടം<font color='red'><b>,</b></font> ആപത്ത്‌<font color='red'><b>,</b></font> അവിചാരിതസംഭവം<font color='red'><b>,</b></font> ആകസ്‌മികസംഭവം<font color='red'><b>,</b></font> യാദൃച്ഛികം
#
# accidental: അപ്രധാനമായ<font color='red'><b>,</b></font> ആകസ്‌മികമായ<font color='red'><b>,</b></font> അപ്രതീക്ഷിതമായ<font color='red'><b>,</b></font> യാദൃച്ഛികമായ<font color='red'><b>,</b></font> യാദ്രിശ്ചികമായി
#
# acclaim: സ്വീകരിക്കുക<font color='red'><b>,</b></font> കൈകൊട്ടല്‍<font color='red'><b>,</b></font> സ്‌തുതി ഘോഷിക്കല്‍<font color='red'><b>,</b></font> കൈകൊട്ടുക<font color='red'><b>,</b></font> കൈകൊട്ടിയോ ആര്‍ത്തുവിളിച്ചോ അംഗീകരിക്കുക<font color='red'><b>,</b></font> അഭിവാദ്യം ചെയ്യുക<font color='red'><b>,</b></font> സോത്സാഹം അംഗീകരിക്കുക<font color='red'><b>,</b></font> സ്‌തുതിഘോഷിക്കുക<font color='red'><b>,</b></font> കൈകൊട്ടുക<font color='red'><b>,</b></font> കൈകൊട്ടിയോ ആര്‍ത്തുവിളിച്ചോ അഭിവാദ്യം ചെയ്യുക<font color='red'><b>,</b></font> കൈകൊട്ടുക<font color='red'><b>,</b></font> സ്തുതിഘോഷിക്കുക<font color='red'><b>,</b></font> കൈകൊട്ടിയോ ആര്‍ത്തുവിളിച്ചോ അഭിവാദ്യം ചെയ്യുക
#
# acclamation: പ്രശംസ
#
# <font color='red'><b>,</b></font> ശുഭാശംസ<font color='red'><b>,</b></font> ആര്‍പ്പുവിളി<font color='red'><b>,</b></font> കോലാഹലം<font color='red'><b>,</b></font> സ്‌തുതിഘോഷം<font color='red'><b>,</b></font> ശുഭാശംസ<font color='red'><b>,</b></font> കൈകൊട്ടല്‍<font color='red'><b>,</b></font> വാക്കാലുള്ള അംഗീകാരം<font color='red'><b>,</b></font> കോലാഹലം<font color='red'><b>,</b></font> കൈകൊട്ടല്‍<font color='red'><b>,</b></font> സ്തുതിഘോഷം<font color='red'><b>,</b></font> പ്രകീര്‍ത്തിക്കല്‍
#
# accommodating: ഇണക്കമുള്ള<font color='red'><b>,</b></font> വഴങ്ങുന്നത്<font color='red'><b>,</b></font> അന്യാഭിലാഷത്തിലിണങ്ങുന്ന<font color='red'><b>,</b></font> ഉതകുന്ന<font color='red'><b>,</b></font> സഹായിക്കാന്‍ മനസ്സുള്ള<font color='red'><b>,</b></font> വഴങ്ങുന്ന
#
# accomplished: അഭ്യാസം തികഞ്ഞ<font color='red'><b>,</b></font> ശ്രേഷ്ടമായ
#
# <font color='red'><b>,</b></font> സാമര്‍ത്ഥ്യമുള്ള<font color='red'><b>,</b></font> വൈദഗ്‌ദ്ധ്യമുള്ള<font color='red'><b>,</b></font> നിപുണമായ<font color='red'><b>,</b></font> ശ്രേഷ്ഠമായ<font color='red'><b>,</b></font> നിറവേറ്റിയ<font color='red'><b>,</b></font> സംസ്‌കാരവും പരിഷ്‌കാരവുമുള്ള<font color='red'><b>,</b></font> വൈദഗ്ദ്ധ്യമുള്ള<font color='red'><b>,</b></font> സംസ്കാരവും പരിഷ്കാരവുമുള്ള
#
# accredited: നിയമസാധുതയുള്ള<font color='red'><b>,</b></font> അംഗീകാരമുളള
#
# accumulate: ശേഖരിക്കുക<font color='red'><b>,</b></font> സംഭരിക്കുക<font color='red'><b>,</b></font> കൂമ്പാരമാക്കുക<font color='red'><b>,</b></font> കൂട്ടിചേര്‍ത്തുവയ്‌ക്കുക<font color='red'><b>,</b></font> കുന്നുകൂട്ടുക<font color='red'><b>,</b></font> സ്വരൂപിച്ചു വയ്‌ക്കുക<font color='red'><b>,</b></font> കൂട്ടിച്ചേര്‍ത്തു വയ്‌ക്കുക<font color='red'><b>,</b></font> കൂട്ടിച്ചേര്‍ത്തുവയ്ക്കുക<font color='red'><b>,</b></font> കൂട്ടിച്ചേര്‍ത്തു വയ്ക്കുക<font color='red'><b>,</b></font> സ്വരൂപിച്ചു വയ്ക്കുക
#
# accuracy: നിശ്ചയം<font color='red'><b>,</b></font> കൃത്യത<font color='red'><b>,</b></font> സത്യസന്ധത<font color='red'><b>,</b></font> സൂക്ഷ്‌മത<font color='red'><b>,</b></font> തിട്ടം<font color='red'><b>,</b></font> നിഷ്‌ഠ<font color='red'><b>,</b></font> കമ്പ്യൂട്ടറില്‍ ഉപയോഗിക്കുന്ന വിവരങ്ങളുടെ കൃത്യത<font color='red'><b>,</b></font> യഥാര്‍ത്ഥത<font color='red'><b>,</b></font> സൂക്ഷ്മത<font color='red'><b>,</b></font> നിഷ്ഠ
#
# accurate: കൃത്യമായ<font color='red'><b>,</b></font> ശരിയായ<font color='red'><b>,</b></font> സൂക്ഷ്‌മമായ<font color='red'><b>,</b></font> ഏറ്റക്കുറച്ചിലില്ലാത്ത<font color='red'><b>,</b></font> തിട്ടമായ<font color='red'><b>,</b></font> സൂക്ഷ്മമായ<font color='red'><b>,</b></font> തെറ്റുകൂടാത്ത
#
# accursed: നിന്ദ്യമായ<font color='red'><b>,</b></font> ശപിക്കപ്പെട്ട<font color='red'><b>,</b></font> നിന്ദ്യനായ<font color='red'><b>,</b></font> ദൈവഹതകനായ<font color='red'><b>,</b></font> വെറുക്കപ്പെട്ട<font color='red'><b>,</b></font> ശപ്‌തമായ<font color='red'><b>,</b></font> ശപ്തമായ
#
# accusation: അധിക്ഷേപം<font color='red'><b>,</b></font> കുറ്റാരോപണം<font color='red'><b>,</b></font> അപവാദം<font color='red'><b>,</b></font> കുറ്റംചുമത്തല്‍<font color='red'><b>,</b></font> ദോഷാരോപണം<font color='red'><b>,</b></font> കുറ്റപ്പെടുത്തല്‍
#
# accusing: കുറ്റപ്പെടുത്തുന്ന<font color='red'><b>,</b></font> നിന്ദിക്കുന്ന<font color='red'><b>,</b></font> കുറ്റപ്പെടുത്തുന്നതായ<font color='red'><b>,</b></font> അപവാദമടങ്ങിയ
#
# accustomed: പതിവായ<font color='red'><b>,</b></font> ശീലിച്ച<font color='red'><b>,</b></font> അഭ്യസിച്ച<font color='red'><b>,</b></font> ശീലമാക്കിയ<font color='red'><b>,</b></font> പരിചിതമായ
#
# achievement: വിജയം<font color='red'><b>,</b></font> കൃത്യം<font color='red'><b>,</b></font> നേട്ടം<font color='red'><b>,</b></font> നിര്‍വഹണം<font color='red'><b>,</b></font> ഇഷ്‌ടസാദ്ധ്യം<font color='red'><b>,</b></font> സാധിച്ചകാര്യം<font color='red'><b>,</b></font> മഹായോഗ്യത
#
# aching: വേദന<font color='red'><b>,</b></font> നൊമ്പരം<font color='red'><b>,</b></font> വേദനിക്കുന്ന<font color='red'><b>,</b></font> വേദനയുളവാക്കുന്ന
#
# acknowledged: വകവച്ചുകൊടുക്കുന്ന
#
# acquaintance: അറിവ്‌<font color='red'><b>,</b></font> പരിചയം<font color='red'><b>,</b></font> പരിചിതന്‍<font color='red'><b>,</b></font> പിടിത്തം<font color='red'><b>,</b></font> പിടിപാട്‌<font color='red'><b>,</b></font> പരിചയക്കാരന്‍<font color='red'><b>,</b></font> മുഖപരിചയം ഉള്ളയാള്‍<font color='red'><b>,</b></font> അറിവ്<font color='red'><b>,</b></font> പിടിപാട്
#
# acquiescence: മൗനാനുവാദം<font color='red'><b>,</b></font> അനുമതി<font color='red'><b>,</b></font> അംഗീകാരം<font color='red'><b>,</b></font> വഴങ്ങിക്കൊടുക്കല്‍<font color='red'><b>,</b></font> വഴങ്ങിക്കൊടുക്കല്‍
#
# acquire: നേടുക<font color='red'><b>,</b></font> സമ്പാദിക്കുക<font color='red'><b>,</b></font> സമ്പാദിക്കുക<font color='red'><b>,</b></font> കൈക്കലാക്കുക<font color='red'><b>,</b></font> ആര്‍ജ്ജിക്കുക<font color='red'><b>,</b></font> ഭൂമിയും മറ്റും ഒഴിപ്പിച്ചെടുക്കുക
#
# acquired: നേടിയ<font color='red'><b>,</b></font> ആര്‍ജ്ജിതമായ<font color='red'><b>,</b></font> കൈവരിച്ച
#
# acquisition: സമ്പാദ്യം<font color='red'><b>,</b></font> കൈവശപ്പെടുത്തല്‍<font color='red'><b>,</b></font> നേട്ടം<font color='red'><b>,</b></font> നേടല്‍<font color='red'><b>,</b></font> നേടിയ സ്വത്ത്‌<font color='red'><b>,</b></font> സ്വന്തമാക്കല്‍<font color='red'><b>,</b></font> ആര്‍ജ്ജനം<font color='red'><b>,</b></font> എറ്റെടുക്കല്‍<font color='red'><b>,</b></font> ഏറ്റെടുക്കൽ
#
# acrid: അത്യുഗ്രമായ<font color='red'><b>,</b></font> ക്രൂരമായ<font color='red'><b>,</b></font> തീക്ഷ്‌ണമായ<font color='red'><b>,</b></font> പരുഷമായ<font color='red'><b>,</b></font> എരിവുള്ള<font color='red'><b>,</b></font> നിഷ്‌ഠുരമായ<font color='red'><b>,</b></font> തീക്ഷ്‌ണഗന്ധമോ സ്വാദോ ഉള്ള<font color='red'><b>,</b></font> കടുംവിഷം<font color='red'><b>,</b></font> നിഷ്ഠൂരമായ<font color='red'><b>,</b></font> തീക്ഷ്ണഗന്ധമോ സ്വാദോ ഉള്ള
#
# acrimonious: മുന വെച്ചതും കൈപ്പേറിയതുമായ ഭാഷ<font color='red'><b>,</b></font> ഉഗ്രമായ<font color='red'><b>,</b></font> കഠിനമായ<font color='red'><b>,</b></font> പരുഷമായ<font color='red'><b>,</b></font> തിക്തമായ
#
# acrimony: രൂക്ഷത<font color='red'><b>,</b></font> കാഠിന്യം<font color='red'><b>,</b></font> പെരുമാറ്റത്തിലേയും മറ്റും തീക്ഷണത<font color='red'><b>,</b></font> വികാരപാരുഷ്യം<font color='red'><b>,</b></font> ക്രൂരവാക്ക്‌<font color='red'><b>,</b></font> ക്രൂരവാക്ക്
#
# act: ചെയ്‌തി<font color='red'><b>,</b></font> അധികാരം പ്രയോഗിക്കുക<font color='red'><b>,</b></font> നിയമം<font color='red'><b>,</b></font> പ്രവൃത്തി<font color='red'><b>,</b></font> പ്രകടനം<font color='red'><b>,</b></font> കാര്യം<font color='red'><b>,</b></font> നാടകാങ്കം<font color='red'><b>,</b></font> ക്രിയ<font color='red'><b>,</b></font> നടിക്കല്‍<font color='red'><b>,</b></font> പെരുമാറുക<font color='red'><b>,</b></font> നടിക്കുക<font color='red'><b>,</b></font> പ്രവര്‍ത്തിക്കുക<font color='red'><b>,</b></font> അഭിനയിക്കുക<font color='red'><b>,</b></font> പ്രതിനിധിയായിരിക്കുക<font color='red'><b>,</b></font> പകരം ജോലി നോക്കുക<font color='red'><b>,</b></font> പ്രാവര്‍ത്തികമാക്കുക<font color='red'><b>,</b></font> പ്രവൃത്തിക്കുക
#
# action: വ്യവഹാരം<font color='red'><b>,</b></font> ചേഷ്‌ട<font color='red'><b>,</b></font> ആംഗ്യം<font color='red'><b>,</b></font> യുദ്ധം<font color='red'><b>,</b></font> പ്രവര്‍ത്തനം<font color='red'><b>,</b></font> പ്രവൃത്തി<font color='red'><b>,</b></font> ഫലം<font color='red'><b>,</b></font> ചലനം<font color='red'><b>,</b></font> നടപടി<font color='red'><b>,</b></font> അഭിനയം<font color='red'><b>,</b></font> കോടതി വ്യവഹാരം<font color='red'><b>,</b></font> കര്‍മ്മോത്സുകന്‍<font color='red'><b>,</b></font> പ്രവര്‍ത്തനരീതി<font color='red'><b>,</b></font> ക്രിയ<font color='red'><b>,</b></font> കോടതി നടപടി<font color='red'><b>,</b></font> കോടതി നടപടി<font color='red'><b>,</b></font> ചേഷ്ട<font color='red'><b>,</b></font> കോടതി വ്യവഹാരം<font color='red'><b>,</b></font> കഥയിലോ നാടകത്തിലോ ഉള്ള സംഭവങ്ങള്‍<font color='red'><b>,</b></font> നിയമനടപടികളെടുക്കത്തക്കതായ<font color='red'><b>,</b></font> കോടതി നടപടി
#
# active: ചുണയുള്ള<font color='red'><b>,</b></font> കര്‍മ്മോദ്യുക്തനായ<font color='red'><b>,</b></font> ഉത്സാഹമുള്ള<font color='red'><b>,</b></font> പരിശ്രമശീലമുള്ള<font color='red'><b>,</b></font> സജീവമായ<font color='red'><b>,</b></font> സകര്‍മ്മകമായ<font color='red'><b>,</b></font> ഓജസ്സുള്ള<font color='red'><b>,</b></font> ഉത്സാഹമുളള<font color='red'><b>,</b></font> ഓജസുള്ള
#
# actively: പ്രസരിപ്പോടെ<font color='red'><b>,</b></font> ഊര്‍ജ്ജസ്വലമായി<font color='red'><b>,</b></font> ചുറുചുറുക്കായി<font color='red'><b>,</b></font> ഊര്‍ജ്ജസ്വലമായി<font color='red'><b>,</b></font> ചുറുചുറുക്കായി<font color='red'><b>,</b></font> പ്രസരിപ്പോടെ
#
# activities: ചര്യകള്‍<font color='red'><b>,</b></font> പ്രവര്‍ത്തികള്‍
#
# activity: പ്രവര്‍ത്തനം<font color='red'><b>,</b></font> കര്‍മ്മം<font color='red'><b>,</b></font> താല്പര്യം<font color='red'><b>,</b></font> ചുറുചുറുക്ക്‌<font color='red'><b>,</b></font> പ്രവര്‍ത്തനശക്തി<font color='red'><b>,</b></font> താല്‍പര്യം<font color='red'><b>,</b></font> ഉത്സാഹാവസ്ഥ<font color='red'><b>,</b></font> ഉപജീവനം<font color='red'><b>,</b></font> ചൊടി<font color='red'><b>,</b></font> കര്‍മ്മണ്യത<font color='red'><b>,</b></font> ക്രിയാശീലത<font color='red'><b>,</b></font> ചുറുചുറുക്ക്<font color='red'><b>,</b></font> ചൊടി
#
# actual: യഥാര്‍ത്ഥമായ<font color='red'><b>,</b></font> യഥാര്‍ത്ഥത്തിലുള്ള<font color='red'><b>,</b></font> വാസ്‌തവമായ<font color='red'><b>,</b></font> വാസ്‌തവികമായ<font color='red'><b>,</b></font> ഇപ്പോഴുള്ള<font color='red'><b>,</b></font> സത്യമായ<font color='red'><b>,</b></font> ഇപ്പോഴുള്ള<font color='red'><b>,</b></font> പാരമാര്‍ത്ഥികമായ<font color='red'><b>,</b></font> വാസ്തവമായ
#
# acumen: സൂക്ഷ്‌മബുദ്ധി<font color='red'><b>,</b></font> ഗ്രഹണവൈദഗ്‌ദ്ധ്യം<font color='red'><b>,</b></font> യുക്തി<font color='red'><b>,</b></font> നിശിതബുദ്ധി<font color='red'><b>,</b></font> കാര്യഗ്രഹണശക്തി<font color='red'><b>,</b></font> സൂക്ഷ്മബുദ്ധി
#
# acute: തീക്ഷ്‌ണമായ<font color='red'><b>,</b></font> സൂക്ഷ്‌മബുദ്ധിയുള്ള<font color='red'><b>,</b></font> കഠിനമായ<font color='red'><b>,</b></font> സൂക്ഷ്‌മമായ<font color='red'><b>,</b></font> തീവ്രമായ<font color='red'><b>,</b></font> തുളച്ചുകയറുന്ന<font color='red'><b>,</b></font> കൂര്‍ത്ത<font color='red'><b>,</b></font> ആഴത്തിലേക്കിറങ്ങുന്ന<font color='red'><b>,</b></font> കൂര്‍ത്തമുനയുള്ള<font color='red'><b>,</b></font> അതിയായ<font color='red'><b>,</b></font> കുശാഗ്രബുദ്ധിയുള്ള<font color='red'><b>,</b></font> തീക്ഷ്ണമായ<font color='red'><b>,</b></font> അത്യന്തം മൂര്‍ച്ഛിച്ച
#
# acutely: അഗാധമായി<font color='red'><b>,</b></font>  ഗാഢമായി<font color='red'><b>,</b></font> തീവ്രമായി<font color='red'><b>,</b></font> കടുപ്പമായി<font color='red'><b>,</b></font> കടുപ്പമായി<font color='red'><b>,</b></font> തീവ്രതയോടെ<font color='red'><b>,</b></font> തീവ്രതയോടെ
#
# acuteness: അവബോധം<font color='red'><b>,</b></font> തീവ്രത<font color='red'><b>,</b></font> കടുപ്പം<font color='red'><b>,</b></font> ഉഗ്രത<font color='red'><b>,</b></font> ബുദ്ധികൂര്‍മ്മത
#
# adamantine: വജ്രത്തെപ്പോലെ കടുപ്പമുള്ള
#
# adaptation: അനുരൂപീകരണം<font color='red'><b>,</b></font> പരിതഃസ്ഥിതകളോടു പൂര്‍ണ്ണമായും ഇണങ്ങിചേരല്‍
#
# addition: സമ്മേളനം<font color='red'><b>,</b></font> സംയോഗം<font color='red'><b>,</b></font> ചേര്‍ക്കല്‍<font color='red'><b>,</b></font> സംയോജനം<font color='red'><b>,</b></font> സംയോഗം<font color='red'><b>,</b></font> സംഭാഷണം<font color='red'><b>,</b></font> സങ്കലനം<font color='red'><b>,</b></font> കൂട്ടല്‍<font color='red'><b>,</b></font> കലര്‍ത്തല്‍<font color='red'><b>,</b></font> ചേര്‍ക്കപ്പട്ടത്‌<font color='red'><b>,</b></font> കൂടുതലായി ചേര്‍ത്ത വസ്‌തു<font color='red'><b>,</b></font> സംയോഗം<font color='red'><b>,</b></font> സംയോജനം<font color='red'><b>,</b></font> ചേര്‍ക്കപ്പട്ടത്<font color='red'><b>,</b></font> കൂടുതലായി ചേര്‍ത്ത വസ്തു<font color='red'><b>,</b></font> ചേര്‍ക്കല്‍<font color='red'><b>,</b></font> കൂടെ
#
# address: മേല്‍വിലാസമെഴുതുക<font color='red'><b>,</b></font> പ്രസംഗം<font color='red'><b>,</b></font> പ്രഭാഷണം<font color='red'><b>,</b></font> ഡാറ്റ മെമ്മറിയില്‍ രേഖപ്പെടുത്തി സൂക്ഷിക്കുന്ന സ്‌ഥലത്തെ തിരിച്ചറിയാനുള്ള പ്രത്യേക പേരോ നമ്പരോ<font color='red'><b>,</b></font> മേല്‍വിലാസം<font color='red'><b>,</b></font> അഭിസംബോധനം<font color='red'><b>,</b></font> ആരംഭിക്കുക<font color='red'><b>,</b></font> പ്രസംഗിക്കുക<font color='red'><b>,</b></font> സംബോധന ചെയ്യുക<font color='red'><b>,</b></font> എഴുതി അറിയിക്കുക<font color='red'><b>,</b></font> സദസ്സിനോടൊ വ്യക്തിയോടൊ പ്രസംഗിക്കുക<font color='red'><b>,</b></font> നിവേദനം നടത്തുക<font color='red'><b>,</b></font> പറയുക<font color='red'><b>,</b></font> ഉപചരിക്കുക<font color='red'><b>,</b></font> വിലാസം എഴുതുക<font color='red'><b>,</b></font> അറിവുണ്ടായിരിക്കുക<font color='red'><b>,</b></font> പരിചയമുണ്ടായിരിക്കുക
#
# adequacy: പര്യാപ്‌തത<font color='red'><b>,</b></font> അനുയോജ്യത<font color='red'><b>,</b></font> ക്ഷമത<font color='red'><b>,</b></font> മതിയായിരിക്കല്‍
#
# adequate: കഷ്ടിച്ച്<font color='red'><b>,</b></font> യോഗ്യമായ<font color='red'><b>,</b></font> യോജിച്ച്<font color='red'><b>,</b></font> മതിയായ<font color='red'><b>,</b></font> പര്യാപ്‌തമായ<font color='red'><b>,</b></font> യോജിച്ച<font color='red'><b>,</b></font> തൃപ്‌തികരമായ<font color='red'><b>,</b></font> വേണ്ടിടത്തോളമുള്ള<font color='red'><b>,</b></font> കഷ്‌ടിച്ചു തികയുന്ന<font color='red'><b>,</b></font> അനുയോജ്യമായ<font color='red'><b>,</b></font> ആവശ്യമായ
#
# adherence: താല്‍പര്യം<font color='red'><b>,</b></font> അവലംബനം<font color='red'><b>,</b></font> പിന്‍തുടരല്‍<font color='red'><b>,</b></font> പിന്തുണ നല്‍കല്‍<font color='red'><b>,</b></font> ഒട്ടിപ്പിടിക്കല്‍<font color='red'><b>,</b></font> കൂറ്‌
#
# adherent: ആശ്രിതന്‍<font color='red'><b>,</b></font> ശിഷ്യന്‍<font color='red'><b>,</b></font> പക്ഷക്കാരന്‍<font color='red'><b>,</b></font> അനുചരന്‍<font color='red'><b>,</b></font> അനുയായി
#
# adherents: പക്ഷക്കാര്‍<font color='red'><b>,</b></font> ശിഷ്യജനങ്ങള്‍<font color='red'><b>,</b></font> പിൻതാങ്ങുന്നവർ<font color='red'><b>,</b></font> അനുയായികൾ
#
# adhesion: സംസക്തി<font color='red'><b>,</b></font> അവലംബനം<font color='red'><b>,</b></font> ഒട്ടല്‍<font color='red'><b>,</b></font> പിടിത്തം<font color='red'><b>,</b></font> കൂടിച്ചേരല്‍<font color='red'><b>,</b></font> പിടിപ്പ്‌<font color='red'><b>,</b></font> ഉറ്റബന്ധം<font color='red'><b>,</b></font> പിടിപ്പ്
#
# adhesive: പശ<font color='red'><b>,</b></font> ഒട്ടിക്കാനുപയോഗിക്കുന്ന വസ്‌തു<font color='red'><b>,</b></font> ഒട്ടിപ്പിടിക്കുന്ന വസ്‌തു<font color='red'><b>,</b></font> ഒട്ടുന്ന വസ്തു<font color='red'><b>,</b></font> ഒട്ടിക്കുക<font color='red'><b>,</b></font> ഘടിപ്പിക്കുക<font color='red'><b>,</b></font> ബന്ധിപ്പിക്കുക<font color='red'><b>,</b></font> ഒട്ടുന്ന<font color='red'><b>,</b></font> പറ്റുന്ന<font color='red'><b>,</b></font> ഒട്ടിപ്പിടിക്കുന്ന<font color='red'><b>,</b></font> ഘടിപ്പിക്കാനുപയോഗിക്കുന്ന<font color='red'><b>,</b></font> ദൃഢീകരിക്കത്തക്ക<font color='red'><b>,</b></font> ഘടിപ്പിക്കാവുന്ന
#
# admirable: ശ്രേഷ്ടമായ
#
# <font color='red'><b>,</b></font> സ്‌തുത്യര്‍ഹമായ<font color='red'><b>,</b></font> മികച്ച<font color='red'><b>,</b></font> ആരാധ്യനായ<font color='red'><b>,</b></font> പ്രശംസനീയമായ
#
# admiration: പ്രശംസ
#
# <font color='red'><b>,</b></font> മതിപ്പ്‌<font color='red'><b>,</b></font> ആനന്ദംകലര്‍ന്ന ആരാധന<font color='red'><b>,</b></font> ആരാധനാപാത്രം<font color='red'><b>,</b></font> ആദരവ്‌
#
# admire: പുകഴ്‌ത്തുക<font color='red'><b>,</b></font> ആദരിക്കുക<font color='red'><b>,</b></font> പ്രശംസിക്കുക<font color='red'><b>,</b></font> ആരാധിക്കുക<font color='red'><b>,</b></font> വിസ്‌മയത്തോടെ കാണുക<font color='red'><b>,</b></font> കൗതുകപ്പെടുക<font color='red'><b>,</b></font> പുകഴ്ത്തുക<font color='red'><b>,</b></font> വിസ്മയത്തോടെ കാണുക
#
# admissible: സ്വീകാരയോഗ്യമായ<font color='red'><b>,</b></font> തെളിവായി കൈകൊള്ളാവുന്ന<font color='red'><b>,</b></font> പരിഗണിക്കാവുന്ന<font color='red'><b>,</b></font> തെളിവായി കൈക്കൊള്ളാവുന്ന<font color='red'><b>,</b></font> സ്വീകാരയോഗ്യമായ<font color='red'><b>,</b></font> തെളിവായി കൈക്കൊള്ളാവുന്ന
#
# admission: പ്രവേശനാനുമതി<font color='red'><b>,</b></font> സമ്മതം<font color='red'><b>,</b></font> പ്രവേശനം<font color='red'><b>,</b></font> ഏറ്റുപറയല്‍<font color='red'><b>,</b></font> അംഗീകരണം<font color='red'><b>,</b></font> കുറ്റസമ്മതം
#
# admittedly: നിസ്സംശയമായും<font color='red'><b>,</b></font> തീര്‍ച്ചയായും<font color='red'><b>,</b></font> സത്യം പറഞ്ഞാല്‍<font color='red'><b>,</b></font> സമ്മതപൂര്‍വ്വം
#
# admonitory: താക്കീത്‌<font color='red'><b>,</b></font> ഉപദേശം<font color='red'><b>,</b></font> താക്കീതു നല്‍കുന്ന<font color='red'><b>,</b></font> ഗുണദോഷ രൂപത്തിലുള്ള<font color='red'><b>,</b></font> ഗുണദോഷ രൂപത്തിലുള്ള
#
# adolescent: യുവതി<font color='red'><b>,</b></font> അനതീതകൗമാരന്‍<font color='red'><b>,</b></font> യുവാവ്<font color='red'><b>,</b></font> ഇളംപ്രായമായ<font color='red'><b>,</b></font> കൗമാരപ്രായത്തിലുള്ള ആള്‍<font color='red'><b>,</b></font> കൗമാരപ്രായമായ<font color='red'><b>,</b></font> യൗവനം പ്രാപിച്ച
#
# adorable: മനോഹരമായ<font color='red'><b>,</b></font> സ്‌തുത്യര്‍ഹമായ<font color='red'><b>,</b></font> ആരാധ്യമായ<font color='red'><b>,</b></font> ഉത്തമമായ<font color='red'><b>,</b></font> മാന്യമായ<font color='red'><b>,</b></font> മനോഹരമായ<font color='red'><b>,</b></font> സ്തുത്യര്‍ഹമായ<font color='red'><b>,</b></font> സ്‌നേഹിക്കാവുന്ന<font color='red'><b>,</b></font> ആരാധനീയമായ<font color='red'><b>,</b></font> സ്നേഹിക്കാവുന്ന
#
# adoration: വന്ദനം<font color='red'><b>,</b></font> അര്‍ച്ചന<font color='red'><b>,</b></font> ഭയഭക്തി<font color='red'><b>,</b></font> ആരാധന<font color='red'><b>,</b></font> വണക്കം<font color='red'><b>,</b></font> വഴിപാട്‌<font color='red'><b>,</b></font> വഴിപാട്
#
# adorned: അലങ്കരിക്കപ്പെട്ട<font color='red'><b>,</b></font> അലംകൃതമായ<font color='red'><b>,</b></font> ആടാഭരണങ്ങളണിഞ്ഞ
#
# adroit: ചാതുര്യമുള്ള<font color='red'><b>,</b></font> കൗശലമുള്ള<font color='red'><b>,</b></font> നിപുണനായ<font color='red'><b>,</b></font> സാമര്‍ത്ഥ്യമുള്ള<font color='red'><b>,</b></font> മിടുക്കുള്ള
#
# adroitness: മിടുക്ക്‌<font color='red'><b>,</b></font> നൈപുണ്യം<font color='red'><b>,</b></font> ചാതുര്യം<font color='red'><b>,</b></font> വിരുത്‌<font color='red'><b>,</b></font> മിടുക്ക്<font color='red'><b>,</b></font> വിരുത്
#
# advance: പുരോഗതി<font color='red'><b>,</b></font> അഭിവൃദ്ധി<font color='red'><b>,</b></font> കയറ്റം<font color='red'><b>,</b></font> മുന്‍കൂട്ടി<font color='red'><b>,</b></font> പുരോഗമനം<font color='red'><b>,</b></font> മുന്‍പന്‍<font color='red'><b>,</b></font> പടര്‍ച്ച<font color='red'><b>,</b></font> മുന്‍കൂര്‍<font color='red'><b>,</b></font> വര്‍ദ്ധനം<font color='red'><b>,</b></font> മുന്‍പണം<font color='red'><b>,</b></font> നേതാവ്
#
# <font color='red'><b>,</b></font> പുരോഗതി<font color='red'><b>,</b></font> പുരോഗമനം<font color='red'><b>,</b></font> പ്രേമാഭ്യര്‍ത്ഥന<font color='red'><b>,</b></font> നേരത്തെ<font color='red'><b>,</b></font> പുരോഗമി<font color='red'><b>,</b></font> പോഷിപ്പിക്കുക<font color='red'><b>,</b></font> വളര്‍ത്തുക<font color='red'><b>,</b></font> മുന്നേറുക<font color='red'><b>,</b></font> നീട്ടുക<font color='red'><b>,</b></font> ഉയര്‍ത്തുക<font color='red'><b>,</b></font> പുറപ്പെടുവിക്കുക<font color='red'><b>,</b></font> മുന്നോട്ടുനീങ്ങുക<font color='red'><b>,</b></font> മുന്നോട്ടു കൊണ്ടുവരിക<font color='red'><b>,</b></font> മുന്‍കൂര്‍ കൊടുക്കുക<font color='red'><b>,</b></font> പുരോഗതിനേടുക<font color='red'><b>,</b></font> വായ്‌പയായി നല്‍കുക<font color='red'><b>,</b></font> വര്‍ദ്ധിക്കുക<font color='red'><b>,</b></font> മുമ്പോട്ടുപോകുക<font color='red'><b>,</b></font> കൂടുതല്‍ മെച്ചപ്പെടുക<font color='red'><b>,</b></font> വായ്‌പ കൊടുക്കുക<font color='red'><b>,</b></font> മുമ്പേറു കൊടുക്കുക<font color='red'><b>,</b></font> നിര്‍ദ്ദേശം നല്‍കുക<font color='red'><b>,</b></font> നേരത്തെയാകുക<font color='red'><b>,</b></font> പണം മുന്‍കൂര്‍ കൊടുക്കുക<font color='red'><b>,</b></font> നേരത്തെയുള്ള<font color='red'><b>,</b></font> മുമ്പിലെത്തിയ<font color='red'><b>,</b></font> മുന്‍കൂറായി<font color='red'><b>,</b></font> മുന്‍കൂട്ടിയുള്ള<font color='red'><b>,</b></font> മുന്‍കൂട്ടി<font color='red'><b>,</b></font> മുന്‍പോട്ടാക്കുക
#
# advantage: അവസരം<font color='red'><b>,</b></font> ആനുകൂല്യം<font color='red'><b>,</b></font> പറ്റിക്കുക<font color='red'><b>,</b></font> പ്രയോജനം<font color='red'><b>,</b></font> ഗുണം<font color='red'><b>,</b></font> നേട്ടം<font color='red'><b>,</b></font> അനുകൂലസന്ദര്‍ഭം<font color='red'><b>,</b></font> കൂടുതല്‍ മെച്ചപ്പെട്ട സ്ഥാനം<font color='red'><b>,</b></font> കാര്യലാഭം<font color='red'><b>,</b></font> പിഴപ്പിക്കുക<font color='red'><b>,</b></font> മുന്‍ഗണന<font color='red'><b>,</b></font> പ്രയോജനം<font color='red'><b>,</b></font> ടെന്നീസില്‍ ഡ്യൂസ്‌ കഴിഞ്ഞ്‌ കിട്ടുന്ന ആദ്യത്തെ പോയിന്റ്‌<font color='red'><b>,</b></font> അനുകൂലത<font color='red'><b>,</b></font> മെച്ചം<font color='red'><b>,</b></font> പ്രയോജനപ്പെടുത്തുക<font color='red'><b>,</b></font> ടെന്നീസില്‍ ഡ്യൂസ് കഴിഞ്ഞ് കിട്ടുന്ന ആദ്യത്തെ പോയിന്‍റ്<font color='red'><b>,</b></font> സാഹചര്യങ്ങള്‍ പ്രയോജനപ്പെടുത്തുക<font color='red'><b>,</b></font> പറ്റിക്കുക<font color='red'><b>,</b></font> ഉപകരിക്കുക<font color='red'><b>,</b></font> പോഷിപ്പിക്കുക<font color='red'><b>,</b></font> മേന്മ<font color='red'><b>,</b></font> പ്രയോജനപ്പെടുക<font color='red'><b>,</b></font> അനുകൂലമായിരിക്കുക<font color='red'><b>,</b></font> സാഹചര്യങ്ങള്‍ പ്രയോജനപ്പെടുത്തുക<font color='red'><b>,</b></font> പിഴപ്പിക്കുക<font color='red'><b>,</b></font> പ്രയോജനപ്പെടുത്തുക<font color='red'><b>,</b></font> ലാഭമാക്കുക<font color='red'><b>,</b></font> പ്രയോജനം<font color='red'><b>,</b></font> അനുകൂലമാക്കുക<font color='red'><b>,</b></font> അനുകൂല സന്ദര്‍ഭം
#
# advantageous: പറ്റിക്കുക<font color='red'><b>,</b></font> സാഹചര്യങ്ങള്‍ പ്രയോജനപ്പെടുത്തുക<font color='red'><b>,</b></font> പിഴപ്പിക്കുക<font color='red'><b>,</b></font> ഹിതകരമായ<font color='red'><b>,</b></font> പ്രയോജനപ്രദമായ<font color='red'><b>,</b></font> ഗുണകരമായ<font color='red'><b>,</b></font> പ്രയോജനപ്രദമായ
#
# adventitious: ആഗന്തുകമായ<font color='red'><b>,</b></font> ആകസ്‌മികമായ<font color='red'><b>,</b></font> യദൃച്ഛയാ സംഭവിക്കുന്ന<font color='red'><b>,</b></font> പതിവില്ലാത്ത സ്ഥനത്തു സംഭവിക്കുന്ന<font color='red'><b>,</b></font> പതിവില്ലാത്ത<font color='red'><b>,</b></font> അസ്ഥാനത്തുണ്ടായ
#
# adventure: സാഹസം<font color='red'><b>,</b></font> അപകടസാദ്ധ്യത നിറഞ്ഞ സംരംഭം<font color='red'><b>,</b></font> വീരസാഹസ പ്രവൃത്തി<font color='red'><b>,</b></font> അപ്രതീക്ഷിതമോ സ്‌തോഭജനകമോ ആയ സംഭവം<font color='red'><b>,</b></font> സാഹസകൃത്യം<font color='red'><b>,</b></font> വീരസാഹസപ്രവൃത്തി<font color='red'><b>,</b></font> ആകസ്മിക സംഭവം<font color='red'><b>,</b></font> തുനിയുക<font color='red'><b>,</b></font> അപകടകാര്യത്തില്‍ പ്രവേശിക്കുക
#
# adventurer: വീരന്‍<font color='red'><b>,</b></font> സാഹസികന്‍<font color='red'><b>,</b></font> സൂത്രങ്ങള്‍കൊണ്ട്‌ ജീവിക്കുന്നവന്‍<font color='red'><b>,</b></font> സൂത്രങ്ങള്‍ കൊണ്ട്‌ ജീവിക്കുന്നവന്‍<font color='red'><b>,</b></font> ദുഷ്കര്‍മ്മത്തില്‍ പരിശ്രമിക്കുന്നവന്‍<font color='red'><b>,</b></font> സൂത്രങ്ങള്‍ കൊണ്ട് ജീവിക്കുന്നവന്‍
#
# adventurous: സാഹസിക കൃത്യങ്ങള്‍<font color='red'><b>,</b></font> സാഹസികമായ<font color='red'><b>,</b></font> ധൈര്യമുള്ള<font color='red'><b>,</b></font> സാഹസമുള്ള<font color='red'><b>,</b></font> തുനിയുന്ന
#
# adverse: വിപരീതമായ<font color='red'><b>,</b></font> വിരുദ്ധമായ<font color='red'><b>,</b></font> പ്രതികൂലമായ<font color='red'><b>,</b></font> ഹാനികരമായ<font color='red'><b>,</b></font> കോട്ടം വരുത്തുന്ന<font color='red'><b>,</b></font> മോശമായ<font color='red'><b>,</b></font> വിരോധമായ<font color='red'><b>,</b></font> വിരോധമുള്ള<font color='red'><b>,</b></font> അനുകൂലമല്ലാത്ത<font color='red'><b>,</b></font> കോട്ടം വരുത്തുന്ന
#
# advice: അനുശാസനം<font color='red'><b>,</b></font> അറിവ്‌<font color='red'><b>,</b></font> അറിയിപ്പ്‌<font color='red'><b>,</b></font> ഉപദേശം<font color='red'><b>,</b></font> അഭിപ്രായം<font color='red'><b>,</b></font> അറിയിപ്പ്
#
# advisable: ഉചിതമായ<font color='red'><b>,</b></font> യോഗ്യമായ<font color='red'><b>,</b></font> അഭിലഷണീയമായ<font color='red'><b>,</b></font> യുക്തമായ<font color='red'><b>,</b></font> വിവേകപൂര്‍വ്വമായ<font color='red'><b>,</b></font> ആശാസ്യമായ<font color='red'><b>,</b></font> ബുദ്ധിപൂര്‍വ്വമായ<font color='red'><b>,</b></font> ശുപാര്‍ശചെയ്യാന്‍ തക്കതായ
#
# affability: അനുനയം<font color='red'><b>,</b></font> വിനയം<font color='red'><b>,</b></font> കുലീനത<font color='red'><b>,</b></font> ആദരവ്‌<font color='red'><b>,</b></font> സൗഹൃദം<font color='red'><b>,</b></font> ഇണങ്ങിച്ചേരല്‍<font color='red'><b>,</b></font> സ്‌നേഹപൂര്‍വ്വമായ പെരുമാറ്റം<font color='red'><b>,</b></font> ആദരവ്<font color='red'><b>,</b></font> സ്നേഹപൂര്‍വ്വമായ പെരുമാറ്റം
#
# affable: അനുനയമുള്ള<font color='red'><b>,</b></font> ഉപചാരശീലമുള്ള<font color='red'><b>,</b></font> മര്യാദയുള്ള<font color='red'><b>,</b></font> മധുരവാക്കായ<font color='red'><b>,</b></font> കൃപയുള്ള<font color='red'><b>,</b></font> സൗഹൃദമുള്ള<font color='red'><b>,</b></font> ഉപചാരശീലമുളള
#
# affably: വിനയപൂര്‍വ്വം<font color='red'><b>,</b></font> കുലീനതയോടെ<font color='red'><b>,</b></font> മര്യാദയോടെ<font color='red'><b>,</b></font> സൗഹൃദത്തോടെ<font color='red'><b>,</b></font> കുലീനതയോടെ<font color='red'><b>,</b></font> മര്യാദയോടെ<font color='red'><b>,</b></font> സൗഹൃദത്തോടെ
#
# affectation: അഹങ്കാരം<font color='red'><b>,</b></font> കാപട്യം<font color='red'><b>,</b></font> നാട്യം<font color='red'><b>,</b></font> നടിപ്പ്‌<font color='red'><b>,</b></font> വേഷം കെട്ടല്‍
#
# affected: കപടമായ<font color='red'><b>,</b></font> കൃത്രിമമായ<font color='red'><b>,</b></font> ബാധിതമായി<font color='red'><b>,</b></font> ഉദ്ധതമായ<font color='red'><b>,</b></font> കപടവേഷമായ<font color='red'><b>,</b></font> ചായ്‌വുള്ള<font color='red'><b>,</b></font> അസ്വാഭാവികമായ<font color='red'><b>,</b></font> പ്രഭാവം ചെലുത്തുന്ന<font color='red'><b>,</b></font> രോഗഗ്രസ്‌തമായ<font color='red'><b>,</b></font> രോഗഗ്രസ്തമായ<font color='red'><b>,</b></font> ചായ്‍വുള്ള
#
# affection: സ്വഭാവം<font color='red'><b>,</b></font> രോഗം<font color='red'><b>,</b></font> വികാരം<font color='red'><b>,</b></font> സ്‌നേഹം<font color='red'><b>,</b></font> മമത<font color='red'><b>,</b></font> വ്യാധി<font color='red'><b>,</b></font> പ്രതിപത്തി<font color='red'><b>,</b></font> ദയ<font color='red'><b>,</b></font> മാനസികാവസ്ഥ<font color='red'><b>,</b></font> സ്‌നേഹബന്ധം<font color='red'><b>,</b></font> വാത്സല്യം<font color='red'><b>,</b></font> സ്നേഹം<font color='red'><b>,</b></font> സ്നേഹബന്ധം
#
# affectionate: സ്‌നേഹമുള്ള<font color='red'><b>,</b></font> സ്‌നേഹപൂര്‍വ്വമായ<font color='red'><b>,</b></font> വാത്സല്യപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> അനുരാഗപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> സ്നേഹമുള്ള
#
# affective: വൈകാരികമായ<font color='red'><b>,</b></font> സ്‌നേഹാദിവികാരങ്ങളെ സംബന്ധിച്ച<font color='red'><b>,</b></font> വികാരസംബന്ധിയായ
#
# affianced: മന:സ്സമ്മതം കഴിഞ്ഞ
#
# affirmation: ഉറപ്പ്‌<font color='red'><b>,</b></font> ദൃഢപ്രതിജ്ഞ<font color='red'><b>,</b></font> സമ്മതിക്കല്‍<font color='red'><b>,</b></font> സത്യവാചകം<font color='red'><b>,</b></font> പ്രമാണീകരണം
#
# affirmative: വാസ്‌തവസ്ഥാപനം<font color='red'><b>,</b></font> വിധിരൂപം<font color='red'><b>,</b></font> സമ്മതാര്‍ത്ഥം കുറിക്കുന്ന വാക്ക്‌<font color='red'><b>,</b></font> സമ്മതിക്കുന്ന<font color='red'><b>,</b></font> ഉറപ്പിക്കുന്ന<font color='red'><b>,</b></font> സിദ്ധാന്തരൂപമായ<font color='red'><b>,</b></font> അംഗീകാര സ്വഭാവമുള്ള<font color='red'><b>,</b></font> അംഗീകാരദ്യോതകമായ<font color='red'><b>,</b></font> സ്വീകാര്യദ്യോതകമായ<font color='red'><b>,</b></font> അംഗീകാരദ്യോതകമായ<font color='red'><b>,</b></font> സ്വീകാര്യദ്യോതകമായ
#
# affluence: ഭാഗ്യം<font color='red'><b>,</b></font> സമൃദ്ധി<font color='red'><b>,</b></font> പ്രവാഹം<font color='red'><b>,</b></font> ഒഴുക്ക്‌<font color='red'><b>,</b></font> സമ്പത്ത്‌<font color='red'><b>,</b></font> ആധിക്യം<font color='red'><b>,</b></font> ഐശ്വര്യം<font color='red'><b>,</b></font> സമ്പത്ത്<font color='red'><b>,</b></font> ധനാഢ്യത<font color='red'><b>,</b></font> ഒഴുക്ക്<font color='red'><b>,</b></font> സന്പത്ത്
#
# affluent: പോഷകനദി<font color='red'><b>,</b></font> സമൃദ്ധമായ<font color='red'><b>,</b></font> സമ്പത്തുള്ള<font color='red'><b>,</b></font> ധനാഢ്യമായ<font color='red'><b>,</b></font> ഉപനദി<font color='red'><b>,</b></font> പോഷകനദി<font color='red'><b>,</b></font> സന്പത്തുള്ള
#
# affright: ഭയപ്പെടുത്തുക<font color='red'><b>,</b></font> ഭീഷണിപ്പെടുത്തുക
#
# affront: അധിക്ഷേപം<font color='red'><b>,</b></font> നിന്ദ<font color='red'><b>,</b></font> അവജ്ഞ<font color='red'><b>,</b></font> അവഹേളനം<font color='red'><b>,</b></font> അപമര്യാദ<font color='red'><b>,</b></font> അനാദരവ്‌<font color='red'><b>,</b></font> അപമാനം<font color='red'><b>,</b></font> നിന്ദിക്കുക<font color='red'><b>,</b></font> അധിക്ഷേപിക്കുക<font color='red'><b>,</b></font> ധിക്കരിക്കുക<font color='red'><b>,</b></font> നേരിടുക<font color='red'><b>,</b></font> അപമാനിക്കുക<font color='red'><b>,</b></font> പരസ്യമായി അപമാനിക്കുക<font color='red'><b>,</b></font> അവഹേളിക്കുക
#
# afraid: പേടിച്ചരണ്ട<font color='red'><b>,</b></font> വിരണ്ട<font color='red'><b>,</b></font> ഖേദമുളള<font color='red'><b>,</b></font> സംശയമുളള<font color='red'><b>,</b></font> ഭയപ്പെട്ട<font color='red'><b>,</b></font> ശങ്കിക്കുന്ന<font color='red'><b>,</b></font> ശങ്കയുള്ള<font color='red'><b>,</b></font> പേടിച്ച<font color='red'><b>,</b></font> ഖേദമുള്ള<font color='red'><b>,</b></font> ഭയമുള്ള
#
# after-
#
# age: കാലഘട്ടം<font color='red'><b>,</b></font> തലമുറ<font color='red'><b>,</b></font> പുരുഷായുസ്‌<font color='red'><b>,</b></font> യുഗം<font color='red'><b>,</b></font> പ്രായം<font color='red'><b>,</b></font> ജീവതകാലം<font color='red'><b>,</b></font> പുരുഷാന്തരം<font color='red'><b>,</b></font> നിയമപ്രകാരമുള്ള പ്രായപൂര്‍ത്തി<font color='red'><b>,</b></font> വയസ്സ്‌<font color='red'><b>,</b></font> ആയുസ്സ്‌<font color='red'><b>,</b></font> കുറേസമയം<font color='red'><b>,</b></font> കല്‌പം<font color='red'><b>,</b></font> യുഗങ്ങള്‍<font color='red'><b>,</b></font> പ്രാചീനത്വം<font color='red'><b>,</b></font> ആയുസ്സ്<font color='red'><b>,</b></font> വയസ്സ്<font color='red'><b>,</b></font> കല്പം<font color='red'><b>,</b></font> വളരുക<font color='red'><b>,</b></font> വയസ്സാവുക<font color='red'><b>,</b></font> പഴകുക<font color='red'><b>,</b></font> പ്രായമാവുക<font color='red'><b>,</b></font> വൃദ്ധനാവുക<font color='red'><b>,</b></font> വാര്‍ദ്ധക്യം പ്രാപിക്കുക
#
# agent: കാര്യസ്ഥന്‍<font color='red'><b>,</b></font> പ്രതിനിധി<font color='red'><b>,</b></font> ഹേതു<font color='red'><b>,</b></font> മൂലശക്തി<font color='red'><b>,</b></font> കാണഭൂതന്‍<font color='red'><b>,</b></font> ഒരാള്‍ക്കു പകരം വ്യവഹാരം നടത്തുന്നതിന്‍ അധികാരമുള്ളവന്‍<font color='red'><b>,</b></font> വാര്‍ത്താ വാഹകന്‍<font color='red'><b>,</b></font> പ്രകൃതിശക്തി<font color='red'><b>,</b></font> പ്രവര്‍ത്തകന്‍<font color='red'><b>,</b></font> കാര്യകര്‍ത്താവ്‌<font color='red'><b>,</b></font> ഏജന്റ്‌<font color='red'><b>,</b></font> ഏജന്‍റ്<font color='red'><b>,</b></font> കാര്യകര്‍ത്താവ്
#
# aggrandizement: ധന(പദവി) സമ്പാദനം<font color='red'><b>,</b></font> പ്രതാപം ഉയര്‍ത്തല്‍<font color='red'><b>,</b></font> അധികാരോന്നമനം<font color='red'><b>,</b></font> ശക്തിവര്‍ദ്ധന<font color='red'><b>,</b></font> ധന(പദവി) സന്പാദനം<font color='red'><b>,</b></font> അധികാരോന്നമനം
#
# aggravated: വര്‍ദ്ധിതം<font color='red'><b>,</b></font> ഏറിയ<font color='red'><b>,</b></font> കൂടിയ
#
# aggregate: സംഗ്രഹിക്കുക<font color='red'><b>,</b></font> ഒന്നുചേര്‍ന്ന<font color='red'><b>,</b></font> ഒന്നായി കൂട്ടിയത്‌<font color='red'><b>,</b></font> ഒന്നിക്കുക<font color='red'><b>,</b></font> സംഗ്രഹം<font color='red'><b>,</b></font> മൊത്തം<font color='red'><b>,</b></font> ശേഖരിക്കുക<font color='red'><b>,</b></font> സമാഹരിക്കുക<font color='red'><b>,</b></font> സഞ്ചയിക്കുക<font color='red'><b>,</b></font> കൂട്ടുക<font color='red'><b>,</b></font> മൊത്തം തുക<font color='red'><b>,</b></font> ഒന്നിച്ചു ചേര്‍ക്കുക<font color='red'><b>,</b></font> മൊത്തമാക്കുക<font color='red'><b>,</b></font> ഒരുമിച്ചു കൂട്ടുക<font color='red'><b>,</b></font> സമഷ്‌ടയായ<font color='red'><b>,</b></font> മൊത്തമായ<font color='red'><b>,</b></font> ആകെത്തുകയായ
#
# aggression: ആക്രമണം<font color='red'><b>,</b></font> സമാധാന ലംഘനം<font color='red'><b>,</b></font> യുദ്ധാരംഭം<font color='red'><b>,</b></font> പ്രഥമാപകാരം<font color='red'><b>,</b></font> കൈയേറ്റം<font color='red'><b>,</b></font> പ്രകോപനമില്ലാതെയുള്ള
#
# aggressive: വിരുദ്ധമായ<font color='red'><b>,</b></font> ആക്രമിക്കുന്ന<font color='red'><b>,</b></font> ആക്രമണ സൗഭവമുള്ള<font color='red'><b>,</b></font> വൈരംനിറഞ്ഞതോ വിനാശകരമോ ആയ<font color='red'><b>,</b></font> ആക്രമസ്വഭാവമുള്ള<font color='red'><b>,</b></font> ഉത്സാഹത്തോടെയുള്ള
#
# aggressiveness: കൈയേറ്റക്കാരന്‍<font color='red'><b>,</b></font> അക്രമി
#
# aghast: അമ്പരന്ന<font color='red'><b>,</b></font> അമ്പരന്ന്‌<font color='red'><b>,</b></font> അന്പരന്ന്<font color='red'><b>,</b></font> അത്ഭുതപരവശമായി<font color='red'><b>,</b></font> ഭയപ്പെട്ട<font color='red'><b>,</b></font> ഭയാക്രാന്തനായ<font color='red'><b>,</b></font> അന്ധാളിച്ച<font color='red'><b>,</b></font> ഭ്രമിച്ച<font color='red'><b>,</b></font> ഭയപരവശമായ
#
# agile: ചൈതന്യമുള്ള<font color='red'><b>,</b></font> ഉത്സാഹമുള്ള<font color='red'><b>,</b></font> ഊര്‍ജ്ജസ്വലമായ<font color='red'><b>,</b></font> ചുറുചുറുക്കുള്ള<font color='red'><b>,</b></font> ശരീരലാഘവമുള്ള<font color='red'><b>,</b></font> വേഗഗമനമുള്ള<font color='red'><b>,</b></font> സമര്‍ത്ഥനായ<font color='red'><b>,</b></font> വേഗത്തിലും അനായാസവും  ചലിക്കാന്‍  കഴിവുളള<font color='red'><b>,</b></font> ചുണയുളള
#
# agility: ചുറുചുറുക്ക്‌<font color='red'><b>,</b></font> ശരീരലാഘവമുള്ള
#
# agitate: ഇളക്കി മറിക്കുക<font color='red'><b>,</b></font> മനഃക്ഷോഭം വരുത്തുക<font color='red'><b>,</b></font> ശക്തിപൂര്‍വ്വം വാദിക്കുക<font color='red'><b>,</b></font> ഇളക്കിവിടുക<font color='red'><b>,</b></font> പ്രക്ഷോഭണം നടത്തുക<font color='red'><b>,</b></font> ബഹളം കൂട്ടുക<font color='red'><b>,</b></font> പ്രക്ഷോഭം നടത്തുക<font color='red'><b>,</b></font> സമരം നടത്തുക<font color='red'><b>,</b></font> പൊതു ജനശ്രദ്ധ ഉണര്‍ത്തുക<font color='red'><b>,</b></font> പ്രക്ഷോഭം നടത്തുക<font color='red'><b>,</b></font> ക്ഷോഭിപ്പിക്കുക
#
# agitated: വിക്ഷോഭത്തിനടിമയായവന്‍<font color='red'><b>,</b></font> പ്രക്ഷുബ്‌ധമായ<font color='red'><b>,</b></font> ഇളകിവശായ<font color='red'><b>,</b></font> വിക്ഷോഭിക്കപ്പെട്ട
#
# agitation: കുഴപ്പം<font color='red'><b>,</b></font> ബഹളം<font color='red'><b>,</b></font> അസ്വാസ്ഥ്യം<font color='red'><b>,</b></font> വ്യാകുലത<font color='red'><b>,</b></font> വിപ്ലവം<font color='red'><b>,</b></font> പ്രക്ഷോഭം<font color='red'><b>,</b></font> വിക്ഷോഭം<font color='red'><b>,</b></font> അസ്വാസ്ഥത<font color='red'><b>,</b></font> പ്രക്ഷോഭണം<font color='red'><b>,</b></font> പ്രക്ഷോഭം<font color='red'><b>,</b></font> പ്രക്ഷോഭണം
#
# agonizing: തീവ്രവേദന അനുഭവിക്കുക<font color='red'><b>,</b></font> വേദനാജനകമായ<font color='red'><b>,</b></font> വേദനിപ്പിക്കുന്ന<font color='red'><b>,</b></font> ഉത്‌കണ്‌ഠയുളവാക്കുന്ന
#
# agony: യാതന<font color='red'><b>,</b></font> മരണവേദന<font color='red'><b>,</b></font> കഠിനമായ കായികപീഡ<font color='red'><b>,</b></font> പ്രാണസങ്കടം<font color='red'><b>,</b></font> ഭയങ്കര കഷ്‌ടപ്പാട്‌<font color='red'><b>,</b></font> കഠിനദുഃഖം<font color='red'><b>,</b></font> അതിവേദന<font color='red'><b>,</b></font> മരണതുല്യമായ കഷ്‌ടപ്പാട്‌<font color='red'><b>,</b></font> ഭയങ്കര കഷ്ടപ്പാട്<font color='red'><b>,</b></font> മരണതുല്യമായ കഷ്ടപ്പാട്
#
# agreeable: മനോഹരമായ<font color='red'><b>,</b></font> പൊരുത്തമുള്ള<font color='red'><b>,</b></font> യോഗ്യമായ<font color='red'><b>,</b></font> യോജിച്ച<font color='red'><b>,</b></font> രുചികരമായ<font color='red'><b>,</b></font> മനസ്സുള്ള<font color='red'><b>,</b></font> തൃപ്‌തികരമായ<font color='red'><b>,</b></font> അമിതമായ<font color='red'><b>,</b></font> സ്വീകാര്യമായ<font color='red'><b>,</b></font> ഒത്ത<font color='red'><b>,</b></font> സദൃശ്യമായ<font color='red'><b>,</b></font> യോജിക്കുന്ന<font color='red'><b>,</b></font> പഥ്യമായ<font color='red'><b>,</b></font> ഒക്കുന്ന<font color='red'><b>,</b></font> അഭിമതമായ<font color='red'><b>,</b></font> ഹൃദ്യമായ<font color='red'><b>,</b></font> ഒരുക്കമുള്ള<font color='red'><b>,</b></font> സുന്ദരമായ<font color='red'><b>,</b></font> സമ്മതമായ
#
# agreement: ഐക്യം<font color='red'><b>,</b></font> ചേര്‍ച്ച<font color='red'><b>,</b></font> യോജിപ്പ്‌<font color='red'><b>,</b></font> കരാര്‍<font color='red'><b>,</b></font> പൊരുത്തം<font color='red'><b>,</b></font> ഐക്യമത്യം<font color='red'><b>,</b></font> സമ്മതം<font color='red'><b>,</b></font> സാദൃശ്യം<font color='red'><b>,</b></font> സഖ്യം<font color='red'><b>,</b></font> സമ്മതപത്രം<font color='red'><b>,</b></font> സാമജ്ഞസ്യം<font color='red'><b>,</b></font> ഐകമത്യം<font color='red'><b>,</b></font> നിശ്‌ഛയരേഖ<font color='red'><b>,</b></font> നിശ്ചയരേഖ
#
# aids: ആര്‍ട്ടിഫിഷ്യലി ഇന്റലിജന്‍റ്‌ ഡ്രാഫ്‌റ്റ്‌സ്‌മാന്‍ ഫോര്‍ സ്‌കീമാറ്റിക്‌സ്‌<font color='red'><b>,</b></font> എയ്‌ഡ്‌സ്‌ രോഗം<font color='red'><b>,</b></font> എയ്ഡ്സ് രോഗം
#
# aim: ഓങ്ങുക<font color='red'><b>,</b></font> ഉന്നം വയ്ക്കുക<font color='red'><b>,</b></font> പദ്ധതി<font color='red'><b>,</b></font> ലക്ഷ്യം<font color='red'><b>,</b></font> ഉദ്ദേശ്യം<font color='red'><b>,</b></font> ഉന്നം<font color='red'><b>,</b></font> നോട്ടം<font color='red'><b>,</b></font> ലക്ഷ്യമാക്കുക<font color='red'><b>,</b></font> പ്രയത്‌നിക്കുക<font color='red'><b>,</b></font> ഉന്നംവയ്‌ക്കുക<font color='red'><b>,</b></font> ലക്ഷ്യം നോക്കി പ്രയോഗിക്കുക<font color='red'><b>,</b></font> ഉദ്ധേശിക്കുക<font color='red'><b>,</b></font> ശ്രമിക്കുക<font color='red'><b>,</b></font> ലാക്കാക്കുക
#
# aimless: ലക്ഷ്യശൂന്യമായ<font color='red'><b>,</b></font> ഉദ്ധേശ്യരഹിതമായ<font color='red'><b>,</b></font> ലക്ഷ്യമില്ലാത്ത<font color='red'><b>,</b></font> ഉദ്ദേശ്യരഹിതമായ<font color='red'><b>,</b></font> ഉദ്ദേശ്യരഹിതമായി<font color='red'><b>,</b></font> പ്രയോജനമില്ലാത്ത<font color='red'><b>,</b></font> ലാക്കറ്റ
#
# aims: ലക്ഷ്യമാക്കുക
#
# air: കാലാവസ്ഥ<font color='red'><b>,</b></font> മുഖഭാവം<font color='red'><b>,</b></font> സ്ഥിതി<font color='red'><b>,</b></font> ഭാവം<font color='red'><b>,</b></font> വായു<font color='red'><b>,</b></font> കാറ്റ്‌<font color='red'><b>,</b></font> തുറന്നപ്രദേശം<font color='red'><b>,</b></font> ഉദ്ധതഭാവം<font color='red'><b>,</b></font> അന്തരീക്ഷം<font color='red'><b>,</b></font> വായുമണ്‌ഡലം<font color='red'><b>,</b></font> വിമാനം<font color='red'><b>,</b></font> ആകാരം<font color='red'><b>,</b></font> പരസ്യമാക്കുക<font color='red'><b>,</b></font> പ്രസ്‌താവിക്കുക<font color='red'><b>,</b></font> ഉണക്കുക<font color='red'><b>,</b></font> കാറ്റ്‌ കൊള്ളിക്കുക<font color='red'><b>,</b></font> കാറ്റത്തിടുക<font color='red'><b>,</b></font> അവാസ്തവമായ<font color='red'><b>,</b></font> കാറ്റ്
#
# airs: അഹങ്കാരം<font color='red'><b>,</b></font> പൊങ്ങച്ചം<font color='red'><b>,</b></font> നടിക്കല്‍
#
# airy: കാറ്റിന്റെ<font color='red'><b>,</b></font> ഉന്നതമായ<font color='red'><b>,</b></font> ഉത്സാഹമുളള<font color='red'><b>,</b></font> വായുമയമായ<font color='red'><b>,</b></font> ബാലിശമായ<font color='red'><b>,</b></font> ലോലമായ<font color='red'><b>,</b></font> സാങ്കല്‍പികമായ<font color='red'><b>,</b></font> കഴമ്പില്ലാത്ത<font color='red'><b>,</b></font> കാറ്റുപോലുള്ള<font color='red'><b>,</b></font> നല്ലപോലെ കാറ്റു കിട്ടുന്ന<font color='red'><b>,</b></font> വളരെ ഉയരത്തിലുള്ള<font color='red'><b>,</b></font> ലാഘവമുള്ള<font color='red'><b>,</b></font> ലോലഹൃദയമുള്ള<font color='red'><b>,</b></font> ഭൗതികമല്ലാത്ത<font color='red'><b>,</b></font> കാര്യഗൗരവമല്ലാത്ത<font color='red'><b>,</b></font> വായുസഞ്ചാരമുള്ള
#
# alacrity: ജാഗ്രത<font color='red'><b>,</b></font> ശീഘ്രത്വം<font color='red'><b>,</b></font> ചുറുചുറുപ്പ്<font color='red'><b>,</b></font> ഉത്സാഹം<font color='red'><b>,</b></font> ചുറുചുറുക്ക്‌<font color='red'><b>,</b></font> പൂര്‍ണസന്നദ്ധത<font color='red'><b>,</b></font> ചൊടി<font color='red'><b>,</b></font> പൂര്‍ണ്ണസന്നദ്ധത
#
# alarm: അസ്വസ്ഥത<font color='red'><b>,</b></font> അമ്പരപ്പ്‌<font color='red'><b>,</b></font> ഞെട്ടല്‍<font color='red'><b>,</b></font> പരിഭ്രമം<font color='red'><b>,</b></font> ആപത്സൂചകധ്വനി<font color='red'><b>,</b></font> ആപദ്‌ഭയം<font color='red'><b>,</b></font> ആര്‍ത്തനാദം<font color='red'><b>,</b></font> ഉറക്കമുണര്‍ത്തുന്ന മണിയൊച്ച<font color='red'><b>,</b></font> അലാറം<font color='red'><b>,</b></font> ഉദ്വേഗം<font color='red'><b>,</b></font> ആപല്‍ സൂചന<font color='red'><b>,</b></font> ആപത്തറിയിക്കുന്ന മണിനാദം<font color='red'><b>,</b></font> ഭയാക്രോശം<font color='red'><b>,</b></font> ഭയപ്പെടുത്തുക<font color='red'><b>,</b></font> ഒരുങ്ങിക്കൊള്ളാന്‍ അറിയിക്കുക
#
# alarmed: ഭയന്ന<font color='red'><b>,</b></font> ശ്രദ്ധയുള്ള<font color='red'><b>,</b></font> ജാഗ്രതയുള്ള<font color='red'><b>,</b></font> ഭയാര്‍ത്തമായ<font color='red'><b>,</b></font> ഭീതമായ<font color='red'><b>,</b></font> ഭയപ്പെടുത്തുന്ന മട്ടിലുള്ള<font color='red'><b>,</b></font> പരിഭ്രമിപ്പിക്കത്തക്ക<font color='red'><b>,</b></font> ഉള്‍പ്പേടിപൂണ്ട
#
# alarming: ഭയങ്കരമായ<font color='red'><b>,</b></font> ഭയജനകമായ<font color='red'><b>,</b></font> പരിഭ്രമിപ്പിക്കുന്ന<font color='red'><b>,</b></font> ഭയപ്പെടുത്തുന്ന
#
# alert: ശ്രദ്ധയുള്ള<font color='red'><b>,</b></font> അവധാനപൂര്‍വ്വമായ<font color='red'><b>,</b></font> ഉത്സാഹമുള്ള<font color='red'><b>,</b></font> ജാഗ്രതയുള്ള<font color='red'><b>,</b></font> ജാഗരൂകനായ<font color='red'><b>,</b></font> ഊര്‍ജ്ജസ്വലതയുള്ള<font color='red'><b>,</b></font> കരുതലുള്ള
#
# alien: വിഭിന്നമായ<font color='red'><b>,</b></font> വിദേശി<font color='red'><b>,</b></font> സ്വഭാവവിരുദ്ധമായ<font color='red'><b>,</b></font> അന്യദേശി<font color='red'><b>,</b></font> പുറനാട്ടുകാരന്‍<font color='red'><b>,</b></font> പരദേശി<font color='red'><b>,</b></font> അന്യരാജ്യത്തു നിന്നു വന്ന<font color='red'><b>,</b></font> ഇതരമായ<font color='red'><b>,</b></font> ഭിന്നമായ<font color='red'><b>,</b></font> വിദേശീയമായ<font color='red'><b>,</b></font> അന്യമായ<font color='red'><b>,</b></font> പൊരുത്തമില്ലാത്ത<font color='red'><b>,</b></font> ജുഗുപ്‌സയുണര്‍ത്തുന്ന<font color='red'><b>,</b></font> അന്യരാജ്യത്തുനിന്നുവന്ന<font color='red'><b>,</b></font> വൈദേശികപൗരത്വമുള്ള<font color='red'><b>,</b></font> സ്വഭാവസാമ്യമില്ലാത്ത<font color='red'><b>,</b></font> വിരുദ്ധ പ്രകൃതിയായ തന്റേതല്ലാത്ത<font color='red'><b>,</b></font> അപരിചിതമായ<font color='red'><b>,</b></font> പരദേശത്തുള്ള<font color='red'><b>,</b></font> അന്യഗ്രഹത്തിലുള്ള
#
# alive: ജീവനുള്ള<font color='red'><b>,</b></font> ചൊടിയുള്ള<font color='red'><b>,</b></font> പ്രയത്നിക്കുന്ന<font color='red'><b>,</b></font> സചേതനമായ<font color='red'><b>,</b></font> അറിവുള്ള<font color='red'><b>,</b></font> ഉത്സാഹമുള്ള<font color='red'><b>,</b></font> ജീവനുള്ള<font color='red'><b>,</b></font> ജാഗ്രതയുള്ള<font color='red'><b>,</b></font> സജീവമായ<font color='red'><b>,</b></font> ജീവിച്ചിരിക്കുന്ന<font color='red'><b>,</b></font> ചുറുചുറുക്കുള്ള<font color='red'><b>,</b></font> ബോധവാനായ<font color='red'><b>,</b></font> ജീവനോടുകൂടിയ<font color='red'><b>,</b></font> ബോധവാനായ<font color='red'><b>,</b></font> ജീവനോടുകൂടിയ
#
# all: പൂര്‍ണ്ണമായും<font color='red'><b>,</b></font> ആകപ്പാടെ<font color='red'><b>,</b></font> ഒക്കെ<font color='red'><b>,</b></font> സര്‍വം<font color='red'><b>,</b></font> സര്‍വ്വം<font color='red'><b>,</b></font> എന്തെങ്കിലും<font color='red'><b>,</b></font> സമസ്‌തം<font color='red'><b>,</b></font> എപ്പോഴും<font color='red'><b>,</b></font> മുഴുവന്‍<font color='red'><b>,</b></font> വളരെ<font color='red'><b>,</b></font> എല്ലാവരും<font color='red'><b>,</b></font> വീതം (കളിയിലെ സ്‌കോര്‍)<font color='red'><b>,</b></font> നിശ്ശേഷമായ<font color='red'><b>,</b></font> എല്ലാ<font color='red'><b>,</b></font> അഖില<font color='red'><b>,</b></font> സകല<font color='red'><b>,</b></font> തികച്ചും<font color='red'><b>,</b></font> പൂര്‍ണ്ണമായി<font color='red'><b>,</b></font> സമസ്തം<font color='red'><b>,</b></font> എല്ലാം<font color='red'><b>,</b></font> ആകെ
#
# all-
#
# alleged: ആരോപിതമായ<font color='red'><b>,</b></font> ആരോപിക്കപ്പെട്ട<font color='red'><b>,</b></font> ആരോപിക്കപ്പെട്ട
#
# allegiance: കര്‍ത്തവ്യം<font color='red'><b>,</b></font> രാജഭക്തി<font color='red'><b>,</b></font> സ്വാമിഭക്തി<font color='red'><b>,</b></font> ഗവണ്‍മെന്റിനോടോ രാജാവിനോടോ ഉള്ള കൂര്‍<font color='red'><b>,</b></font> കൂറ്‌<font color='red'><b>,</b></font> യജമാനനോടുള്ള കൂറ്‌<font color='red'><b>,</b></font> കൂറ്<font color='red'><b>,</b></font> ഭക്തിബന്ധം<font color='red'><b>,</b></font> യജമാനനോടുള്ള കൂറ്
#
# allegorical: ദൃഷ്‌ടാന്തരൂപമായ<font color='red'><b>,</b></font> രൂപകത്തിലുള്ള<font color='red'><b>,</b></font> അന്തരാര്‍ത്ഥമുള്ള
#
# alliance: ചങ്ങാത്തം<font color='red'><b>,</b></font> സഹകരണം<font color='red'><b>,</b></font> സഖ്യം<font color='red'><b>,</b></font> ദേശങ്ങള്‍ തമ്മിലുള്ള സഖ്യ ഉടമ്പടി<font color='red'><b>,</b></font> ബാന്ധവം<font color='red'><b>,</b></font> വിവാഹം വഴിയുള്ള ബന്ധം<font color='red'><b>,</b></font> മൈത്രി<font color='red'><b>,</b></font> സംബന്ധം<font color='red'><b>,</b></font> വിവാഹബന്ധം<font color='red'><b>,</b></font> രാജ്യസഖ്യം
#
# allied: അനുബന്ധ വസ്‌തുക്കള്‍<font color='red'><b>,</b></font> അതോടനുബന്ധിച്ചത്‌<font color='red'><b>,</b></font> ബന്ധപ്പെട്ട<font color='red'><b>,</b></font> സമാനമായ<font color='red'><b>,</b></font> സജാതീയമായ<font color='red'><b>,</b></font> ഏകീകരിക്കപ്പെട്ട<font color='red'><b>,</b></font> ഉടമ്പടിമൂലം സഖ്യം ചെയ്‌ത<font color='red'><b>,</b></font> സഖ്യമുള്ള<font color='red'><b>,</b></font> ഉടന്പടിമൂലം സഖ്യം ചെയ്ത
#
# alliteration: ശബ്‌ധാവര്‍ത്തനം<font color='red'><b>,</b></font> അനുപ്രാസം<font color='red'><b>,</b></font> ശബ്‌ദാവര്‍ത്തനം<font color='red'><b>,</b></font> ശബ്ദാവര്‍ത്തനം
#
# allowable: അവന്‍സ്‌<font color='red'><b>,</b></font> ജീവനാംശം<font color='red'><b>,</b></font> ബത്ത<font color='red'><b>,</b></font> അനുവദനീയമായ<font color='red'><b>,</b></font> സമ്മതിക്കത്തക്ക<font color='red'><b>,</b></font> നിരോധിക്കപ്പെടാത്ത<font color='red'><b>,</b></font> നിരോധിക്കപ്പെടാത്ത
#
# allowance: കമ്മി<font color='red'><b>,</b></font> കിഴിവ്‌<font color='red'><b>,</b></font> ജീവനാംശം<font color='red'><b>,</b></font> വേതനം<font color='red'><b>,</b></font> അനുവാദം<font color='red'><b>,</b></font> ബത്ത<font color='red'><b>,</b></font> അലവന്‍സ്‌<font color='red'><b>,</b></font> അലവന്‍സ്<font color='red'><b>,</b></font> വിട്ടുവീഴ്ച്ച
#
# allurement: വശീകരണം<font color='red'><b>,</b></font> വശീകരിക്കല്‍
#
# alluring: ആകര്‍ഷകമായ<font color='red'><b>,</b></font> മോഹിപ്പിക്കുന്ന<font color='red'><b>,</b></font> വശീകരിക്കുന്ന<font color='red'><b>,</b></font> വശ്യമായ<font color='red'><b>,</b></font> വശീകരണ ശക്തിയുള്ള<font color='red'><b>,</b></font> പ്രലോഭനപരമായ<font color='red'><b>,</b></font> ആകര്‍ഷണ ശക്തിയുള്ള
#
# allusion: സൂചന<font color='red'><b>,</b></font> ഉദാഹരണം<font color='red'><b>,</b></font> പ്രസ്‌താവം
#
# <font color='red'><b>,</b></font> സൂചിത കഥ<font color='red'><b>,</b></font> പരാമര്‍ശം<font color='red'><b>,</b></font> പരോക്ഷസൂചന<font color='red'><b>,</b></font> ഒരു ആളിനെയോ  ഒരു  സംഭവത്തെയോ മാത്രമായി പരാമർശിക്കുന്ന രീതിയിലുള്ള  വ്യാഖ്യാനം
#
# alone: ഏകാന്തമായ<font color='red'><b>,</b></font> പ്രത്യേകമായ<font color='red'><b>,</b></font> ഒറ്റയായ<font color='red'><b>,</b></font> ഏകാകിയായ<font color='red'><b>,</b></font> മാത്രമായ<font color='red'><b>,</b></font> ഒറ്റയ്ക്കിരിക്കുന്ന<font color='red'><b>,</b></font> വേറിട്ട്‌<font color='red'><b>,</b></font> പ്രത്യേകമായി<font color='red'><b>,</b></font> തനിയെ<font color='red'><b>,</b></font> മാത്രമായി
#
# aloofness: അകല്‍ച്ച<font color='red'><b>,</b></font> അകന്നുള്ള നില<font color='red'><b>,</b></font> താല്‍പര്യമില്ലാത്ത<font color='red'><b>,</b></font> സഹതാപമില്ലാത്ത<font color='red'><b>,</b></font> അകന്നുള്ള
#
# altogether: എല്ലാം<font color='red'><b>,</b></font> ആകപ്പാടെ<font color='red'><b>,</b></font> സാകല്യേന<font color='red'><b>,</b></font> ഒട്ടുക്ക്‌<font color='red'><b>,</b></font> ഉയര്‍ച്ച<font color='red'><b>,</b></font> പൂര്‍ണ്ണമായി<font color='red'><b>,</b></font> ശ്രേഷ്ഠത<font color='red'><b>,</b></font> ഒട്ടൊഴിയാതെ<font color='red'><b>,</b></font> എല്ലാം<font color='red'><b>,</b></font> പൂര്‍ണ്ണമായി<font color='red'><b>,</b></font> ആകപ്പാടെ<font color='red'><b>,</b></font> ആകെ<font color='red'><b>,</b></font> മൊത്തത്തില്‍ എല്ലാംകൂടി<font color='red'><b>,</b></font> എല്ലാം കൂടി<font color='red'><b>,</b></font> മൊത്തത്തില്‍ എല്ലാംകൂടി<font color='red'><b>,</b></font> ആകെ<font color='red'><b>,</b></font> മൊത്തത്തില്‍
#
# altruistic: പരോപകാരതല്‍പരനായ<font color='red'><b>,</b></font> നിസ്വാര്‍ത്ഥനായ<font color='red'><b>,</b></font> പരോപകാരിയായ<font color='red'><b>,</b></font> പരക്ഷേമകാംക്ഷയുള്ള<font color='red'><b>,</b></font> പരോപകാരിയായ
#
# amass: കൂന്പാരമാക്കുക<font color='red'><b>,</b></font> ശേഖരിക്കുക<font color='red'><b>,</b></font> സംഭരിക്കുക<font color='red'><b>,</b></font> ഏകീകരിക്കുക<font color='red'><b>,</b></font> ചേര്‍ത്തുവയ്‌ക്കുക<font color='red'><b>,</b></font> ഒന്നിച്ചു കൂട്ടുക<font color='red'><b>,</b></font> വാരിക്കൂട്ടുക<font color='red'><b>,</b></font> സമ്പാദിച്ചു കൂട്ടുക<font color='red'><b>,</b></font> സന്പാദിച്ചു കൂട്ടുക
#
# amatory: അദ്‌ഭുതസ്‌തബ്‌ധനാക്കുക<font color='red'><b>,</b></font> ആശ്ചര്യപ്പെടുത്തുക
#
# amaze: വിസ്‌മയം<font color='red'><b>,</b></font> കുഴക്കുക<font color='red'><b>,</b></font> ഭ്രമിപ്പിക്കുക<font color='red'><b>,</b></font> അമ്പരപ്പിക്കുക<font color='red'><b>,</b></font> ആശ്ചര്യപ്പെടുത്തുക<font color='red'><b>,</b></font> വിസ്‌മയിപ്പിക്കുക<font color='red'><b>,</b></font> അന്ധാളിക്കുക<font color='red'><b>,</b></font> ആശ്ചര്യം ജനിപ്പിക്കുക<font color='red'><b>,</b></font> ചകിതനാവുക<font color='red'><b>,</b></font> ആശ്ചര്യഭരിതമാവുക<font color='red'><b>,</b></font> അതിശയിപ്പിക്കുക
#
# amazed: അമ്പരന്ന<font color='red'><b>,</b></font> അതിശയിപ്പിക്കുന്ന
#
# amazement: അത്ഭുതം<font color='red'><b>,</b></font> വിസ്‌മയം<font color='red'><b>,</b></font> വിനോദം<font color='red'><b>,</b></font> അമ്പരപ്പ്‌<font color='red'><b>,</b></font> ആശ്ചര്യം<font color='red'><b>,</b></font> കളിതമാശ<font color='red'><b>,</b></font> അത്ഭുതപാരവശ്യം
#
# amazing: വിചിത്രമായ<font color='red'><b>,</b></font> അത്ഭുതകരമായ<font color='red'><b>,</b></font> ആശ്ചര്യജനകമായ<font color='red'><b>,</b></font> ആശ്ചര്യപ്പെടുത്തുന്ന
#
# ambidextrous: രണ്ടു കൈയും ഒരുപോലെ സ്വാധീനമുള്ള<font color='red'><b>,</b></font> സവ്യസാചിത്വമുള്ള
#
# ambiguity: സംശയം<font color='red'><b>,</b></font> ഉഭയാര്‍ത്ഥം<font color='red'><b>,</b></font> അനിശ്ചിതാര്‍ത്ഥം<font color='red'><b>,</b></font> സന്ദിഗ്‌ദ്ധാര്‍ത്ഥത<font color='red'><b>,</b></font> അവ്യക്തത<font color='red'><b>,</b></font> അസ്‌പഷ്‌ടത<font color='red'><b>,</b></font> ശ്ലേഷം<font color='red'><b>,</b></font> അനേകാര്‍ഥം<font color='red'><b>,</b></font> വ്യക്തതയില്ലായ്‌മ<font color='red'><b>,</b></font> സംശയമുള്ള സ്വഭാവം<font color='red'><b>,</b></font> വ്യക്തതയില്ലായ്മ
#
# ambiguous: വക്രമായ<font color='red'><b>,</b></font> അര്‍ത്ഥം<font color='red'><b>,</b></font> രണ്ടുതരത്തില്‍ വ്യാഖ്യാനിക്കാന്‍ പഴുതുളള<font color='red'><b>,</b></font> അര്‍ത്ഥം<font color='red'><b>,</b></font> അവ്യക്തമായ<font color='red'><b>,</b></font> ദ്വയാര്‍ത്ഥമുള്ള<font color='red'><b>,</b></font> സന്ദിഗ്‌ദ്ധാര്‍ഥമായ<font color='red'><b>,</b></font> രണ്ടര്‍ത്ഥമുള്ള<font color='red'><b>,</b></font> വ്യക്തമല്ലാത്ത<font color='red'><b>,</b></font> അനേകാര്‍ഥമുള്ള<font color='red'><b>,</b></font> സംശയാര്‍ത്ഥമുള്ള<font color='red'><b>,</b></font> സംശയാത്മകമായ<font color='red'><b>,</b></font> ദ്വയാര്‍ഥമുള്ള<font color='red'><b>,</b></font> വ്യക്തമായി മനസിലാക്കാൻ പ്രയാസമുള്ള
#
# ambition: തീവ്രമായ ഉല്‍ക്കര്‍ഷേച്ഛ<font color='red'><b>,</b></font> അഭ്യൂദയേച്ഛ<font color='red'><b>,</b></font> ഉല്‍ക്കര്‍ഷേച്ഛ<font color='red'><b>,</b></font> അതിമോഹം<font color='red'><b>,</b></font> സ്ഥാനകാംക്ഷ<font color='red'><b>,</b></font> അഭിലാഷം<font color='red'><b>,</b></font> അത്യാശ<font color='red'><b>,</b></font> ഉല്‍ക്കര്‍ഷേച്ഛ<font color='red'><b>,</b></font> അഭീഷ്‌ടം<font color='red'><b>,</b></font> അഭീഷ്‌ട വസ്‌തു<font color='red'><b>,</b></font> അധികാരാസക്തി<font color='red'><b>,</b></font> അഭീഷ്ടം<font color='red'><b>,</b></font> അഭീഷ്ട വസ്തു
#
# ambitious: അതിമോഹമുള്ള<font color='red'><b>,</b></font> തീവ്ര ഉല്‍ക്കര്‍ഷച്ഛയുള്ള<font color='red'><b>,</b></font> ഉത്‌കര്‍ഷേച്ഛ നിറഞ്ഞ<font color='red'><b>,</b></font> തീവ്രമായ ഉത്‌കര്‍ഷേച്ഛയുള്ള<font color='red'><b>,</b></font> അതിമോഹമുള്ള<font color='red'><b>,</b></font> ഉത്കര്‍ഷേച്ഛ നിറഞ്ഞ<font color='red'><b>,</b></font> തീവ്രമായ ഉത്കര്‍ഷേച്ഛയുള്ള
#
# ambrosial: അസാധാരണമായ രുചിയും മണവുമുള്ള
#
# <font color='red'><b>,</b></font> നൈവേദ്യം
#
# amenities: രമ്യമായ കാഴ്‌ചകള്‍<font color='red'><b>,</b></font> സുഖസൗകര്യങ്ങള്‍<font color='red'><b>,</b></font> സുഖസാമഗ്രികള്‍<font color='red'><b>,</b></font> സൗകര്യങ്ങള്‍
#
# amiable: സൗമ്യമായ<font color='red'><b>,</b></font> മനോഹരമായ<font color='red'><b>,</b></font> സ്‌നേഹമുള്ള<font color='red'><b>,</b></font> മനസ്സിനിണങ്ങിയ<font color='red'><b>,</b></font> പ്രിയംകരമായ<font color='red'><b>,</b></font> സൗഹൃദ പൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> സൗഹൃദമുണര്‍ത്തുന്ന<font color='red'><b>,</b></font> സുശീലമായ<font color='red'><b>,</b></font> സൗഹൃദഭാവമുള്ള<font color='red'><b>,</b></font> പ്രിയങ്കരമായ<font color='red'><b>,</b></font> രമ്യസ്വഭാവമുളള
#
# amicable: സൗഹാര്‍ദ്ദപരമായ<font color='red'><b>,</b></font> ഇണക്കമുളള<font color='red'><b>,</b></font> സൗമ്യമായ<font color='red'><b>,</b></font> അനുകൂലമായ<font color='red'><b>,</b></font> മിത്രഭാവമുള്ള<font color='red'><b>,</b></font> സൗഹൃദരീതിയില്‍ നിര്‍വഹിച്ച<font color='red'><b>,</b></font> ഹിതമുള്ള<font color='red'><b>,</b></font> സ്‌നേഹശീലമുള്ള<font color='red'><b>,</b></font> സ്നേഹശീലമുള്ള
#
# amity: ഐക്യം<font color='red'><b>,</b></font> സൗഹാര്‍ദ്ദം<font color='red'><b>,</b></font> സന്ധി<font color='red'><b>,</b></font> യോജിപ്പ്‌<font color='red'><b>,</b></font> ചങ്ങാത്തം<font color='red'><b>,</b></font> സഖ്യം<font color='red'><b>,</b></font> മൈത്രി<font color='red'><b>,</b></font> സൗമനസ്യം<font color='red'><b>,</b></font> സൗഹാര്‍ദം<font color='red'><b>,</b></font> അനുകൂലത<font color='red'><b>,</b></font> സ്നേഹഭാവം
#
# amorous: സംഭോഗേച്ഛയുള്ള<font color='red'><b>,</b></font> കാമസക്തമായ<font color='red'><b>,</b></font> ശൃഗാര രസപ്രധാനമായ<font color='red'><b>,</b></font> പ്രമഭരിതമായ<font color='red'><b>,</b></font> പ്രമം സംബന്ധിച്ച<font color='red'><b>,</b></font> കാമാസക്തനായ<font color='red'><b>,</b></font> അനുരക്തമായ<font color='red'><b>,</b></font> പ്രേമശീലമുളള<font color='red'><b>,</b></font> ശൃംഗാരശീലമുളള<font color='red'><b>,</b></font> മോഹമുള്ള<font color='red'><b>,</b></font> പ്രേമഭരിതമായ<font color='red'><b>,</b></font> പ്രേമം സംബന്ധിച്ച
#
# ample: ധാരാളം<font color='red'><b>,</b></font> വിപുലം<font color='red'><b>,</b></font> വളരെ<font color='red'><b>,</b></font> യഥേഷ്‌ടം<font color='red'><b>,</b></font> പര്യാപ്‌തമായ<font color='red'><b>,</b></font> സമൃദ്ധമായ<font color='red'><b>,</b></font> ബഹുലമായ<font color='red'><b>,</b></font> വിസ്‌തൃതമായ<font color='red'><b>,</b></font> വിപുലമായ<font color='red'><b>,</b></font> മതിയാവോളമുള്ള<font color='red'><b>,</b></font> വളരെയധികം<font color='red'><b>,</b></font> യഥേഷ്ടം<font color='red'><b>,</b></font> പര്യാപ്തമായ<font color='red'><b>,</b></font> വിസ്തൃതമായ<font color='red'><b>,</b></font> വളരെയധികം<font color='red'><b>,</b></font> യഥേഷ്ടം
#
# amplitude: വിസ്‌തൃതി<font color='red'><b>,</b></font> സമൃദ്ധി<font color='red'><b>,</b></font> ബാഹുല്യം<font color='red'><b>,</b></font> പ്രതാപം<font color='red'><b>,</b></font> വിശാലത<font color='red'><b>,</b></font> വിസ്‌താരം<font color='red'><b>,</b></font> വിസ്‌തീര്‍ണ്ണത<font color='red'><b>,</b></font> ആയാമം
#
# amused: സന്തോഷഭരിതനായ<font color='red'><b>,</b></font> സന്തോഷപൂര്‍വ്വമായ<font color='red'><b>,</b></font> സന്തോഷഭരിതനായ<font color='red'><b>,</b></font> സന്തോഷപൂര്‍വ്വമായ
#
# amusement: കേളി<font color='red'><b>,</b></font> വിനോദം<font color='red'><b>,</b></font> തമാശ<font color='red'><b>,</b></font> നേരംപോക്ക്‌<font color='red'><b>,</b></font> പ്രസന്നത<font color='red'><b>,</b></font> ഉല്ലാസം<font color='red'><b>,</b></font> കളിതമാശ<font color='red'><b>,</b></font> നേരംപോക്ക്<font color='red'><b>,</b></font> വിനോദം
#
# amusing: രസകരമായ<font color='red'><b>,</b></font> ആനന്ദകരമായ<font color='red'><b>,</b></font> ആനന്ദിപ്പിക്കുന്ന<font color='red'><b>,</b></font> ആഹ്ലാദിപ്പിക്കുന്ന<font color='red'><b>,</b></font> ഉല്ലാസം നല്‍കുന്ന<font color='red'><b>,</b></font> രസിപ്പിക്കുന്ന<font color='red'><b>,</b></font> ഉല്ലസിപ്പിക്കുന്ന
#
# analogous: സമാനമായ<font color='red'><b>,</b></font> തുല്യമായ<font color='red'><b>,</b></font> സംബന്ധമുള്ള<font color='red'><b>,</b></font> സമാന്തരസാദൃശ്യം പ്രകടമാക്കുന്ന<font color='red'><b>,</b></font> സമധര്‍മ്മമായ
#
# anarchy: അരാജകത്വം<font color='red'><b>,</b></font> അനായകത്വം<font color='red'><b>,</b></font> രാഷ്‌ട്രീയക്കുഴപ്പം<font color='red'><b>,</b></font> ക്രമസമാധാന ലംഘനം<font color='red'><b>,</b></font> ആഭ്യന്തരകലഹം<font color='red'><b>,</b></font> അനാഥസ്ഥിതി<font color='red'><b>,</b></font> ഭരണമില്ലാത്ത സ്ഥിതി<font color='red'><b>,</b></font> രാഷ്ട്രീയ കുഴപ്പം
#
# ancestors: പൂര്‍വ്വികര്‍<font color='red'><b>,</b></font> പരേതാത്മാവ്‌<font color='red'><b>,</b></font> പൂര്‍വ്വസൂരികള്‍<font color='red'><b>,</b></font> പൂര്‍വ്വപിതാമഹന്മാര്‍
#
# ancestral: പൂര്‍വ്വികരില്‍നിന്നു പരമ്പരയാ സിദ്ധിച്ചിട്ടുള്ള<font color='red'><b>,</b></font> പൈതൃകമായ<font color='red'><b>,</b></font> പൂര്‍വ്വികമായ<font color='red'><b>,</b></font> വംശവഴിയായ
#
# anchorage: ആശ്രമം<font color='red'><b>,</b></font> ഏകാന്തസ്ഥലം<font color='red'><b>,</b></font> നങ്കൂരമടിച്ചു കിടക്കല്‍<font color='red'><b>,</b></font> നങ്കൂരമിടുന്ന സ്ഥലം<font color='red'><b>,</b></font> കപ്പല്‍ നില്‌ക്കുന്ന സ്ഥലം<font color='red'><b>,</b></font> നൗകാബന്ധനം<font color='red'><b>,</b></font> നങ്കൂരപ്പണം<font color='red'><b>,</b></font> കപ്പല്‍ നില്ക്കുന്ന സ്ഥലം
#
# ancient: പഴക്കംചെന്ന<font color='red'><b>,</b></font> പഴക്കംചെന്ന<font color='red'><b>,</b></font> വന്ദനീയമായ<font color='red'><b>,</b></font> പുരാതനമായ<font color='red'><b>,</b></font> പ്രാചീനമായ<font color='red'><b>,</b></font> പഴയ രീതിയിലുള്ള<font color='red'><b>,</b></font> പഴയ<font color='red'><b>,</b></font> പൗരാണികമായ<font color='red'><b>,</b></font> പുരാണമായ
#
# and: അങ്ങനെയാണെങ്കില്‍<font color='red'><b>,</b></font>  ആൽ <font color='red'><b>,</b></font> എന്നുമാത്രമല്ല<font color='red'><b>,</b></font> എന്നു മാത്രമല്ല<font color='red'><b>,</b></font> അനന്തരം<font color='red'><b>,</b></font> രണ്ടുപദങ്ങളെ അല്ലെങ്കില്‍വാക്കുകളെ കൂട്ടിയോജിപ്പിക്കാന്‍ ഉപയോഗിക്കുന്ന പദം അഥവാ വാക്ക്‌<font color='red'><b>,</b></font> മറ്റും<font color='red'><b>,</b></font> കൂടെ<font color='red'><b>,</b></font> അങ്ങനെ<font color='red'><b>,</b></font> അതും<font color='red'><b>,</b></font> മേലും<font color='red'><b>,</b></font> പിന്നെ<font color='red'><b>,</b></font> ഉം
#
# anecdote: ചെറുകഥ<font color='red'><b>,</b></font> കെട്ടുകഥ<font color='red'><b>,</b></font> ഉപാഖ്യാനം<font color='red'><b>,</b></font> ഫലിതം<font color='red'><b>,</b></font> രസകരമായ സംഭവകഥ<font color='red'><b>,</b></font> ആഖ്യാനം<font color='red'><b>,</b></font> സംഭവചരിത്രം
#
# angelic: പരിശുദ്ധമായ<font color='red'><b>,</b></font> ദിവ്യമായ<font color='red'><b>,</b></font> ദൈവികമായ<font color='red'><b>,</b></font> വിശുദ്ധമായ<font color='red'><b>,</b></font> ദൈവീകമായ<font color='red'><b>,</b></font> മാലാഖയെപ്പോലുള്ള<font color='red'><b>,</b></font> മാലാഖയെപ്പോലെയുള്ള<font color='red'><b>,</b></font> ദേവദൂതപരമായ<font color='red'><b>,</b></font> മാലാഖയെപ്പോലെയുള്ള
#
# anger: കോപം<font color='red'><b>,</b></font> രോഷം<font color='red'><b>,</b></font> അമര്‍ഷം<font color='red'><b>,</b></font> ദേഷ്യം<font color='red'><b>,</b></font> അമര്‍ഷാവേശം<font color='red'><b>,</b></font> കോപം<font color='red'><b>,</b></font> കുപിതനാക്കുക<font color='red'><b>,</b></font> ക്ഷുബ്‌ധനാക്കുക<font color='red'><b>,</b></font> കോപിപ്പിക്കുക<font color='red'><b>,</b></font> ശുണ്‌ഠി പിടിപ്പിക്കുക<font color='red'><b>,</b></font> ക്രാധിപ്പിക്കുക<font color='red'><b>,</b></font> രോഷം
#
# angry: കുപിതനായ<font color='red'><b>,</b></font> കോപം കാണിക്കുന്ന<font color='red'><b>,</b></font> അങ്ങേയറ്റം നീരസപ്പെട്ട<font color='red'><b>,</b></font> ഇളകിമറിഞ്ഞ<font color='red'><b>,</b></font> നീരു നിറഞ്ഞ<font color='red'><b>,</b></font> ചുവന്നു തുടുത്ത<font color='red'><b>,</b></font> ക്രുദ്ധമായ<font color='red'><b>,</b></font> രോഷാകുലമായ<font color='red'><b>,</b></font> രോഷാകുലനായ
#
# anguish: മനഃപീഡ<font color='red'><b>,</b></font> ശാരീരിക വേദന<font color='red'><b>,</b></font> തീവ്രവേദന<font color='red'><b>,</b></font> അതിവേദന<font color='red'><b>,</b></font> തീവ്രമായ മാനസിക വേദന<font color='red'><b>,</b></font> കഠിനവേദന
#
# anguished: മനോവേദന നിറഞ്ഞ<font color='red'><b>,</b></font> മനോവേദന നിറഞ്ഞ
#
# angular: മെലിഞ്ഞ<font color='red'><b>,</b></font> കോണുകളുള്ള<font color='red'><b>,</b></font> മാര്‍ദ്ധവംകുറഞ്ഞ<font color='red'><b>,</b></font> മുനയുള്ള<font color='red'><b>,</b></font> നയരഹിതമായ<font color='red'><b>,</b></font> പരുഷസ്വഭാവമുള്ള<font color='red'><b>,</b></font> കോണുകളെ സംബന്ധിച്ച<font color='red'><b>,</b></font> കോണുകളെ സംബന്ധിച്ച<font color='red'><b>,</b></font> കോണുകളുള്ള
#
# animate: ജീവനുള്ള<font color='red'><b>,</b></font> ജീവിപ്പിക്കുക<font color='red'><b>,</b></font> ചൈതന്യം നല്‍കുക<font color='red'><b>,</b></font> ജീവന്‍ നല്‍കുക<font color='red'><b>,</b></font> സചേതനമായ<font color='red'><b>,</b></font> ഉത്സാഹിപ്പിക്കുക<font color='red'><b>,</b></font> കാര്‍ട്ടൂണ്‍ ചിത്രങ്ങളിലെ കഥാപാത്രങ്ങളെ ചലിപ്പിക്കുക
#
# animated: ജീവനുള്ള<font color='red'><b>,</b></font> സജീവമായ<font color='red'><b>,</b></font> ചൂടുപിടിച്ച<font color='red'><b>,</b></font> സചേതനയുള്ള<font color='red'><b>,</b></font> ആവേശപൂര്‍ണ്ണമായ
#
# animation: ചൈതന്യം<font color='red'><b>,</b></font> ഉന്മേഷം<font color='red'><b>,</b></font> ജീവസഞ്ചരണം<font color='red'><b>,</b></font> ജീവചൈതന്യം<font color='red'><b>,</b></font> ഉണര്‍ച്ച<font color='red'><b>,</b></font> ജീവന്‍ നല്‍കല്‍<font color='red'><b>,</b></font> ചലനശേഷി
#
# animosity: വിരോധം<font color='red'><b>,</b></font> തീരാപ്പക<font color='red'><b>,</b></font> വിദ്വേഷം<font color='red'><b>,</b></font> ബദ്ധവൈരം<font color='red'><b>,</b></font> കഠിനവിദ്വോഷം<font color='red'><b>,</b></font> വൈരഭാവം<font color='red'><b>,</b></font> ഉഗ്രവൈരം<font color='red'><b>,</b></font> അതിവിരോധം<font color='red'><b>,</b></font> കഠിനവിദ്വേഷം<font color='red'><b>,</b></font> അതിവിരോധം
#
# annoyance: ഉപദ്രവഹേദു<font color='red'><b>,</b></font> പൊറുതികേട്‌<font color='red'><b>,</b></font> ക്ലേശം<font color='red'><b>,</b></font> ശല്യം<font color='red'><b>,</b></font> ഉപദ്രവം<font color='red'><b>,</b></font> ബാധ<font color='red'><b>,</b></font> അസഹ്യത<font color='red'><b>,</b></font> സ്വൈര്യക്കേട്‌<font color='red'><b>,</b></font> മുഷിച്ചില്‍<font color='red'><b>,</b></font> ക്ലേശിപ്പിക്കുന്ന കാര്യം<font color='red'><b>,</b></font> ശല്യപ്പെടുത്തല്‍<font color='red'><b>,</b></font> മുഷിപ്പിക്കല്‍<font color='red'><b>,</b></font> ബുദ്ധിമുട്ട്<font color='red'><b>,</b></font> സ്വൈരക്കേട്
#
# annoying: അസഹ്യമായ<font color='red'><b>,</b></font> ശല്യപ്പെടുത്തുന്ന<font color='red'><b>,</b></font> അലട്ടുന്ന<font color='red'><b>,</b></font> അലോസരപ്പെടുത്തുന്ന<font color='red'><b>,</b></font> സ്വൈര്യക്കേടുളവാക്കുന്ന
#
# annul: വ്യര്‍ത്ഥമാക്കുക<font color='red'><b>,</b></font> അസാധുവാക്കുക<font color='red'><b>,</b></font> റദ്ദാക്കുക<font color='red'><b>,</b></font> ഇല്ലായമചെയ്യുക<font color='red'><b>,</b></font> റദ്ധാക്കുക<font color='red'><b>,</b></font> പിന്‍വലിക്കുക<font color='red'><b>,</b></font> വൃര്‍ത്ഥമാക്കുക<font color='red'><b>,</b></font> ഇല്ലായ്മ ചെയ്യുക
#
# anomalous: അസാധാരണമായ<font color='red'><b>,</b></font> ക്രമവിരുദ്ധമായ<font color='red'><b>,</b></font> അനുചിതമായ<font color='red'><b>,</b></font> നിരക്കാത്ത<font color='red'><b>,</b></font> സാധാരണമല്ലാത്ത
#
# anon: ഉടനെ<font color='red'><b>,</b></font> പെട്ടെന്ന്‌<font color='red'><b>,</b></font> വേഗത്തില്‍
#
# anonymous: പേരറിയാത്ത<font color='red'><b>,</b></font> അജ്ഞാതനാമകനായ<font color='red'><b>,</b></font> പേരുവയ്‌ക്കാത്ത<font color='red'><b>,</b></font> അജ്ഞാതനായ<font color='red'><b>,</b></font> നാമഹീനമായ
#
# answer: ഫലം<font color='red'><b>,</b></font> പരിഹാരം<font color='red'><b>,</b></font> പ്രത്യുത്തരം<font color='red'><b>,</b></font> മതിയായിരിക്കുക്‌<font color='red'><b>,</b></font> ഉത്തരം<font color='red'><b>,</b></font> സമാധാനം<font color='red'><b>,</b></font> ഉത്തരവാദം ചെയ്യുക<font color='red'><b>,</b></font> വാക്കിലൂടെയോ പ്രവൃത്തിയിലൂടെയോ മറുപടി പറയുക<font color='red'><b>,</b></font> സമാധാനം പറയുക<font color='red'><b>,</b></font> ഉത്തരം പറയുക<font color='red'><b>,</b></font> മറുപടി പറയുക<font color='red'><b>,</b></font> അനുസരിച്ചു പ്രവര്‍ത്തിക്കുക<font color='red'><b>,</b></font> തൃപ്‌തിയായിരിക്കുക<font color='red'><b>,</b></font> മറുപടി നല്‍കുക<font color='red'><b>,</b></font> മതിയാക്കുക
#
# answering: മറുപടിപറയല്‍
#
# antagonism: മത്സരം<font color='red'><b>,</b></font> വിരോധം<font color='red'><b>,</b></font> എതിര്‍പ്പ്‌<font color='red'><b>,</b></font> വിവാദം<font color='red'><b>,</b></font> പക<font color='red'><b>,</b></font> ശത്രുത<font color='red'><b>,</b></font> പ്രതികൂലത<font color='red'><b>,</b></font> ശത്രുത്വം<font color='red'><b>,</b></font> വിരോധം<font color='red'><b>,</b></font> എതിര്‍ത്തുനില്‌പ്‌<font color='red'><b>,</b></font> എതിര്‍ത്തുനില്പ്
#
# antagonist: മത്സരിക്കുന്നയാള്‍<font color='red'><b>,</b></font> വിരോധി<font color='red'><b>,</b></font> പ്രതിയോഗി<font color='red'><b>,</b></font> എതിരാളി<font color='red'><b>,</b></font> ശത്രു<font color='red'><b>,</b></font> പ്രതിയോഗി<font color='red'><b>,</b></font> എതിര്‍ചേരിക്കാരന്‍
#
# antagonistic: വൈരുദ്ധ്യമാര്‍ന്ന<font color='red'><b>,</b></font> പരസ്‌പരവിരുദ്ധമായ<font color='red'><b>,</b></font> എതിരായ<font color='red'><b>,</b></font> വിരുദ്ധമായ<font color='red'><b>,</b></font> ശത്രുതയോടുകൂടിയ<font color='red'><b>,</b></font> പ്രതിരോധകമായ<font color='red'><b>,</b></font> ശത്രുതയോടുകൂടിയ<font color='red'><b>,</b></font> പരസ്പരവിരുദ്ധമായ<font color='red'><b>,</b></font> പ്രതിരോധകമായ
#
# antecedent: പൂര്‍വ്വഗാമി<font color='red'><b>,</b></font> പൂര്‍വ്വവൃത്താന്തം<font color='red'><b>,</b></font> പൂര്‍വ്വവൃത്താന്തം<font color='red'><b>,</b></font> മുന്നില്‍ നില്‍ക്കുന്ന പദം<font color='red'><b>,</b></font> പൂര്‍വ്വികര്‍<font color='red'><b>,</b></font> കീഴ്‌നടപ്പ്‌<font color='red'><b>,</b></font> പൂര്‍വ്വകാല സംഭവം<font color='red'><b>,</b></font> പൂര്‍വ്വപദം<font color='red'><b>,</b></font> പൂര്‍വ്വകാല ചരിത്രം<font color='red'><b>,</b></font> മുന്‍ചരിത്രങ്ങള്‍<font color='red'><b>,</b></font> കീഴ്നടപ്പ്
#
# anticipative: മുന്‍കൂര്‍ ജാമ്യം
#
# antipathy: വിരോധം<font color='red'><b>,</b></font> വെറുപ്പ്‌<font color='red'><b>,</b></font> വിദ്വേഷം<font color='red'><b>,</b></font> വൈപരീത്യം<font color='red'><b>,</b></font> സഹജദ്വേഷം<font color='red'><b>,</b></font> വിരോധം<font color='red'><b>,</b></font> സഹജമായ വെറുപ്പ്<font color='red'><b>,</b></font> അനിഷ്ടം
#
# antiquated: പഴക്കംചെന്ന<font color='red'><b>,</b></font> പഴകിയ<font color='red'><b>,</b></font> പ്രചാരലുപ്തമായ<font color='red'><b>,</b></font> പഴക്കംചെന്ന<font color='red'><b>,</b></font> യാഥാസ്ഥിതികനായ<font color='red'><b>,</b></font> പ്രചാരലുപ്‌തനായ<font color='red'><b>,</b></font> പഴയരീതിയിലായിത്തീര്‍ന്ന<font color='red'><b>,</b></font> പ്രചാരലുപ്തനായ
#
# antiquity: പുരാതനത്വം<font color='red'><b>,</b></font> പൂര്‍വ്വികന്‍മാര്‍<font color='red'><b>,</b></font> പൗരാണികകാലം<font color='red'><b>,</b></font> പുരാതനകാലം
#
# antithesis: വിരോധം<font color='red'><b>,</b></font> വൈപരീത്യം<font color='red'><b>,</b></font> വിരോധാഭാസം<font color='red'><b>,</b></font> വിരുദ്ധാലങ്കാരം<font color='red'><b>,</b></font> എതിരായുള്ളത്‌<font color='red'><b>,</b></font> വിരുദ്ധമായ
#
# anxiety: വ്യാകുലത<font color='red'><b>,</b></font> ആകാംക്ഷ<font color='red'><b>,</b></font> ചിന്താകുലത<font color='red'><b>,</b></font> ഉത്‌ക്കണ്‌ഠ<font color='red'><b>,</b></font> മനഃസ്‌താപം<font color='red'><b>,</b></font> ആകുലത<font color='red'><b>,</b></font> ഉത്സുകത<font color='red'><b>,</b></font> ഉല്‍കണ്‌ഠ<font color='red'><b>,</b></font> ഉല്‍കണ്ഠ
#
# anxious: അതിയായി അഭിലഷിക്കുന്ന<font color='red'><b>,</b></font> ഉത്‌ക്കണ്‌ഠാജനകമായ<font color='red'><b>,</b></font> ഉദ്വേഗകരമായ<font color='red'><b>,</b></font> ചിന്താകുലനായ<font color='red'><b>,</b></font> ഉത്സുകമായ<font color='red'><b>,</b></font> വിചാരപ്പെടുന്ന<font color='red'><b>,</b></font> ഉത്കണ്ഠാപൂര്‍വ്വമായ<font color='red'><b>,</b></font> ചിന്താവിഷ്ടമായ
#
# apathetic: ഉദാസീനമായ<font color='red'><b>,</b></font> നിരുത്സാഹനായ<font color='red'><b>,</b></font> താല്പര്യമില്ലാത്ത
#
# apathy: ഭാവശൂന്യത<font color='red'><b>,</b></font> അനുകന്പയില്ലായ്മ<font color='red'><b>,</b></font> വികാരശൂന്യത<font color='red'><b>,</b></font> ഉന്മേഷക്കുറവ്<font color='red'><b>,</b></font> ഉദാസീനത<font color='red'><b>,</b></font> ജാഡ്യം<font color='red'><b>,</b></font> താല്‍പര്യമില്ലായ്‌മ<font color='red'><b>,</b></font> നിര്‍വ്വികാരത<font color='red'><b>,</b></font> താത്‌പര്യരാഹിത്യം<font color='red'><b>,</b></font> താല്പര്യമില്ലായ്മ
#
# apocalyptic: മഹാ ദുരന്തം വിതയ്ക്കുന്ന
#
# apocryphal: കെട്ടിച്ചമച്ച<font color='red'><b>,</b></font> അധികൃതമല്ലാത്ത
#
# apologetic: ക്ഷമാപണസ്വഭാവമുള്ള<font color='red'><b>,</b></font> തര്‍ക്കിച്ചു സാധൂകരിക്കുന്ന<font color='red'><b>,</b></font> മാപ്പപേക്ഷിക്കുന്ന<font color='red'><b>,</b></font> ക്ഷമാപണത്തോടെയുളള<font color='red'><b>,</b></font> ഖേദപൂര്‍വ്വമായ
#
# apology: ന്യായീകരണം<font color='red'><b>,</b></font> സമാധാനം<font color='red'><b>,</b></font> നിരപരാധിയെന്നു തെളിയിക്കല്‍<font color='red'><b>,</b></font> ക്ഷമാപണം<font color='red'><b>,</b></font> മാപ്പ്‌<font color='red'><b>,</b></font> മാപ്പു ചോദിക്കല്‍<font color='red'><b>,</b></font> സമര്‍ത്ഥനം
#
# appalled: ഭയന്ന<font color='red'><b>,</b></font> വിഹ്വലമായ
#
# appalling: ഭയാനകമായ<font color='red'><b>,</b></font> നടക്കുന്ന<font color='red'><b>,</b></font> അതിഭയാവഹമായ<font color='red'><b>,</b></font> ഭീകരമായ<font color='red'><b>,</b></font> വേദനാജനകമായ<font color='red'><b>,</b></font> ഞെട്ടിക്കുന്ന
#
# apparel: വസ്ത്രം<font color='red'><b>,</b></font> ഉടുപ്പ്‌<font color='red'><b>,</b></font> ചമയം<font color='red'><b>,</b></font> വേഷം<font color='red'><b>,</b></font> ഉടയാട<font color='red'><b>,</b></font> തുണിത്തരങ്ങള്‍<font color='red'><b>,</b></font> അണിയിക്കുക<font color='red'><b>,</b></font> അലങ്കരിക്കുക<font color='red'><b>,</b></font> ധരിപ്പിക്കുക
#
# apparent: വ്യക്തമായ<font color='red'><b>,</b></font> സ്‌പഷ്‌ടമായ<font color='red'><b>,</b></font> മിഥ്യയായ<font color='red'><b>,</b></font> പ്രത്യക്ഷമായ<font color='red'><b>,</b></font> പ്രകടമായ<font color='red'><b>,</b></font> കാണാവുന്ന<font color='red'><b>,</b></font> തോന്നുന്ന<font color='red'><b>,</b></font> ഗോചരമായ<font color='red'><b>,</b></font> മാത്രമായ<font color='red'><b>,</b></font> പുറമേ കാണുന്ന
#
# apparition: പ്രത്യക്ഷപ്പെടല്‍<font color='red'><b>,</b></font> ഒരു വ്യക്തിയുടെയോ സാധനത്തിന്‍റെയോ വ്യക്തമല്ലാത്ത കാഴ്ച<font color='red'><b>,</b></font> മറഞ്ഞതിനു ശേഷം വീണ്ടും പ്രത്യക്ഷമാകല്‍<font color='red'><b>,</b></font> തോന്നല്‍<font color='red'><b>,</b></font> തോന്നല്‍<font color='red'><b>,</b></font> ഭൂതം<font color='red'><b>,</b></font> മായാരൂപം<font color='red'><b>,</b></font> പ്രത്യക്ഷീകരണം<font color='red'><b>,</b></font> പ്രേതം<font color='red'><b>,</b></font> മായക്കാഴ്‌ച
#
# appeal: നിവേദനം<font color='red'><b>,</b></font> അപേക്ഷ<font color='red'><b>,</b></font> വശ്യത<font color='red'><b>,</b></font> അപ്പീല്‍<font color='red'><b>,</b></font> സഹായത്തിനുള്ള നിലവിളി<font color='red'><b>,</b></font> ദൈന്യതയാര്‍ന്ന അപേക്ഷ<font color='red'><b>,</b></font> ഗൗരവമായി അഭ്യര്‍ത്ഥിക്കുക<font color='red'><b>,</b></font> അപേക്ഷിക്കുക<font color='red'><b>,</b></font> അഭ്യര്‍ത്ഥിക്കുക<font color='red'><b>,</b></font> ആകര്‍ഷിക്കുക<font color='red'><b>,</b></font> പുന്‍വിചാരണ ആവശ്യപ്പെടുക<font color='red'><b>,</b></font> പുനര്‍വിചാരണ ആവശ്യപ്പെടുക<font color='red'><b>,</b></font> സഹായത്തിനും ദയയ്ക്കും അപേക്ഷിക്കുക<font color='red'><b>,</b></font> താഴ്മയായി ആവലാതി ബോധിപ്പിക്കുക<font color='red'><b>,</b></font> സങ്കടഹര്‍ജി
#
# appealing: ആകര്‍ഷകമായ<font color='red'><b>,</b></font> അഭ്യര്‍ത്ഥിക്കുന്ന<font color='red'><b>,</b></font> ഹൃദയസ്‌പര്‍ശിയായ<font color='red'><b>,</b></font> അഭ്യര്‍ത്ഥനാ രൂപത്തിലുള്ള
#
# appearance: ഉദയം<font color='red'><b>,</b></font> ഭാവം<font color='red'><b>,</b></font> ഉത്ഭവം<font color='red'><b>,</b></font> ആവിര്‍ഭാവം<font color='red'><b>,</b></font> കാഴ്‌ച<font color='red'><b>,</b></font> രൂപം<font color='red'><b>,</b></font> വേഷം<font color='red'><b>,</b></font> ആകാരം<font color='red'><b>,</b></font> ജനനം<font color='red'><b>,</b></font> പ്രസിദ്ധീകരണം<font color='red'><b>,</b></font> വെളിയില്‍ കാണുന്ന അവസ്ഥ<font color='red'><b>,</b></font> ഹാജരാകല്‍<font color='red'><b>,</b></font> പ്രത്യക്ഷപ്പെടല്‍<font color='red'><b>,</b></font> പ്രതിഭാസം<font color='red'><b>,</b></font> പ്രകടമാക്കല്‍<font color='red'><b>,</b></font> ബാഹ്യരൂപം<font color='red'><b>,</b></font> പുരംകാഴ്ച
#
# appellation: പദവി<font color='red'><b>,</b></font> അഭിധാനം<font color='red'><b>,</b></font> സംജ്ഞ<font color='red'><b>,</b></font> പേര്‌<font color='red'><b>,</b></font> ജാതിപ്പേര്‌<font color='red'><b>,</b></font> സ്ഥാനപ്പേര്‌
#
# applause: അനുമോദനം<font color='red'><b>,</b></font> പ്രശംസ
#
# <font color='red'><b>,</b></font> സ്‌തുതിഘോഷം<font color='red'><b>,</b></font> കരഘോഷം<font color='red'><b>,</b></font> ജയജയധ്വനി
#
# appointed: നിയോഗിച്ച്‌<font color='red'><b>,</b></font> നിയതമായ<font color='red'><b>,</b></font> നിയുക്തമായ<font color='red'><b>,</b></font> നിശ്ചയിച്ചതായ
#
# apposite: ഉചിതമായ<font color='red'><b>,</b></font> സമുചിതമായ<font color='red'><b>,</b></font> അനുയോജ്യമായ<font color='red'><b>,</b></font> സാന്ദര്‍ഭികമായ
#
# appraisement: മൂല്യനിര്‍ണ്ണയം<font color='red'><b>,</b></font> വില നിശ്ചയിക്കല്‍<font color='red'><b>,</b></font> വിലയിരുത്തല്‍
#
# appreciable: എടുത്തുപറയത്തക്കൃ<font color='red'><b>,</b></font> ഗണ്യമായ<font color='red'><b>,</b></font> അഭിനന്ദനീയമായ<font color='red'><b>,</b></font> എടുത്തു പറയത്തക്കതായ<font color='red'><b>,</b></font> ഗണനീയമായ<font color='red'><b>,</b></font> കാര്യമായ<font color='red'><b>,</b></font> സുഗ്രാഹ്യമായ
#
# appreciation: അഭിനന്ദനം<font color='red'><b>,</b></font> ബഹുമാനം<font color='red'><b>,</b></font> മൂല്യനിര്‍ണ്ണയം<font color='red'><b>,</b></font> ഗുണഗ്രഹണം<font color='red'><b>,</b></font> ആസ്വാദനം<font color='red'><b>,</b></font> വിലയേറ്റം<font color='red'><b>,</b></font> കൃതജ്ഞത<font color='red'><b>,</b></font> മൂല്യവൃദ്ധി<font color='red'><b>,</b></font> നന്ദിപൂര്‍വ്വമുള്ള അംഗീകാരം<font color='red'><b>,</b></font> വിലക്കയറ്റം<font color='red'><b>,</b></font> വിലമതിക്കല്‍<font color='red'><b>,</b></font> സാഹിത്യാസ്വാദനം
#
# appreciative: മനസ്സിനിണങ്ങിയ<font color='red'><b>,</b></font> സുഭഗമായ<font color='red'><b>,</b></font> കൃതജ്ഞതയുള്ള<font color='red'><b>,</b></font> അഭിനന്ദനാര്‍ഹമായ<font color='red'><b>,</b></font> ഗുണഗ്രാഹ്യമായ<font color='red'><b>,</b></font> ബഹുമാനപൂര്‍വ്വമായ
#
# apprehension: ധാരണ<font color='red'><b>,</b></font> ബന്ധനം<font color='red'><b>,</b></font> ഭയം<font color='red'><b>,</b></font> ആശങ്ക<font color='red'><b>,</b></font> പേടി<font color='red'><b>,</b></font> ഗ്രഹിക്കല്‍<font color='red'><b>,</b></font> നീത്യന്യായപ്രകാരം ഉളള ബന്ധനം<font color='red'><b>,</b></font> അറസ്റ്റ്<font color='red'><b>,</b></font> പൊതുജനാഭിപ്രായം<font color='red'><b>,</b></font> വാസ്തവമായി അംഗീകരിക്കല്‍
#
# apprehensive: ഭയപ്പെടുക<font color='red'><b>,</b></font> ഭയമുള്ള<font color='red'><b>,</b></font> ആശങ്കയുളള<font color='red'><b>,</b></font> എളുപ്പം ഗ്രഹിക്കുന്നത്<font color='red'><b>,</b></font> ബുദ്ധിയുളള<font color='red'><b>,</b></font> വിവേകബുദ്ധിയുള്ള<font color='red'><b>,</b></font> എളുപ്പം ഗ്രഹിക്കുന്ന<font color='red'><b>,</b></font> ആശങ്കമായ
#
# apprentice: മറ്റൊരാളുടെ കീഴില്‍ തൊഴില്‍ പരിശീലനം നടത്തുന്നവന്‍<font color='red'><b>,</b></font> വേലപഠിക്കുന്നവന്‍<font color='red'><b>,</b></font> തൊഴലഭ്യസിക്കുന്നവന്‍<font color='red'><b>,</b></font> അപ്രന്റിസ്‌ (തൊഴിലഭ്യസിക്കുന്നവന്‍)<font color='red'><b>,</b></font> അപ്രന്‍റിസ് (തൊഴിലഭ്യസിക്കുന്നവന്‍)<font color='red'><b>,</b></font> മറ്റൊരാളുടെ കീഴില്‍ തൊഴില്‍പരിശീലനം നടത്തുക<font color='red'><b>,</b></font> വേല പഠിക്കുന്നവന്‍<font color='red'><b>,</b></font> മറ്റൊരാളുടെ കീഴില്‍ തൊഴില്‍ പരിശീലനം നടത്തുന്നവന്‍
#
# approach: സമീപിക്കുക<font color='red'><b>,</b></font> എത്തുക<font color='red'><b>,</b></font> സാദൃശ്യം<font color='red'><b>,</b></font> പ്രവേശനം<font color='red'><b>,</b></font> ആസന്നത<font color='red'><b>,</b></font> ഇടവഴി<font color='red'><b>,</b></font> ആഗമനം<font color='red'><b>,</b></font> സാമിപ്യം<font color='red'><b>,</b></font> നടവഴി<font color='red'><b>,</b></font> ഔപചാരിക നിര്‍ദ്ദേശം<font color='red'><b>,</b></font> ജോലി ചെയ്യുന്ന രീതി<font color='red'><b>,</b></font> സമീപനം<font color='red'><b>,</b></font> ജോലി ചെയ്യുന്ന രീതി<font color='red'><b>,</b></font> സമീപിക്കുക<font color='red'><b>,</b></font> എത്തുക<font color='red'><b>,</b></font> അടുത്തുവരിക<font color='red'><b>,</b></font> ആസന്നമാക്കുക<font color='red'><b>,</b></font> അടുത്തു ചെല്ലുക<font color='red'><b>,</b></font> അഭിമുഖീകരിക്കുവാന്‍ തുടങ്ങുക<font color='red'><b>,</b></font> അടുത്തു വരിക<font color='red'><b>,</b></font> മറ്റൊരാളെ സമീപിക്കുക
#
# approbation: അനുവാദം<font color='red'><b>,</b></font> സാക്ഷ്യപ്പെടുത്തല്‍<font color='red'><b>,</b></font> അംഗീകരിക്കല്‍<font color='red'><b>,</b></font> അനുമോദനം<font color='red'><b>,</b></font> സമ്മതം<font color='red'><b>,</b></font> അനുമതി<font color='red'><b>,</b></font> സ്വീകരണം<font color='red'><b>,</b></font> പൂര്‍ണ്ണമായ അംഗീകരണം
#
# appropriate: വിനിയോഗിക്കുക<font color='red'><b>,</b></font> തട്ടിയെടുക്കുക<font color='red'><b>,</b></font> മാറ്റിവയ്‌ക്കുക<font color='red'><b>,</b></font> കയ്യടക്കുക<font color='red'><b>,</b></font> കൈവശപ്പെടുത്തുക<font color='red'><b>,</b></font> നീക്കി വയ്‌ക്കുക<font color='red'><b>,</b></font> സാഹചര്യത്തിനു യോജിച്ച<font color='red'><b>,</b></font> ഔചിത്യ പൂര്‍വ്വമായ<font color='red'><b>,</b></font> ഉചിതമായ<font color='red'><b>,</b></font> അനുഗുണമായ<font color='red'><b>,</b></font> സമുചിതമായ<font color='red'><b>,</b></font> സന്ദര്‍ഭോചിതമായ<font color='red'><b>,</b></font> ഔചിത്യപൂര്‍വ്വമായ<font color='red'><b>,</b></font> മുറപ്രകാരമുള്ള<font color='red'><b>,</b></font> ഉപയുക്തമായ<font color='red'><b>,</b></font> സന്ദര്‍ഭോചിതമായ
#
# approval: അനുമോദനം<font color='red'><b>,</b></font> അഭിനന്ദനം<font color='red'><b>,</b></font> സമ്മതം<font color='red'><b>,</b></font> അംഗീകാരം<font color='red'><b>,</b></font> അനുകരിക്കല്‍<font color='red'><b>,</b></font> അംഗീകരിക്കല്‍<font color='red'><b>,</b></font> അനുമതി നല്‍കല്‍
#
# approve: സ്ഥിരീകരിക്കുക<font color='red'><b>,</b></font> അഭിനന്ദിക്കുക<font color='red'><b>,</b></font> ഇഷ്‌ടപ്പെടുക<font color='red'><b>,</b></font> അനുവദിക്കുക<font color='red'><b>,</b></font> അംഗീകരിക്കുക<font color='red'><b>,</b></font> പ്രശംസിക്കുക<font color='red'><b>,</b></font> ശരിവയ്‌ക്കുക<font color='red'><b>,</b></font> അംഗീകാരം നല്കുക<font color='red'><b>,</b></font> അനുകൂലമായി ചിന്തിക്കുക
#
# approving: പ്രശംസാപരമായ
#
# approximately: ഏതാണ്ട്‌<font color='red'><b>,</b></font> ഉദ്ദേശം<font color='red'><b>,</b></font> ഏകദേശമായ<font color='red'><b>,</b></font> ഏകദേശം
#
# apt: ഉചിതമായ<font color='red'><b>,</b></font> കൃത്യമായ<font color='red'><b>,</b></font> ബുദ്ധിചടുലതയുള്ള<font color='red'><b>,</b></font> പ്രവണതയുള്ള<font color='red'><b>,</b></font> കുശാഗ്രബുദ്ധിയുള്ള<font color='red'><b>,</b></font> സാഹചര്യത്തിനു യോജിച്ച<font color='red'><b>,</b></font> സഹജമായ കഴിവുള്ള<font color='red'><b>,</b></font> ആട്ടോമാറ്റിക്കലി പ്രോഗ്രാമ്‌ഡ്‌ ടൂള്‍
#
# aptitude: പ്രവണത<font color='red'><b>,</b></font> അഭിരുചി<font color='red'><b>,</b></font> വാസന<font color='red'><b>,</b></font> ജന്മനായുള്ള കഴിവ്
#
# aptly: അനുയോജ്യമായി
#
# arbitrarily: തോന്നിയപോലെ<font color='red'><b>,</b></font> സ്വേച്ഛയാ
#
# arbitrary: അനിയന്ത്രിതമായ<font color='red'><b>,</b></font> ഏകപക്ഷീയമായ<font color='red'><b>,</b></font> നിയമനിബന്ധനമല്ലാത്ത<font color='red'><b>,</b></font> നിരങ്കുശമായ<font color='red'><b>,</b></font> ബോധിച്ചതുപോലെയുള്ള<font color='red'><b>,</b></font> സ്വേച്ഛാപരമായ<font color='red'><b>,</b></font> വസ്‌തുനിഷ്‌ഠമല്ലാത്ത<font color='red'><b>,</b></font> തോന്നിയപോലെ<font color='red'><b>,</b></font> വസ്തുനിഷ്ഠമല്ലാത്ത
#
# arch: വൃത്താശം<font color='red'><b>,</b></font> വളവ്<font color='red'><b>,</b></font> പ്രാധാന്യം<font color='red'><b>,</b></font> വളവ്‌<font color='red'><b>,</b></font> കമാനം<font color='red'><b>,</b></font> വളച്ചവാതില്‍<font color='red'><b>,</b></font> മേലാപ്പ്‌<font color='red'><b>,</b></font> മുഖ്യത<font color='red'><b>,</b></font> ശ്രഠത<font color='red'><b>,</b></font> ചതുരത<font color='red'><b>,</b></font> ഉത്തമത്വം<font color='red'><b>,</b></font> തുടങ്ങിയവയെ കുറിക്കുന്ന ഉപസര്‍ഗം<font color='red'><b>,</b></font> ചാപം<font color='red'><b>,</b></font> വളച്ചു വാതില്‍<font color='red'><b>,</b></font> വഞ്ചനയുള്ള<font color='red'><b>,</b></font> അലങ്കാരത്തോടുകൂടിയ പ്രവേശനദ്വാരം<font color='red'><b>,</b></font> അര്‍ദ്ധവൃത്താകൃതി
#
# arched: വളച്ചവാതില്‍വഴി
#
# architectural: രൂപകല്‌പനയെ സംബന്ധിച്ച<font color='red'><b>,</b></font> വാസ്‌തുവിദ്യയെ സംബന്ധിച്ച<font color='red'><b>,</b></font> ശില്പകലയെ സംബന്ധിച്ച<font color='red'><b>,</b></font> ശില്പശാസ്ത്രത്തെപ്പറ്റിയുളള<font color='red'><b>,</b></font> രൂപകല്പനയെ സംബന്ധിച്ച<font color='red'><b>,</b></font> വാസ്തുവിദ്യയെ സംബന്ധിച്ച
#
# ardent: ഉത്സാഹമുള്ള<font color='red'><b>,</b></font> ജ്വലിക്കുന്ന<font color='red'><b>,</b></font> തീക്ഷണമായ<font color='red'><b>,</b></font> ഉത്‌ക്കടമായ<font color='red'><b>,</b></font> അത്യസക്തിയുള്ള<font color='red'><b>,</b></font> ഉത്ക്കടമായ
#
# ardor: തീവ്രത<font color='red'><b>,</b></font> ഔത്സുക്യം<font color='red'><b>,</b></font> അഭിനിവേശം<font color='red'><b>,</b></font> രൂക്ഷത<font color='red'><b>,</b></font> അതിയായ ഔത്സുക്യം<font color='red'><b>,</b></font> തീവ്രവികാരം<font color='red'><b>,</b></font> വികാരതീക്ഷണത<font color='red'><b>,</b></font> വികാരതീക്ഷ്‌ണത
#
# arduous: കിഴക്കാംതൂക്കായ<font color='red'><b>,</b></font> കൃഛ്‌റസാധ്യമായ<font color='red'><b>,</b></font> ക്ലേശഭൂയിഷ്‌ഠമായ<font color='red'><b>,</b></font> ചെങ്കുത്തായ<font color='red'><b>,</b></font> ക്ലേശാവഹമായ<font color='red'><b>,</b></font> ദുഷ്‌കരമായ<font color='red'><b>,</b></font> പ്രയാസമായ<font color='red'><b>,</b></font> കയറാന്‍ വിഷമമുള്ള<font color='red'><b>,</b></font> അത്യധ്വാനിയായ<font color='red'><b>,</b></font> കഠിനശ്രമം ആവശ്യമുളള<font color='red'><b>,</b></font> ദുഷ്കരമായ
#
# argue: എതിരുപറയുക<font color='red'><b>,</b></font> ന്യായം പറഞ്ഞു സമ്മതപ്പെടുത്തുക<font color='red'><b>,</b></font> വാദിക്കുക<font color='red'><b>,</b></font> തര്‍ക്കിക്കുക<font color='red'><b>,</b></font> പ്രേരിപ്പിക്കുക<font color='red'><b>,</b></font> തെളിയിക്കുക<font color='red'><b>,</b></font> ന്യായം പറഞ്ഞ്‌ സമ്മതിപ്പിക്കുക<font color='red'><b>,</b></font> ദൃഷ്‌ടാന്തംപ്പെടുത്തുക
#
# argument: വാദപ്രതിവാദം<font color='red'><b>,</b></font> യുക്തിയുക്തം വാദിക്കല്‍<font color='red'><b>,</b></font> തര്‍ക്കം<font color='red'><b>,</b></font> വാദം<font color='red'><b>,</b></font> വിവാദം<font color='red'><b>,</b></font> വഴക്ക്‌<font color='red'><b>,</b></font> വാഗ്വാദം<font color='red'><b>,</b></font> വാദമുഖം<font color='red'><b>,</b></font> വാദവിഷയം<font color='red'><b>,</b></font> യുക്തി<font color='red'><b>,</b></font> വാദഗതി<font color='red'><b>,</b></font> പുസ്‌തകത്തിന്റെ സംഗ്രഹം<font color='red'><b>,</b></font> വഴക്ക്<font color='red'><b>,</b></font> പുസ്തകത്തിന്‍റെ സംഗ്രഹം
#
# arid: ഉണങ്ങിയ<font color='red'><b>,</b></font> നിഷ്ഫലമായ<font color='red'><b>,</b></font> വിരസമായ<font color='red'><b>,</b></font> വരണ്ട<font color='red'><b>,</b></font> ശുഷ്‌കമായ<font color='red'><b>,</b></font> തരിശായ<font color='red'><b>,</b></font> സസ്യങ്ങള്‍ക്കു വളരാനൊക്കാത്ത<font color='red'><b>,</b></font> ജനരഹിതമായ<font color='red'><b>,</b></font> ഊഷരമായ
#
# aristocracy: പ്രഭുത്വം<font color='red'><b>,</b></font> രാജാധിപത്യം<font color='red'><b>,</b></font> അഭിജാത വര്‍ഗ്ഗം<font color='red'><b>,</b></font> പ്രഭുജന വാഴ്‌ച<font color='red'><b>,</b></font> കുലീനാധിപത്യം<font color='red'><b>,</b></font> കുലീനവര്‍ഗ്ഗം<font color='red'><b>,</b></font> കുലീനവര്‍ഗ്ഗത്തിന്റെ ഭരണം<font color='red'><b>,</b></font> പ്രഭുഭരണം<font color='red'><b>,</b></font> കുലീനവര്‍ഗ്ഗത്തിന്‍റെ ഭരണം
#
# aristocratic: കുലീനമായ<font color='red'><b>,</b></font> ആഭിജാത്യമുള്ള<font color='red'><b>,</b></font> പ്രഭുജനങ്ങളെ സംബന്ധിച്ച<font color='red'><b>,</b></font> കുലീനരെ സംബന്ധിച്ച<font color='red'><b>,</b></font> നല്ല തറവാടിത്തമുളള<font color='red'><b>,</b></font> പരിഷ്കാരിയായ
#
# aromatic: വാസനയുള്ള<font color='red'><b>,</b></font> സുരഭിലമായ
#
# arrange: ക്രമീകരിക്കുക<font color='red'><b>,</b></font> ക്രമപ്പെടുത്തുക<font color='red'><b>,</b></font> ഏര്‍പ്പെടുത്തുക<font color='red'><b>,</b></font> സജ്ജീകരിക്കുക<font color='red'><b>,</b></font> അണിനിരത്തുക<font color='red'><b>,</b></font> പരിഷ്‌കരിക്കുക<font color='red'><b>,</b></font> ശരിയാക്കുക<font color='red'><b>,</b></font> അടുക്കിവയ്‌ക്കുക<font color='red'><b>,</b></font> മുറപോലെ വയ്‌ക്കുക<font color='red'><b>,</b></font> ഏര്‍പ്പാടു ചെയ്യുക<font color='red'><b>,</b></font> തയ്യാറാക്കുക<font color='red'><b>,</b></font> അടുക്കിവയ്ക്കുക
#
# arranged: ക്രമീകരിക്കപ്പെട്ട
#
# arrangement: രചന<font color='red'><b>,</b></font> വ്യവസ്ഥ<font color='red'><b>,</b></font> വിധാനം<font color='red'><b>,</b></font> വിന്യാസം<font color='red'><b>,</b></font> പദ്ധതി<font color='red'><b>,</b></font> ക്രമം<font color='red'><b>,</b></font> ഏര്‍പ്പാട്‌<font color='red'><b>,</b></font> ഒരുക്കം<font color='red'><b>,</b></font> സജ്ജീകരണം<font color='red'><b>,</b></font> അടുക്ക്‌<font color='red'><b>,</b></font> ചട്ടം<font color='red'><b>,</b></font> ക്രമീകരണം<font color='red'><b>,</b></font> വ്യാത്യാസം<font color='red'><b>,</b></font> ചട്ടവട്ടം<font color='red'><b>,</b></font> രൂപാന്തരണം<font color='red'><b>,</b></font> ചട്ടവട്ടങ്ങള്‍<font color='red'><b>,</b></font> ക്രമമായി സ്ഥാപിക്കല്‍<font color='red'><b>,</b></font> ഏര്‍പ്പാട്
#
# arrant: അങ്ങേയറ്റത്തെ<font color='red'><b>,</b></font> മഹാ<font color='red'><b>,</b></font> മുഴുത്ത
#
# arrogance: അഹങ്കാരം<font color='red'><b>,</b></font> ധിക്കാരം<font color='red'><b>,</b></font> ധാര്‍ഷ്‌ട്യം<font color='red'><b>,</b></font> ഔദ്ധത്യം<font color='red'><b>,</b></font> ഗര്‍വം<font color='red'><b>,</b></font> അധികാരഭാവം<font color='red'><b>,</b></font> ദുരഹങ്കാരം<font color='red'><b>,</b></font> മദം<font color='red'><b>,</b></font> അഹമ്മതി
#
# arrogant: ധിക്കാരി<font color='red'><b>,</b></font> അഹങ്കാരിയായ<font color='red'><b>,</b></font> ധാര്‍ഷ്‌ട്യമുള്ള<font color='red'><b>,</b></font> ഗര്‍വ്വുളള<font color='red'><b>,</b></font> ധാര്‍ഷ്ട്യമുള്ള
#
# arrogate: അനീതിയായി സ്വാധീനപ്പെടുത്തുക<font color='red'><b>,</b></font> അപഹരിച്ചെടുക്കുക
#
# arson: ഈ അപരാധം<font color='red'><b>,</b></font> തീവയ്‌പ്‌<font color='red'><b>,</b></font> തീവയ്പ്<font color='red'><b>,</b></font> തീവയ്‌ക്കല്‍
#
# art: ചരിത്രം<font color='red'><b>,</b></font> ആട്ടോമാറ്റിക്‌ റീസണിംഗ്‌ ടൂള്‍<font color='red'><b>,</b></font> ഭാവനാസൃഷ്ടി<font color='red'><b>,</b></font> സൃഷ്ടിപരമായ കഴിവ്<font color='red'><b>,</b></font> ഭാഷാ<font color='red'><b>,</b></font> സാഹിത്യം മുതലായവയെക്കുറിച്ചുളള പഠനം<font color='red'><b>,</b></font> ഉപായം<font color='red'><b>,</b></font> അറിവ്‌<font color='red'><b>,</b></font> തന്ത്രം<font color='red'><b>,</b></font> നൈപുണ്യം<font color='red'><b>,</b></font> ചാതുര്യം<font color='red'><b>,</b></font> സൂത്രം<font color='red'><b>,</b></font> തൊഴില്‍<font color='red'><b>,</b></font> കൗശലം<font color='red'><b>,</b></font> കൗശലപ്പണി<font color='red'><b>,</b></font> കല<font color='red'><b>,</b></font> പ്രയോഗചാതുര്യം<font color='red'><b>,</b></font> ശില്‍പം<font color='red'><b>,</b></font> വിദ്യ<font color='red'><b>,</b></font> ചമല്‍ക്കാരം<font color='red'><b>,</b></font> മനുഷ്യന്റെ വൈദഗ്‌ദ്ധ്യം<font color='red'><b>,</b></font> കലാപരമായ വിജ്ഞാനവകുപ്പുകള്‍<font color='red'><b>,</b></font> കലാസൃഷ്‌ടി
#
# artful: ചാതുര്യമുള്ള<font color='red'><b>,</b></font> കൗശലമുള്ള<font color='red'><b>,</b></font> കപടമായ<font color='red'><b>,</b></font> കൃത്രിമമായ<font color='red'><b>,</b></font> കൈമിടുക്കുള്ള<font color='red'><b>,</b></font> കൃത്രിമാമായ<font color='red'><b>,</b></font> മായാവിയായ<font color='red'><b>,</b></font> ചമത്കാരമായ
#
# artifice: വ്യാജം<font color='red'><b>,</b></font> കൃത്രിമം<font color='red'><b>,</b></font> തന്ത്രം<font color='red'><b>,</b></font> സൂത്രപ്പണി<font color='red'><b>,</b></font> കൗശലപ്പണി
#
# artificial: അയഥാര്‍ത്ഥമായ<font color='red'><b>,</b></font> സ്വാഭാവികമല്ലാത്ത<font color='red'><b>,</b></font> ആത്മാര്‍ത്ഥതയില്ലാത്ത<font color='red'><b>,</b></font> കൃത്രിമമായ<font color='red'><b>,</b></font> മനുഷ്യനിര്‍മ്മിതമായ<font color='red'><b>,</b></font> ശില്‍പനിര്‍മ്മിതമായ<font color='red'><b>,</b></font> നാട്യമായ
#
# artistic: ചമല്‍ക്കാരമുള്ള<font color='red'><b>,</b></font> കലാപരമായ<font color='red'><b>,</b></font> കലയെക്കുറിച്ചുള്ള<font color='red'><b>,</b></font> ശില്‍പവിഷയകമായ<font color='red'><b>,</b></font> കലാകാരന്മാരെ സംബന്ധിച്ച<font color='red'><b>,</b></font> കലാപ്രേമി<font color='red'><b>,</b></font> കലാപ്രേമി
#
# artistry: കലാചാതുരി<font color='red'><b>,</b></font> നിര്‍മ്മാണചാതുര്യം
#
# artless: കഴിവില്ലാത്ത<font color='red'><b>,</b></font> അകൃത്രിമമായ<font color='red'><b>,</b></font> അനാഗരികമായ<font color='red'><b>,</b></font> നിഷ്കപടമായ<font color='red'><b>,</b></font> പരമാര്‍ത്ഥമുളള<font color='red'><b>,</b></font> സ്വാഭാവികമായ<font color='red'><b>,</b></font> നിഷ്‌കപടമായ<font color='red'><b>,</b></font> അകൃത്രിമാമായ<font color='red'><b>,</b></font> കലാസ്വഭാവമില്ലാത്ത<font color='red'><b>,</b></font> കലാവൈദഗ്‌ദ്ധ്യമില്ലാത്ത<font color='red'><b>,</b></font> വിലക്ഷമായ<font color='red'><b>,</b></font> നിഷ്കളങ്കമായ<font color='red'><b>,</b></font> ചതിവില്ലാത്ത
#
# ascending: കയറുന്ന
#
# ascetic: ജിതേന്ദ്രിയന്‍<font color='red'><b>,</b></font> തപസ്വി<font color='red'><b>,</b></font> സന്ന്യാസി<font color='red'><b>,</b></font> യതി<font color='red'><b>,</b></font> യോഗി<font color='red'><b>,</b></font> കഠിനവ്രതത്തോടുകൂടിയ
#
# ashamed: സലജ്ജമായ<font color='red'><b>,</b></font> നാണം കുണുങ്ങുന്ന<font color='red'><b>,</b></font> ലജ്ജിച്ച<font color='red'><b>,</b></font> ലജ്ജയാല്‍ വിഷമിക്കുന്ന<font color='red'><b>,</b></font> ലജ്ജയുള്ള<font color='red'><b>,</b></font> ലജ്ജിതമായ<font color='red'><b>,</b></font> നാണംകുണുങ്ങുക<font color='red'><b>,</b></font> ലജ്ജിതനായ<font color='red'><b>,</b></font> സലജ്ജ<font color='red'><b>,</b></font> നാണക്കേടുളള
#
# aspect: സ്വഭാവം<font color='red'><b>,</b></font> മുഖഭാവം<font color='red'><b>,</b></font> ആകൃതി<font color='red'><b>,</b></font> ഭാവം<font color='red'><b>,</b></font> നിരീക്ഷണം<font color='red'><b>,</b></font> ദര്‍ശനം<font color='red'><b>,</b></font> നോട്ടം<font color='red'><b>,</b></font> കാഴ്‌ച<font color='red'><b>,</b></font> ദൃഷ്‌ടി<font color='red'><b>,</b></font> രൂപം<font color='red'><b>,</b></font> ആകാരം<font color='red'><b>,</b></font> വീക്ഷണം<font color='red'><b>,</b></font> വശം<font color='red'><b>,</b></font> നോട്ടം<font color='red'><b>,</b></font> കെട്ടിടത്തിന്റെ വശം<font color='red'><b>,</b></font> ഗ്രഹത്തിന്റെ നില<font color='red'><b>,</b></font> പ്രത്യേക വശം<font color='red'><b>,</b></font> കാഴ്ചപ്പാട്<font color='red'><b>,</b></font> കെട്ടിടത്തിന്‍റെ വശം<font color='red'><b>,</b></font> ഗ്രഹത്തിന്‍റെ നില
#
# aspects: ഭാവങ്ങള്‍
#
# asperity: രൂക്ഷത<font color='red'><b>,</b></font> പരുപരുപ്പ്‌<font color='red'><b>,</b></font> കാര്‍ക്കശ്യം<font color='red'><b>,</b></font> പരുക്കന്‍ സ്വഭാവം<font color='red'><b>,</b></font> പാരുഷ്യം<font color='red'><b>,</b></font> കഠോരത<font color='red'><b>,</b></font> ശബ്‌ദപാരുഷ്യം
#
# aspersions: അധിക്ഷേപം
#
# aspiration: ആഗ്രഹം<font color='red'><b>,</b></font> അഭിലാഷം<font color='red'><b>,</b></font> രൂക്ഷത<font color='red'><b>,</b></font> പാരുഷ്യം<font color='red'><b>,</b></font> ശ്വസനം<font color='red'><b>,</b></font> ഉത്‌കടമായ അഭിലാഷം<font color='red'><b>,</b></font> ഘോഷോച്ചാരണം<font color='red'><b>,</b></font> ഉത്കടമായ അഭിലാഷം<font color='red'><b>,</b></font> ഘോഷോച്ചാരണം
#
# assemble: വിളിച്ചു കൂട്ടുക<font color='red'><b>,</b></font> ഒന്നിച്ചുചേര്‍ക്കുക<font color='red'><b>,</b></font> സംയോജിപ്പിക്കുക<font color='red'><b>,</b></font> യോഗം കൂട്ടുക<font color='red'><b>,</b></font> ശേഖരിക്കുക<font color='red'><b>,</b></font> സമ്മേളിക്കുക<font color='red'><b>,</b></font> ഘടിപ്പിക്കുക<font color='red'><b>,</b></font> യോഗം ചേരുക<font color='red'><b>,</b></font> കൂട്ടംകൂടുക<font color='red'><b>,</b></font> കൂനകൂട്ടുക<font color='red'><b>,</b></font> ഒന്നിച്ചുചേര്‍ക്കല്‍
#
# assent: സമ്മതം<font color='red'><b>,</b></font> അനുമതി<font color='red'><b>,</b></font> ഉടമ്പാട്‌<font color='red'><b>,</b></font> അംഗീകരിക്കുക<font color='red'><b>,</b></font> യോജിക്കുക<font color='red'><b>,</b></font> സമ്മതം വെളിവാക്കുക
#
# assertion: വാദം<font color='red'><b>,</b></font> പ്രതിജ്ഞ<font color='red'><b>,</b></font> ദൃഢനിശ്ചയം<font color='red'><b>,</b></font> ഉറപ്പിച്ചു പറയല്‍<font color='red'><b>,</b></font> അവകാശവാദം<font color='red'><b>,</b></font> ശക്തിയുക്തം സ്ഥാപിക്കല്‍<font color='red'><b>,</b></font> ദൃഢപ്രസ്താവം<font color='red'><b>,</b></font> തറപ്പിച്ചു പറയല്‍
#
# assiduity: ഉത്സാഹം<font color='red'><b>,</b></font> ഉദ്യമം<font color='red'><b>,</b></font> നിരന്തരോദ്യമം<font color='red'><b>,</b></font> ശുഷ്കാന്തി<font color='red'><b>,</b></font> തല്‍പരത<font color='red'><b>,</b></font> നിരന്തരോദ്യമം
#
# assiduously: ശുഷ്‌കാന്തിയോടെ<font color='red'><b>,</b></font> അവധാനതയോടെ<font color='red'><b>,</b></font> ശുഷ്കാന്തിയോടെ
#
# assimilated: കലര്‍ത്തുക<font color='red'><b>,</b></font> ഉള്‍ച്ചേര്‍ക്കുക
#
# assimilation: ഏകീകരണം<font color='red'><b>,</b></font> ഒന്നിച്ചുചേരല്‍<font color='red'><b>,</b></font> സാത്മീകരണം<font color='red'><b>,</b></font> ദഹനപ്രക്രിയ<font color='red'><b>,</b></font> സ്വാംശീകരണം<font color='red'><b>,</b></font> ഉള്‍ച്ചേര്‍ക്കല്‍<font color='red'><b>,</b></font> ആഗിരണം
#
# assistance: ഉപകാരം<font color='red'><b>,</b></font> കൂട്ട്<font color='red'><b>,</b></font> തുണ<font color='red'><b>,</b></font> സഹായം
#
# assistant: സഹായി
#
# associated: സംഘടിതമായ
#
# association: സംഘം<font color='red'><b>,</b></font> കൂട്ടുകെട്ട്‌<font color='red'><b>,</b></font> ചങ്ങാത്തം<font color='red'><b>,</b></font> സംഘടന<font color='red'><b>,</b></font> സമിതി<font color='red'><b>,</b></font> സംസര്‍ഗ്ഗം<font color='red'><b>,</b></font> കൂടിച്ചേരല്‍<font color='red'><b>,</b></font> കൂട്ടുകെട്ട്
#
# assumed: ഏറ്റെടുക്കപ്പെട്ട<font color='red'><b>,</b></font> ഒളിച്ചുവെച്ച
#
# assumption: ധാരണ<font color='red'><b>,</b></font> കല്‍പന<font color='red'><b>,</b></font> അനുമാനം<font color='red'><b>,</b></font> അംഗീകാരം<font color='red'><b>,</b></font> അഹംഭാവം<font color='red'><b>,</b></font> സങ്കല്പം
#
# assurance: ജാമ്യം<font color='red'><b>,</b></font> ഉറപ്പു നല്‍കല്‍<font color='red'><b>,</b></font> ഇന്‍ഷ്വറന്‍സ്‌<font color='red'><b>,</b></font> വാഗ്ദാനം<font color='red'><b>,</b></font> ആത്മവിശ്വാസം<font color='red'><b>,</b></font> വാഗ്‌ദാനം<font color='red'><b>,</b></font> ഔപചാരികമായ പ്രതിജ്ഞ<font color='red'><b>,</b></font> നിസ്സന്ദേഹമായ സ്ഥൈര്യം<font color='red'><b>,</b></font> സ്ഥിരപ്രത്യാശ<font color='red'><b>,</b></font> വാഗ്ദാനം<font color='red'><b>,</b></font> ഉറപ്പ്<font color='red'><b>,</b></font> ഇന്‍ഷ്വറന്‍സ്
#
# assured: നിസ്സംശയമായും<font color='red'><b>,</b></font> സുനിശ്ചിതമായ<font color='red'><b>,</b></font> വിശ്വാസ്യമായ<font color='red'><b>,</b></font> തീരുമാനിച്ച<font color='red'><b>,</b></font> നിശ്ചയിച്ച<font color='red'><b>,</b></font> തീര്‍ച്ചയായും
#
# assuredly: നിശ്ചയമായും<font color='red'><b>,</b></font> സന്ദേഹം കൂടാതെ<font color='red'><b>,</b></font> നിസ്സംശയം<font color='red'><b>,</b></font> തീര്‍ച്ചയായും<font color='red'><b>,</b></font> നിശ്ചയമായി<font color='red'><b>,</b></font> അസംശയം
#
# astonished: അത്ഭുതപരവശമാവുക<font color='red'><b>,</b></font> ആശ്ചര്യഭരിതമായ
#
# astonishing: ആശ്ചര്യകരമായ<font color='red'><b>,</b></font> വിസ്‌മയജനകമായ
#
# astonishment: ആശ്ചര്യം<font color='red'><b>,</b></font> അദ്‌ഭുദപാരവ്‌ശ്യം<font color='red'><b>,</b></font> വിസ്മയം<font color='red'><b>,</b></font> അത്ഭുതകാരണം<font color='red'><b>,</b></font> അന്പരപ്പ്
#
# astound: സംഭ്രമിപ്പിക്കുക<font color='red'><b>,</b></font> അമ്പരപ്പിക്കുക<font color='red'><b>,</b></font> വിസ്‌മയസ്‌തബ്‌ധനാക്കുക<font color='red'><b>,</b></font> അത്ഭുതപ്പെടുത്തുക<font color='red'><b>,</b></font> ആശ്ചര്യപ്പെടുത്തുക<font color='red'><b>,</b></font> വിമോഹിപ്പിക്കുക
#
# astounding: അമ്പരപ്പിക്കുന്ന<font color='red'><b>,</b></font> വിസ്‌മയിപ്പിക്കുന്ന<font color='red'><b>,</b></font> സംഭ്രമിപ്പിക്കുന്ന
#
# astute: വിവേകമുള്ള<font color='red'><b>,</b></font> സൂക്ഷ്മബുദ്ധിയുളള<font color='red'><b>,</b></font> കൗശലമുളള<font color='red'><b>,</b></font> തീക്ഷ്ണബുദ്ധിയുളള<font color='red'><b>,</b></font> കൗശലമുള്ള<font color='red'><b>,</b></font> സൂത്രശാലിയായ<font color='red'><b>,</b></font> സൂക്ഷ്‌മബുദ്ധിയുള്ള<font color='red'><b>,</b></font> നിശിതബുദ്ധിശാലിയായ<font color='red'><b>,</b></font> സൂക്ഷ്‌മഗ്രാഹിയായ<font color='red'><b>,</b></font> നിശിതബുദ്ധിയായ<font color='red'><b>,</b></font> ബുദ്ധിശാലിയായ
#
# asunder: വേറിട്ട്‌<font color='red'><b>,</b></font> കഷണംകഷണമായി<font color='red'><b>,</b></font> വേര്‍പെട്ടതായി<font color='red'><b>,</b></font> വേര്‍പ്പെട്ടതായി<font color='red'><b>,</b></font> ഭാഗങ്ങളായി<font color='red'><b>,</b></font> വേറെ വേറെയായി<font color='red'><b>,</b></font> പ്രത്യേക സ്ഥാനത്ത്<font color='red'><b>,</b></font> വേറിട്ട്
#
# athletic: കായികാഭ്യാസം സംബന്ധിച്ച<font color='red'><b>,</b></font> ബാഹുവീര്യത്തോടുകൂടിയ<font color='red'><b>,</b></font> കായികവിനോദങ്ങളെ സംബന്ധിച്ച<font color='red'><b>,</b></font> കായികാഭ്യാസ സംബന്ധിച്ച<font color='red'><b>,</b></font> സന്നദ്ധശരീരനായ<font color='red'><b>,</b></font> കായികാഭ്യാസ സംബന്ധിയായ<font color='red'><b>,</b></font> ബലവത്തായ
#
# atoms: അണുക്കള്‍
#
# atonement: പ്രായശ്ചിത്തം<font color='red'><b>,</b></font> പ്രതിശാന്തി<font color='red'><b>,</b></font> പാപനിവൃത്തി
#
# atrocious: ഭയങ്കരമായ<font color='red'><b>,</b></font> ദാരുണമായ<font color='red'><b>,</b></font> അതിക്രൂരമായ<font color='red'><b>,</b></font> മോശമായ<font color='red'><b>,</b></font> കൊടിയ<font color='red'><b>,</b></font> നൃശംസമായ<font color='red'><b>,</b></font> അത്യന്തം ദൗഷ്‌ട്യമുള്ള<font color='red'><b>,</b></font> വളരെ ക്രൂരമായ<font color='red'><b>,</b></font> നിഷ്ഠുരമായ
#
# atrocities: പീഡനങ്ങള്‍
#
# attached: അങ്ങേയറ്റം അടുത്ത്‌<font color='red'><b>,</b></font> ഇഴുകിച്ചേര്‍ന്ന<font color='red'><b>,</b></font> ഘടിപ്പിക്കപ്പെട്ട<font color='red'><b>,</b></font> സ്‌നേഹബദ്ധമായ<font color='red'><b>,</b></font> പിടിപ്പിച്ച<font color='red'><b>,</b></font> ചേര്‍ന്നുനില്‍ക്കുന്ന<font color='red'><b>,</b></font> മമതയുള്ള<font color='red'><b>,</b></font> ബന്ധിപ്പിച്ച
#
# attachment: ബന്ധനം<font color='red'><b>,</b></font> അഭിനിവേശം<font color='red'><b>,</b></font> വ്യവഹാരം സംബന്ധിച്ച് കല്പനപ്രകാരം ഒരാളെ പിടികൂടല്‍<font color='red'><b>,</b></font> വസ്തു ജപ്തി ചെയ്യല്‍<font color='red'><b>,</b></font> ബന്ധം<font color='red'><b>,</b></font> താല്പര്യം<font color='red'><b>,</b></font> ആസക്തി<font color='red'><b>,</b></font> സ്‌നേഹം<font color='red'><b>,</b></font> ജപ്‌തി<font color='red'><b>,</b></font> താല്‍പര്യം<font color='red'><b>,</b></font> തൊങ്ങല്‍<font color='red'><b>,</b></font> മമത<font color='red'><b>,</b></font> സ്‌നേഹബന്ധം<font color='red'><b>,</b></font> ബന്ധിച്ചിരിക്കുന്ന അവസ്ഥ<font color='red'><b>,</b></font> ആശാപാശം<font color='red'><b>,</b></font> സ്നേഹം<font color='red'><b>,</b></font> ജപ്തി
#
# attack: അധിക്ഷേപം<font color='red'><b>,</b></font> കയ്യേറ്റം<font color='red'><b>,</b></font> ആക്രമണം<font color='red'><b>,</b></font> ബാധ<font color='red'><b>,</b></font> സൈനികാക്രമണം<font color='red'><b>,</b></font> രൂക്ഷമായ കുറ്റാരോപണം<font color='red'><b>,</b></font> രൂക്ഷവിമര്‍ശനം<font color='red'><b>,</b></font> വാക്കുകള്‍കൊണ്ട് ആക്രമിക്കുക<font color='red'><b>,</b></font> എതിര്‍ക്കുക<font color='red'><b>,</b></font> ആക്രമിക്കുക<font color='red'><b>,</b></font> വിമര്‍ശിക്കുക<font color='red'><b>,</b></font> പിടികൂടുക<font color='red'><b>,</b></font> അധിക്ഷേപിക്കുക<font color='red'><b>,</b></font> യുദ്ധമോ വഴക്കോ തുടങ്ങിയവയ്‌ക്കുക<font color='red'><b>,</b></font> ഭര്‍ത്സിക്കുക<font color='red'><b>,</b></font> വാക്കുകള്‍കൊണ്ടാക്രമിക്കുക<font color='red'><b>,</b></font> രോഗം പിടിക്കുക
#
# attempt: ഉദ്യമം<font color='red'><b>,</b></font> ശ്രമം<font color='red'><b>,</b></font> ആക്രമണം<font color='red'><b>,</b></font> പ്രയത്നിക്കുക<font color='red'><b>,</b></font> യത്നിക്കുക<font color='red'><b>,</b></font> പരീക്ഷിച്ചു നോക്കുക<font color='red'><b>,</b></font> മുതിരുക<font color='red'><b>,</b></font> ഉദ്യമിക്കുക<font color='red'><b>,</b></font> ശ്രമിക്കുക<font color='red'><b>,</b></font> ഒരുങ്ങുക<font color='red'><b>,</b></font> ഒരുമ്പെടുക
#
# attending: പരിചരിക്കുന്ന<font color='red'><b>,</b></font> പരിപാലിക്കുന്ന
#
# attention: ഉപചാരം<font color='red'><b>,</b></font> ദാക്ഷിണ്യം<font color='red'><b>,</b></font> ഏകാഗ്രത<font color='red'><b>,</b></font> ജാഗ്രത<font color='red'><b>,</b></font> ശ്രദ്ധ<font color='red'><b>,</b></font> ആശങ്ക<font color='red'><b>,</b></font> ശുഷ്‌കാന്തി<font color='red'><b>,</b></font> ബഹുമാനം<font color='red'><b>,</b></font> അഭിനിവേശം<font color='red'><b>,</b></font> നിഷ്‌കര്‍ഷ<font color='red'><b>,</b></font> ജാഗരൂകത<font color='red'><b>,</b></font> തല്‍പരത്വം<font color='red'><b>,</b></font> അനുഷ്‌ഠാനം<font color='red'><b>,</b></font> എന്തിലെങ്കിലും ആരിലെങ്കിലും ഒരാളുടെ മനസ്സ് കേന്ദ്രീകരിക്കല്‍<font color='red'><b>,</b></font> പ്രത്യേക ശ്രദ്ധ
#
# attentive: ശ്രദ്ധയുളള<font color='red'><b>,</b></font> ഉപചാരശീലമുളള<font color='red'><b>,</b></font> ജാഗ്രതയുളള<font color='red'><b>,</b></font> ശ്രദ്ധയുള്ള<font color='red'><b>,</b></font> ഉപചാരശീലമുള്ള<font color='red'><b>,</b></font> ബദ്ധശ്രദ്ധനായ<font color='red'><b>,</b></font> ദത്താവധാനമായ
#
# attested: സാക്ഷിപ്പെടുത്തിയ
#
# attitude: നില<font color='red'><b>,</b></font> അഭിപ്രായം<font color='red'><b>,</b></font> പെരുമാറ്റം<font color='red'><b>,</b></font> ഭാവം<font color='red'><b>,</b></font> ശരീരസ്ഥിതി<font color='red'><b>,</b></font> മട്ട്‌ അവസ്ഥാഭേദം<font color='red'><b>,</b></font> മനഃസ്ഥിതി<font color='red'><b>,</b></font> നയം<font color='red'><b>,</b></font> ഇരിപ്പ്‌<font color='red'><b>,</b></font> നിലപാട്‌<font color='red'><b>,</b></font> മട്ട്<font color='red'><b>,</b></font> മനോഭാവം
#
# attract: മയക്കുക<font color='red'><b>,</b></font> വശീകരിക്കുക<font color='red'><b>,</b></font> ആകര്‍ഷിക്കുക<font color='red'><b>,</b></font> അടുപ്പിക്കുക<font color='red'><b>,</b></font> ശ്രദ്ധ പിടച്ചെടുക്കുക<font color='red'><b>,</b></font> ശ്രദ്ധപിടിച്ചു പറ്റുക<font color='red'><b>,</b></font> ശക്തിയോടെ വലിക്കുക
#
# attractive: ആകര്‍ഷകമായ<font color='red'><b>,</b></font> ഹൃദയഹാരിയായ<font color='red'><b>,</b></font> ഹൃദ്യമായ<font color='red'><b>,</b></font> വശീകരിക്കത്തക്ക<font color='red'><b>,</b></font> ആകര്‍ഷിക്കത്തക്ക<font color='red'><b>,</b></font> മനോഹാരിതമായ
#
# attractiveness: ആകര്‍ഷകത്വം<font color='red'><b>,</b></font> വശ്യത<font color='red'><b>,</b></font> ആകര്‍ഷണത്വം
#
# attribute: സ്വാഭാവം<font color='red'><b>,</b></font> ഗുണം<font color='red'><b>,</b></font> പ്രകൃതി<font color='red'><b>,</b></font> വിശേഷണം<font color='red'><b>,</b></font> ധര്‍മ്മം<font color='red'><b>,</b></font> ലക്ഷണം<font color='red'><b>,</b></font> പ്രതീകം<font color='red'><b>,</b></font> ചുമത്തുക<font color='red'><b>,</b></font> ആരോപിക്കുക<font color='red'><b>,</b></font> എന്തെങ്കിലുമൊന്നിനെ മറ്റൊന്നിനു കാരണമായി കാണുക<font color='red'><b>,</b></font> സംബന്ധിപ്പിക്കുക<font color='red'><b>,</b></font> ഹേതുവാക്കുക
#
# attributes: ഗുണങ്ങള്‍<font color='red'><b>,</b></font> ലക്ഷണങ്ങള്‍
#
# audacious: ധിക്കാരിയായ<font color='red'><b>,</b></font> അധികപ്രസംഗിയായ<font color='red'><b>,</b></font> ധാര്‍ഷ്‌ട്യമുള്ള<font color='red'><b>,</b></font> സാഹസികസ്വഭാവമുള്ള<font color='red'><b>,</b></font> ധിക്കാരമുള്ള<font color='red'><b>,</b></font> ഭയരഹിതനായ<font color='red'><b>,</b></font> അഹങ്കാരമുളള<font color='red'><b>,</b></font> ധീരത പ്രകടമാക്കുന്ന<font color='red'><b>,</b></font> കടുസാഹസികനായ
#
# audacity: അഹങ്കാരം<font color='red'><b>,</b></font> അധികപ്രസംഗം<font color='red'><b>,</b></font> നാണമില്ലായ്മ<font color='red'><b>,</b></font> സാഹസം<font color='red'><b>,</b></font> ധിക്കാരം<font color='red'><b>,</b></font> ധാര്‍ഷ്‌ട്യം<font color='red'><b>,</b></font> സാഹസികത<font color='red'><b>,</b></font> ധീരത<font color='red'><b>,</b></font> ധൈര്യം<font color='red'><b>,</b></font> സാഹസികത്വം
#
# audible: ശ്രവണസാധ്യത<font color='red'><b>,</b></font> ശ്രാവ്യത<font color='red'><b>,</b></font> കാതാല്‍ കേള്‍ക്കാവുന്ന<font color='red'><b>,</b></font> കര്‍ണ്ണഗോചരമായ<font color='red'><b>,</b></font> കേള്‍ക്കത്തക്ക<font color='red'><b>,</b></font> സ്‌ഫുടമായി കേള്‍ക്കാവുന്ന<font color='red'><b>,</b></font> സ്ഫുടമായി കേള്‍ക്കാവുന്ന
#
# augment: വര്‍ദ്ധിപ്പിക്കുക<font color='red'><b>,</b></font> വളര്‍ത്തുക<font color='red'><b>,</b></font> അധികമാക്കുക<font color='red'><b>,</b></font> പെരുപ്പിക്കുക<font color='red'><b>,</b></font> വര്‍ദ്ധിക്കുക<font color='red'><b>,</b></font> എന്തെങ്കിലും വലുതാക്കുകയോ എണ്ണം കൂട്ടുകയോ ചെയ്യുക
#
# augury: ശകുനം<font color='red'><b>,</b></font> നിമിത്തം<font color='red'><b>,</b></font> ലക്ഷണശാസ്ത്രം
#
# august: മഹനീയമായ<font color='red'><b>,</b></font> ഗാംഭീര്യമുള്ള<font color='red'><b>,</b></font> പ്രതാപമുള്ള<font color='red'><b>,</b></font> കുലീനനായ<font color='red'><b>,</b></font> ഇംഗ്ലീഷ് വര്‍ഷത്തിലെ മുപ്പത്തിയൊന്ന് ദിവസമുളള എട്ടാമത്തെമാസം<font color='red'><b>,</b></font> ആഗസ്റ്റ് (അഗസ്റ്റസ് ചക്രവര്‍ത്തിയുടെ പേരില്‍നിന്ന്)<font color='red'><b>,</b></font> (മലയാളത്തില്‍ കര്‍ക്കിടകം-ചിങ്ങം)
#
# auspicious: അനുകൂലമായ<font color='red'><b>,</b></font> മംഗളകരമായ<font color='red'><b>,</b></font> ശുഭോദര്‍ക്കമായ<font color='red'><b>,</b></font> ശുഭസൂചകമായ<font color='red'><b>,</b></font> പുണ്യമായ<font color='red'><b>,</b></font> ശുഭമായ<font color='red'><b>,</b></font> ധന്യമായ
#
# austere: കഠിനമായ<font color='red'><b>,</b></font> ചവര്‍പ്പുളള<font color='red'><b>,</b></font> തീവ്രവിരക്തിയോടുകൂടിയ<font color='red'><b>,</b></font> കര്‍ക്കശമായ<font color='red'><b>,</b></font> തീവ്രവിരക്തിയോടുകൂടിയ<font color='red'><b>,</b></font> ഉഗ്രമായ സന്‍മാര്‍ഗനിഷ്‌ഠയുള്ള<font color='red'><b>,</b></font> ലാളിത്യം മുറ്റിനില്‍ക്കുന്ന<font color='red'><b>,</b></font> അലങ്കാരരഹിതമായ<font color='red'><b>,</b></font> സുഖങ്ങളെ ത്യജിക്കുന്ന<font color='red'><b>,</b></font> ഒതുങ്ങിയ മട്ടിലുള്ള
#
# austerity: കാഠിന്യം<font color='red'><b>,</b></font> കഠിന നിഷ്ഠ<font color='red'><b>,</b></font> തീവ്രവിരക്തി<font color='red'><b>,</b></font> സുഖോപഭോഗനിഷേധം<font color='red'><b>,</b></font> സന്ന്യാസം
#
# authentic: സത്യസന്ധമായ
#
# <font color='red'><b>,</b></font> യഥാര്‍ത്ഥമായ<font color='red'><b>,</b></font> വിശ്വാസനീയമായ<font color='red'><b>,</b></font> അധികാരികമായ<font color='red'><b>,</b></font> അകൃത്രിമമായ<font color='red'><b>,</b></font> ആധികാരികമായ<font color='red'><b>,</b></font> വിശ്വസനീയമായ<font color='red'><b>,</b></font> വിശ്വാസ്യമായ<font color='red'><b>,</b></font> വിശ്വാസ്യയോഗ്യമായ
#
# authenticity: പ്രാമാണ്യം
#
# authoritative: പ്രമാണയുക്തമായ<font color='red'><b>,</b></font> അധികൃതമായ<font color='red'><b>,</b></font> ആധികാരികമായ<font color='red'><b>,</b></font> പ്രമാണികമായ<font color='red'><b>,</b></font> പ്രാമാണികമായ<font color='red'><b>,</b></font> ഔദ്യോഗികമായ
#
# authority: അവകാശം<font color='red'><b>,</b></font> വിശ്വാസ്യത<font color='red'><b>,</b></font> പ്രാമാണ്യം<font color='red'><b>,</b></font> ആപ്തവചനം<font color='red'><b>,</b></font> അധികാരി<font color='red'><b>,</b></font> അധികാരം<font color='red'><b>,</b></font> ആധിപത്യം<font color='red'><b>,</b></font> ആജ്ഞ<font color='red'><b>,</b></font> അനുമതി<font color='red'><b>,</b></font> മേല്‍ക്കോയ്‌മ<font color='red'><b>,</b></font> വിദഗ്‌ദ്ധന്‍<font color='red'><b>,</b></font> നിയോഗം<font color='red'><b>,</b></font> ശാസനം<font color='red'><b>,</b></font> ഗൗരവം<font color='red'><b>,</b></font> ആപ്‌തവചനം<font color='red'><b>,</b></font> പ്രമാണ പുരുഷന്‍<font color='red'><b>,</b></font> പ്രാമാണികത്വം<font color='red'><b>,</b></font> നിയമപരമായ അധികാരം<font color='red'><b>,</b></font> പ്രമാണ ഗ്രന്ഥം<font color='red'><b>,</b></font> ഏതെങ്കിലും വിഷയത്തില്‍ നിപുണന്‍
#
# autocracy: സ്വേച്ഛാധിപത്യം<font color='red'><b>,</b></font> സ്വച്ഛാധിപതി<font color='red'><b>,</b></font> ഏകാധിപത്യം<font color='red'><b>,</b></font> ഒരു രാജ്യത്തിന്‍റെ പരമാധികാരം ഒരു വ്യക്തിയില്‍തന്നെ കേന്ദ്രീകരിക്കല്‍
#
# autocratic: ഏകാധിപതി<font color='red'><b>,</b></font> ഏകാധിപത്യ സ്വഭാവമുള്ള
#
# automatic: സ്വയം ചലിക്കുന്ന<font color='red'><b>,</b></font> തന്നെത്താന്‍ പ്രവര്‍ത്തിക്കുന്ന യന്ത്രം<font color='red'><b>,</b></font> സ്വയംപ്രേരിതനായ<font color='red'><b>,</b></font> തന്നത്താനെ പ്രവര്‍ത്തിക്കുന്ന<font color='red'><b>,</b></font> ഇച്ഛാപൂര്‍വ്വകമല്ലാത്ത<font color='red'><b>,</b></font> സ്വയം പ്രേരിതമായ<font color='red'><b>,</b></font> സ്വയം പ്രവര്‍ത്തിക്കുന്ന<font color='red'><b>,</b></font> താനേ പ്രവര്‍ത്തിക്കുന്ന<font color='red'><b>,</b></font> സ്വയമേയുള്ളത്‌<font color='red'><b>,</b></font> സ്വയമേയുള്ളത്
#
# auxiliary: സഹായകമായ സംഗതിയോ വസ്‌തുവോ<font color='red'><b>,</b></font> ഉപകാരിയായ<font color='red'><b>,</b></font> കൂടുതലായ<font color='red'><b>,</b></font> തുണയായ<font color='red'><b>,</b></font> സഹായക്രിയ<font color='red'><b>,</b></font> സഹായസൈന്യം<font color='red'><b>,</b></font> സഹായകക്രിയ<font color='red'><b>,</b></font> സഹകാരിയായ<font color='red'><b>,</b></font> സഹായി<font color='red'><b>,</b></font> സഹായിക്കുന്ന<font color='red'><b>,</b></font> ഉപകരിക്കുന്ന<font color='red'><b>,</b></font> അധികമായുള്ള
#
# available: സുലഭമായ<font color='red'><b>,</b></font> എത്താവുന്ന<font color='red'><b>,</b></font> ലഭ്യമായ<font color='red'><b>,</b></font> ഉപയോഗിക്കാവുന്ന
#
# avarice: അമിത ധനേച്ഛ<font color='red'><b>,</b></font> അമിതധനേച്ഛ<font color='red'><b>,</b></font> അതിധനലോഭം<font color='red'><b>,</b></font> ദുര്‍മ്മോഹം<font color='red'><b>,</b></font> അതിതൃഷ്ണ<font color='red'><b>,</b></font> അത്യാര്‍ത്തി<font color='red'><b>,</b></font> ദുര<font color='red'><b>,</b></font> ദുരാഗ്രഹം<font color='red'><b>,</b></font> അത്യാഗ്രഹം
#
# avaricious: ദുരാഗ്രഹി<font color='red'><b>,</b></font> ധനലോഭിയായ<font color='red'><b>,</b></font> അത്യാഗ്രഹമുളള<font color='red'><b>,</b></font> ദുരാഗ്രഹം നിറഞ്ഞ<font color='red'><b>,</b></font> ദുരാഗ്രഹമുള്ള<font color='red'><b>,</b></font> പണത്തിലാശയുളള
#
# average: സാമാന്യത്തോത്‌<font color='red'><b>,</b></font> സാമാന്യത്തോത്<font color='red'><b>,</b></font> ശരാശരി<font color='red'><b>,</b></font> സാധാരണ നിലവാരം<font color='red'><b>,</b></font> സാധാരണമായ<font color='red'><b>,</b></font> ഇടത്തരമായ<font color='red'><b>,</b></font> ശരാശരിയാക്കുക<font color='red'><b>,</b></font> സുമാര്‍<font color='red'><b>,</b></font> സാമാന്യമായ<font color='red'><b>,</b></font> ശരാശരിയായ
#
# aversion: വെറുപ്പ്‌<font color='red'><b>,</b></font> നീരസം<font color='red'><b>,</b></font> വൈമുഖ്യം<font color='red'><b>,</b></font> പ്രതികൂലം<font color='red'><b>,</b></font> അപ്രീതികരമായ വസ്‌തു<font color='red'><b>,</b></font> വെറുക്കപ്പെടുന്ന വസ്‌തു<font color='red'><b>,</b></font> വെറുപ്പ്<font color='red'><b>,</b></font> വെറുക്കപ്പെടുന്ന വസ്തു
#
# avidity: ആര്‍ത്തി<font color='red'><b>,</b></font> ഔത്സുക്യം
#
# awake: ഉണര്‍ച്ച വരുത്തുക<font color='red'><b>,</b></font> ഊര്‍ജ്ജസ്വലനാകുക<font color='red'><b>,</b></font> പ്രബുദ്ധമാക്കുക<font color='red'><b>,</b></font> ഉണരുക<font color='red'><b>,</b></font> ഉറക്കമുണര്‍ത്തുക<font color='red'><b>,</b></font> ഉറക്കമുണരുക<font color='red'><b>,</b></font> എഴുന്നേല്‍ക്കുക<font color='red'><b>,</b></font> ഉറക്കമുണര്‍ത്തുന്ന<font color='red'><b>,</b></font> ഉണര്‍ന്നിരിക്കുന്ന<font color='red'><b>,</b></font> ഉറങ്ങാത്ത<font color='red'><b>,</b></font> എഴുന്നേറ്റിരിക്കുന്ന<font color='red'><b>,</b></font> ജാഗ്രതയുളള<font color='red'><b>,</b></font> ഉറക്കം ഉണരുക<font color='red'><b>,</b></font> നിദ്ര ഉണര്‍ത്തുക
#
# awakened: ഉണര്‍ത്തപ്പെട്ട
#
# awakening: ഉണര്‍വ്‌<font color='red'><b>,</b></font> ഉണര്‍വ്വ്‌
#
# awe: ആദരസമന്വിതമായ അത്ഭുതം<font color='red'><b>,</b></font> അന്പരപ്പ്<font color='red'><b>,</b></font> അച്ചടക്കത്തോടെയുളള ഭയം<font color='red'><b>,</b></font> വിസ്‌മയം<font color='red'><b>,</b></font> സംഭ്രമം<font color='red'><b>,</b></font> ഭയഭക്തി
#
# awkward: പരുങ്ങലുളവാക്കുന്ന<font color='red'><b>,</b></font> വിലക്ഷണമായ<font color='red'><b>,</b></font> വികൃതമായ<font color='red'><b>,</b></font> ആപല്‍ക്കരമായ<font color='red'><b>,</b></font> കുഴഞ്ഞ<font color='red'><b>,</b></font> കുഴപ്പം പിടിച്ച<font color='red'><b>,</b></font> ശല്യമുണ്ടാക്കുന്ന <font color='red'><b>,</b></font> വിഷമകരമായ<font color='red'><b>,</b></font> ഉപയോഗിക്കാന്‍ വിഷമമുളള<font color='red'><b>,</b></font> അരോചകമായ
#
# awkwardness: കുഴപ്പം<font color='red'><b>,</b></font> വൈകൃതം<font color='red'><b>,</b></font> വൈഷമ്യം<font color='red'><b>,</b></font> വിലക്ഷണത<font color='red'><b>,</b></font> അശൗശലം
#
# axiomatic: സ്വതസ്സിദ്ധപ്രമാണരീതിയിലുള്ള
#
# azure: ആകാശവര്‍ണ്ണമായ<font color='red'><b>,</b></font> ആകാശനീലിമ<font color='red'><b>,</b></font> ആകാശനീലനിറമായ<font color='red'><b>,</b></font> ഇളംനീലിമയാര്‍ന്ന<font color='red'><b>,</b></font> പ്രശാന്തമായ<font color='red'><b>,</b></font> ആകാശനിറമായ<font color='red'><b>,</b></font> കാറും കോളുമില്ലാത്ത<font color='red'><b>,</b></font> നീലിമയേറിയ
#
# babble: വേഗത്തില്‍ സംസാരിക്കുക<font color='red'><b>,</b></font> ജല്‍പനം<font color='red'><b>,</b></font> വായാടി<font color='red'><b>,</b></font> ബാലിശസംസാരം<font color='red'><b>,</b></font> നിരര്‍ത്ഥസംഭാഷണം<font color='red'><b>,</b></font> കളകളാരവം<font color='red'><b>,</b></font> മര്‍മ്മരശബ്‌ദം<font color='red'><b>,</b></font> ജല്‌പകന്‍<font color='red'><b>,</b></font> ജല്‌പനം<font color='red'><b>,</b></font> ജല്പനം<font color='red'><b>,</b></font> മര്‍മ്മരശബ്ദം<font color='red'><b>,</b></font> ജല്പകന്‍<font color='red'><b>,</b></font> ചിലയ്‌ക്കുക<font color='red'><b>,</b></font> അസംബന്ധം പറയുക<font color='red'><b>,</b></font> ജല്‍പിക്കുക<font color='red'><b>,</b></font> പുലമ്പുക<font color='red'><b>,</b></font> അസ്‌പഷ്‌ടമായി ശബ്‌ദിക്കുക<font color='red'><b>,</b></font> ജല്‌പിക്കുക<font color='red'><b>,</b></font> മനസ്സിലാക്കാന്‍ പറ്റാത്തവണ്ണം ധൃതിയില്‍ സംസാരിക്കുക<font color='red'><b>,</b></font> വെള്ളം ഒഴുകുന്ന പോലെയുള്ള ശബ്‌ദമുണ്ടാക്കുക<font color='red'><b>,</b></font> ശ്രദ്ധക്കുറവുകൊണ്ട്‌ ഒരു രഹസ്യം വെളിപ്പെടുത്തുക<font color='red'><b>,</b></font> കുട്ടികളുടെ രീതിയില്‍ സംസാരിക്കുക
#
# babbler: വായാടി<font color='red'><b>,</b></font> വിടുവായന്‍
#
# babbling: ജല്‍പനം<font color='red'><b>,</b></font> ബാലിശസംസാരം<font color='red'><b>,</b></font> നിരര്‍ത്ഥസംഭാഷണം
#
# babel: കുഴപ്പത്തിന്റേയോ<font color='red'><b>,</b></font> നാനാവിധ ശബ്ദം<font color='red'><b>,</b></font> ശബ്ദകോലാഹലം<font color='red'><b>,</b></font> ശബ്‌ദം<font color='red'><b>,</b></font> കോലാഹലം<font color='red'><b>,</b></font> നാനാവിധശബ്‌ദം<font color='red'><b>,</b></font> കുഴച്ചിലിന്റെയോ രംഗം<font color='red'><b>,</b></font> അലപ്പ്‌<font color='red'><b>,</b></font> കോലാഹലം<font color='red'><b>,</b></font> ശബ്ദം<font color='red'><b>,</b></font> അലപ്പ്
#
# bachelor: അവിവാഹിതന്‍<font color='red'><b>,</b></font> കലാശാലാബിരുദധാരി<font color='red'><b>,</b></font> ബ്രഹ്മചാരി<font color='red'><b>,</b></font> സര്‍വ്വകലാശാല ബിരുദം നേടിയ വ്യക്തി
#
# backbone: പ്രധാന അവലംബം<font color='red'><b>,</b></font> നട്ടെല്ല്‌<font color='red'><b>,</b></font> സ്വാഭാവദാര്‍ഢ്യം<font color='red'><b>,</b></font> വളരെ വേഗത്തില്‍ വിവരങ്ങളുടെ കൈമാറ്റം സാധ്യമാക്കുന്ന ടെലികോം ലൈന്‍<font color='red'><b>,</b></font> ഏതെങ്കിലും തരത്തിലുള്ള വിവരവിനിമയ ഉപാധി
#
# bad: ചീത്ത<font color='red'><b>,</b></font> ദൗര്‍ഭാഗ്യം<font color='red'><b>,</b></font> മോശം<font color='red'><b>,</b></font> ജീര്‍ണ്ണിച്ച<font color='red'><b>,</b></font> താന്തോന്നിയായ<font color='red'><b>,</b></font> മോശമായ<font color='red'><b>,</b></font> സദാചാരവിരുദ്ധമായ<font color='red'><b>,</b></font> അയോഗ്യമായ<font color='red'><b>,</b></font> ചീത്തയായ<font color='red'><b>,</b></font> കൊള്ളരുതാത്ത<font color='red'><b>,</b></font> കേടുള്ള<font color='red'><b>,</b></font> പ്രയോജനശൂന്യമായ<font color='red'><b>,</b></font> ദൗര്‍ഭാഗ്യകരമായ<font color='red'><b>,</b></font> വേദനാകരമായ<font color='red'><b>,</b></font> സന്തോഷകരമല്ലാത്ത
#
# badinage: ലഘു പരിഹാസം<font color='red'><b>,</b></font> നര്‍മ്മോക്തി
#
# balanced: സംതുലിതമായ<font color='red'><b>,</b></font> സമീകൃതമായ
#
# baleful: വിനാശകരമായ<font color='red'><b>,</b></font> ഹാനികരമായ<font color='red'><b>,</b></font> കേടുള്ള<font color='red'><b>,</b></font> ദുഖകരമായ<font color='red'><b>,</b></font> ഉപദ്രവകരമായ<font color='red'><b>,</b></font> കെടുതിയായ<font color='red'><b>,</b></font> ക്ലേശപൂര്‍ണ്ണമായ
#
# balmy: സുഖപ്രദമായ<font color='red'><b>,</b></font> സുഗന്ധിയായ<font color='red'><b>,</b></font> സുഗന്ധമുള്ള<font color='red'><b>,</b></font> അനുനയസ്വഭാവമുള്ള<font color='red'><b>,</b></font> ശാന്തി ദായകമായ<font color='red'><b>,</b></font> താപശാന്തികരമായ
#
# baneful: നാശകരമായ<font color='red'><b>,</b></font> വിഷമയമായ
#
# bankrupt: പാപ്പരായവന്‍<font color='red'><b>,</b></font> കോടതി നിര്‍ദ്ധനനായി പ്രഖ്യാപിച്ചവന്‍<font color='red'><b>,</b></font> ദീപാളികുളിച്ചവന്‍<font color='red'><b>,</b></font> പാപ്പര്‍<font color='red'><b>,</b></font> നഷ്ടം നിര്‍ദ്ധനനായ കടക്കാരന്‍<font color='red'><b>,</b></font> കോടതി നിര്‍ദ്ധനനായി പ്രഖ്യാപിച്ചവന്‍<font color='red'><b>,</b></font> പാപ്പരായ<font color='red'><b>,</b></font> നിര്‍ദ്ധനനായ<font color='red'><b>,</b></font> നിര്‍ദ്ധനന്‍<font color='red'><b>,</b></font> കടങ്ങള്‍ വീട്ടാന്‍ കഴിവില്ലെന്നു നീതിന്യായക്കോടതിവിധിയുണ്ടായ വ്യക്തി<font color='red'><b>,</b></font> കടം വീട്ടാന്‍ ശേഷിയില്ലാത്ത പാവപ്പെട്ടവന്‍
#
# barbarism: അജ്ഞത<font color='red'><b>,</b></font> മൃഗീയത്വം<font color='red'><b>,</b></font> മ്ലച്ഛേസ്വഭാവം<font color='red'><b>,</b></font> കാടത്തം<font color='red'><b>,</b></font> സംസ്‌കാരമില്ലാത്ത ഭാഷാപ്രയോഗം<font color='red'><b>,</b></font> സംസ്കാരമില്ലാത്ത ഭാഷാപ്രയോഗം
#
# barbarity: അജ്ഞത<font color='red'><b>,</b></font> മ്ലച്ഛേം<font color='red'><b>,</b></font> മൃഗീയത്വം<font color='red'><b>,</b></font> ദുഷ്‌ടത<font color='red'><b>,</b></font> കാടത്തം<font color='red'><b>,</b></font> മൃഗീയത<font color='red'><b>,</b></font> ദുഷ്ടത<font color='red'><b>,</b></font> അസംസ്‌കൃതി<font color='red'><b>,</b></font> സംസ്‌ക്കാരമില്ലാത്ത ഭാഷാ പ്രയോഗം<font color='red'><b>,</b></font> അസംസ്കൃതി<font color='red'><b>,</b></font> സംസ്ക്കാരമില്ലാത്ത ഭാഷാ പ്രയോഗം
#
# barbarous: അപരിഷ്‌കൃതന്‍<font color='red'><b>,</b></font> അപരിഷ്കൃതമായ<font color='red'><b>,</b></font> ദുഷ്‌ടനായ<font color='red'><b>,</b></font> കിരാതമായ
#
# bards: സ്‌തുതിപാഠകന്‍<font color='red'><b>,</b></font> ഏത്താളന്‍
#
# bare: നഗ്നമാക്കുക<font color='red'><b>,</b></font> വെളിപ്പെടുത്തുക<font color='red'><b>,</b></font> വസ്‌ത്രം അഴിക്കുക<font color='red'><b>,</b></font> ഉരിയുക<font color='red'><b>,</b></font> തുറന്നിടുക<font color='red'><b>,</b></font> ആവരണം കളയുക<font color='red'><b>,</b></font> ലളിതമായ<font color='red'><b>,</b></font> സ്‌പഷ്‌ടമായ<font color='red'><b>,</b></font> ശൂന്യമായ<font color='red'><b>,</b></font> നഗ്നമായ<font color='red'><b>,</b></font> വസ്‌ത്രമില്ലാത്ത<font color='red'><b>,</b></font> അനാവൃതമായ<font color='red'><b>,</b></font> അടിസ്ഥാനപരമായ<font color='red'><b>,</b></font> അനലംകൃതമായ<font color='red'><b>,</b></font> സ്പഷ്ടമായ<font color='red'><b>,</b></font> ഒഴിഞ്ഞിരിക്കുന്ന<font color='red'><b>,</b></font> മറയ്‌ക്കപ്പെടാത്ത<font color='red'><b>,</b></font> മറയ്ക്കപ്പെടാത്ത
#
# barest: ശൂന്യമായ
#
# <font color='red'><b>,</b></font> നഗ്നമായ
#
# bargain: വിലപേശല്‍<font color='red'><b>,</b></font> വില്‍പ്പന<font color='red'><b>,</b></font> ഉടമ്പടി<font color='red'><b>,</b></font> ഒത്തുതീര്‍പ്പ്‌<font color='red'><b>,</b></font> വില്‍പനക്കാരന്‍<font color='red'><b>,</b></font> ക്രയസാധനം<font color='red'><b>,</b></font> കച്ചവടം<font color='red'><b>,</b></font> വില്‍പാനുള്ള നിശ്ചയം<font color='red'><b>,</b></font> അനുകൂലമായ ഏര്‍പ്പാട്‌<font color='red'><b>,</b></font> വിലപേശല്‍<font color='red'><b>,</b></font> വില്‌പനക്കരാര്‍<font color='red'><b>,</b></font> അനുകൂല ഇടപാട്‌<font color='red'><b>,</b></font> ലാഭകരമായ ഏര്‍പ്പാട്‌<font color='red'><b>,</b></font> ഉടന്പടി<font color='red'><b>,</b></font> വില്പനക്കരാര്‍<font color='red'><b>,</b></font> ഒത്തു തീര്‍പ്പ്<font color='red'><b>,</b></font> അനുകൂല ഇടപാട്<font color='red'><b>,</b></font> ലാഭകരമായ ഏര്‍പ്പാട്<font color='red'><b>,</b></font> പ്രതിഫലത്തിനു കൈമാറുക<font color='red'><b>,</b></font> വിലപേശുക<font color='red'><b>,</b></font> വില തീര്‍ച്ചയാക്കുക<font color='red'><b>,</b></font> ആദായമുള്ള<font color='red'><b>,</b></font> വാങ്ങല്‍ എന്നിവയുമായി ബന്ധപ്പെട്ട കരാറുകള്‍ ഉണ്ടാക്കുക
#
# barren: തരിശായ<font color='red'><b>,</b></font> വ്യര്‍ത്ഥമായ<font color='red'><b>,</b></font> പ്രസവിക്കാത്ത<font color='red'><b>,</b></font> വിളയാത്ത<font color='red'><b>,</b></font> കായ്‌ക്കാത്ത<font color='red'><b>,</b></font> വന്ധ്യയായ<font color='red'><b>,</b></font> ധാന്യങ്ങള്‍ വിളയിക്കുന്നതിന്‌ അനുയോജ്യമല്ലാത്ത<font color='red'><b>,</b></font> ഫലിക്കാത്ത<font color='red'><b>,</b></font> തരിശ്നിലം<font color='red'><b>,</b></font> കായ്ക്കാത്ത<font color='red'><b>,</b></font> ധാന്യങ്ങള്‍ വിളയിക്കുന്നതിന് അനുയോജ്യമല്ലാത്ത
#
# barrier: അതിര്‌<font color='red'><b>,</b></font> തടസ്സം<font color='red'><b>,</b></font> പ്രതിബന്ധം<font color='red'><b>,</b></font> സീമ<font color='red'><b>,</b></font> വിഘ്‌നം<font color='red'><b>,</b></font> ശത്രുനിരോധം<font color='red'><b>,</b></font> വേലിതടസ്സം<font color='red'><b>,</b></font> വിഭജനരേഖ<font color='red'><b>,</b></font> ആക്രമണം തടയാനുള്ള തടസ്സം<font color='red'><b>,</b></font> ചലനത്തിന് തടസ്സം സൃഷ്ടിക്കുന്ന വസ്തു
#
# barrister: വക്കീല്‍<font color='red'><b>,</b></font> അഭിഭാഷകന്‍<font color='red'><b>,</b></font> ന്യായവാദി
#
# base: ആരംഭം<font color='red'><b>,</b></font> ഹേതു<font color='red'><b>,</b></font> അടിസ്ഥാനം<font color='red'><b>,</b></font> വാരം<font color='red'><b>,</b></font> തറ<font color='red'><b>,</b></font> സൈന്യത്തിന്റെ പുറകിലായി ഭക്ഷ്യവസ്‌തുക്കളും ആയുധങ്ങളും മറ്റും സംഭരിച്ചിട്ടുള്ള താവളം<font color='red'><b>,</b></font> അടിത്തറ<font color='red'><b>,</b></font> പ്രധാന ഘടകം<font color='red'><b>,</b></font> ആസ്‌തിവാരം<font color='red'><b>,</b></font> ആരംഭസ്ഥാനം<font color='red'><b>,</b></font> കുതിരപ്പന്തയത്തറ<font color='red'><b>,</b></font> മലയുടെ അടിവാരം<font color='red'><b>,</b></font> ഔഷധയോഗത്തിലെ പ്രധാന മരുന്ന്‌<font color='red'><b>,</b></font> അടിവാരം<font color='red'><b>,</b></font> പ്രവര്‍ത്തനത്തിന്റെ ആസ്ഥാനം<font color='red'><b>,</b></font> പ്രധാനപ്പെട്ട ഘടകപദാര്‍ത്ഥം<font color='red'><b>,</b></font> പന്തയഓട്ടത്തിലെ പ്രാരംഭസ്ഥാനം<font color='red'><b>,</b></font> അവലംബിക്കുക<font color='red'><b>,</b></font> സ്ഥാപിക്കുക<font color='red'><b>,</b></font> അസ്‌തിവാരമാക്കുക<font color='red'><b>,</b></font> ആധാരമാക്കുക<font color='red'><b>,</b></font> അടിസ്ഥാനമാക്കുക<font color='red'><b>,</b></font> ഹീനമായ<font color='red'><b>,</b></font> നിന്ദ്യമായ<font color='red'><b>,</b></font> അധഃപതിച്ച<font color='red'><b>,</b></font> നികൃഷ്‌ടമായ<font color='red'><b>,</b></font> വ്യാജമായ<font color='red'><b>,</b></font> ക്ഷുദ്രമായ<font color='red'><b>,</b></font> വിലകെട്ട<font color='red'><b>,</b></font> അധമമായ<font color='red'><b>,</b></font> സത്യസന്ധമല്ലാത്ത<font color='red'><b>,</b></font> അകുലീനമായ<font color='red'><b>,</b></font> അധാര്‍മ്മികമായ<font color='red'><b>,</b></font> ശുദ്ധമല്ലാത്ത<font color='red'><b>,</b></font> അപകൃഷ്‌ടമായ<font color='red'><b>,</b></font> ഹീനകുലമായ<font color='red'><b>,</b></font> അജാതമായ<font color='red'><b>,</b></font> അപകൃഷ്ടമായ
#
# baseless: അടിസ്ഥാനമില്ലാത്ത<font color='red'><b>,</b></font> അടിസ്ഥാനരഹിതമായ<font color='red'><b>,</b></font> അടിത്തറയില്ലാത്ത
#
# bashful: ആത്മവിശ്വാസമില്ലാത്ത<font color='red'><b>,</b></font> ലജ്ജാശീലമുള്ള<font color='red'><b>,</b></font> സഭാകമ്പമുള്ള<font color='red'><b>,</b></font> നാണിക്കുന്ന<font color='red'><b>,</b></font> അടക്കമുള്ള<font color='red'><b>,</b></font> ലജ്ജയുള്ള<font color='red'><b>,</b></font> ലജ്ജാശീലമുളള
#
# basic: ബിഗിനേഴ്‌സ്‌ ആള്‍ പര്‍പ്പസ്‌ സിംബോളിക്‌ ഇന്‍സ്‌ട്രക്ഷന്‍ കോഡ്‌<font color='red'><b>,</b></font> ലളിതമായ ഒരു കമ്പ്യൂട്ടര്‍ പ്രോഗ്രാമിംഗ്‌ ഭാഷ<font color='red'><b>,</b></font> ഏറ്റവും അടിസ്ഥാനമായ<font color='red'><b>,</b></font> മൗലികമായ<font color='red'><b>,</b></font> അടിസ്ഥാനമായ<font color='red'><b>,</b></font> അടിസ്ഥാനപരമായ<font color='red'><b>,</b></font> ആധാരഭൂതമായ<font color='red'><b>,</b></font> വളരെ ലളിതമായ<font color='red'><b>,</b></font> വെണ്‍കല്ലിന്റെ അംശം കുറഞ്ഞ<font color='red'><b>,</b></font> ക്ഷാരഗുണമുള്ള<font color='red'><b>,</b></font> വെണ്‍കല്ലിന്‍റെ അംശം കുറഞ്ഞ
#
# basis: അടിസ്ഥാനം<font color='red'><b>,</b></font> ആധാരം<font color='red'><b>,</b></font> ആസ്‌പദം<font color='red'><b>,</b></font> മുഖ്യപ്രമാണം
#
# battered: കേടുവന്ന<font color='red'><b>,</b></font> ഇടിച്ചുതകര്‍ന്നതായ<font color='red'><b>,</b></font> തേഞ്ഞുപോയ<font color='red'><b>,</b></font> തേഞ്ഞുപോയ
#
# battle: യുദ്ധം<font color='red'><b>,</b></font> മത്സരം<font color='red'><b>,</b></font> കലഹം<font color='red'><b>,</b></font> പോരാട്ടം<font color='red'><b>,</b></font> അങ്കം<font color='red'><b>,</b></font> പട<font color='red'><b>,</b></font> ഒന്നിലധികം വ്യക്തികള്‍ തമ്മിലുള്ള വാദപ്രതിവാദം<font color='red'><b>,</b></font> പൊരുതുക<font color='red'><b>,</b></font> യുദ്ധം ചെയ്യുക
#
# beam: തടി<font color='red'><b>,</b></font> ദണ്‌ഡ്‌<font color='red'><b>,</b></font> കപ്പലിന്റെ തുലാത്തണ്ട്‌<font color='red'><b>,</b></font> രശ്‌മി<font color='red'><b>,</b></font> രശ്മി<font color='red'><b>,</b></font> തുലാം<font color='red'><b>,</b></font> ഒറ്റത്തടി<font color='red'><b>,</b></font> ഉത്തരം<font color='red'><b>,</b></font> കിരണം<font color='red'><b>,</b></font> പ്രകാശകിരണം<font color='red'><b>,</b></font> തടിമരം<font color='red'><b>,</b></font> സൂര്യകിരണം<font color='red'><b>,</b></font> പ്രസന്നമായ പ്രകൃതം<font color='red'><b>,</b></font> വണ്ടിത്തണ്ട്‌<font color='red'><b>,</b></font> ദണ്ഡ്<font color='red'><b>,</b></font> വണ്ടിത്തണ്ട്<font color='red'><b>,</b></font> തിളങ്ങുക<font color='red'><b>,</b></font> പ്രകാശിക്കുക<font color='red'><b>,</b></font> പുഞ്ചിരിതൂകുക<font color='red'><b>,</b></font> പുഞ്ചിരിക്കുക<font color='red'><b>,</b></font> പ്രകാശം പരത്തുക<font color='red'><b>,</b></font> മന്ദഹസിക്കുക<font color='red'><b>,</b></font> ടെലിവിഷന്‍ പരിപാടി സംപ്രഷണം ചെയ്യുക
#
# beaming: പ്രകാശം
#
# bearing: ഒരു വ്യക്തിയുടെ നടത്തരീതി<font color='red'><b>,</b></font> പെരുമാറ്റം<font color='red'><b>,</b></font> വഹിക്കല്‍<font color='red'><b>,</b></font> സ്ഥിതി മുതലായവ<font color='red'><b>,</b></font> സഹിക്കുന്ന<font color='red'><b>,</b></font> താങ്ങുന്ന<font color='red'><b>,</b></font> ഏറ്റുന്ന<font color='red'><b>,</b></font> വഹിക്കുന്ന<font color='red'><b>,</b></font> താരതമ്യേനയുളള നില
#
# beatific: മുക്ത്യരുളുക
#
# beating: അടി<font color='red'><b>,</b></font> പ്രഹരം<font color='red'><b>,</b></font> പ്രഹരിക്കല്‍
#
# beauties: സുന്ദരിമാര്‍
#
# beautiful: മനോഹരമായ<font color='red'><b>,</b></font> അഴകുള്ള<font color='red'><b>,</b></font> രമണീയമായ<font color='red'><b>,</b></font> സൗന്ദര്യമുള്ള<font color='red'><b>,</b></font> ഹൃദ്യമായ<font color='red'><b>,</b></font> കര്‍ണ്ണസുഖപ്രദമായ<font color='red'><b>,</b></font> നയനസുഭഗമായ<font color='red'><b>,</b></font> ആനന്ദകരമായ<font color='red'><b>,</b></font> മനോഹരമായ<font color='red'><b>,</b></font> മനോഹാരിതയുള്ള<font color='red'><b>,</b></font> സൗന്ദര്യമുളള<font color='red'><b>,</b></font> മനോഹാരമായ<font color='red'><b>,</b></font> മനോഹാരിതയുള്ള
#
# beautify: അലങ്കരിക്കുക<font color='red'><b>,</b></font> ഭംഗിവരുത്തുക<font color='red'><b>,</b></font> സുന്ദരമാക്കുക<font color='red'><b>,</b></font> മനോഹരമാക്കുക<font color='red'><b>,</b></font> ചന്തം വരുത്തുക<font color='red'><b>,</b></font> മനോഹരമാക്കുക
#
# beauty: അലങ്കാരം<font color='red'><b>,</b></font> സുന്ദരി<font color='red'><b>,</b></font> പ്രയോജനം<font color='red'><b>,</b></font> ചാരുത്വം<font color='red'><b>,</b></font> സൗന്ദര്യം<font color='red'><b>,</b></font> ലക്ഷണം<font color='red'><b>,</b></font> അഴക്‌<font color='red'><b>,</b></font> ലാവണ്യം<font color='red'><b>,</b></font> ഭൂഷണം<font color='red'><b>,</b></font> ചമല്‍ക്കാരം<font color='red'><b>,</b></font> ചന്തം<font color='red'><b>,</b></font> പ്രയോജനം<font color='red'><b>,</b></font> എന്തിന്റെയെങ്കിലും മഹത്തരമായ ഉദാഹരണം<font color='red'><b>,</b></font> മനോഹാരിത
#
# <font color='red'><b>,</b></font> അഴക്<font color='red'><b>,</b></font> എന്തിന്‍റെയെങ്കിലും മഹത്തരമായ ഉദാഹരണം<font color='red'><b>,</b></font> മനോഹരന്‍
#
# beckoning: ആംഗ്യംകാട്ടിവിളിക്കല്‍
#
# becoming: അനുരൂപമായ<font color='red'><b>,</b></font> ഉചിതമായ<font color='red'><b>,</b></font> യുക്തമായ<font color='red'><b>,</b></font> ആകര്‍ഷകമായ<font color='red'><b>,</b></font> ഉപോല്‍പന്നമായ<font color='red'><b>,</b></font> ഏറ്റവും യോജിച്ച<font color='red'><b>,</b></font> ഏറ്റവും യോജിച്ച
#
# bedraggled: മലിനമായ
#
# befitting: യോജിച്ച
#
# beg: അഭ്യര്‍ത്ഥിക്കുക<font color='red'><b>,</b></font> യാചിക്കുക<font color='red'><b>,</b></font> ഇരക്കുക
#
# beggar: തെണ്ടി<font color='red'><b>,</b></font> ഭിക്ഷക്കാരന്‍<font color='red'><b>,</b></font> യാചകന്‍<font color='red'><b>,</b></font> അപേക്ഷകന്‍<font color='red'><b>,</b></font> ഭിക്ഷു<font color='red'><b>,</b></font> ഹര്‍ജ്ജിക്കാരന്‍<font color='red'><b>,</b></font> ദരിദ്രമാക്കുക<font color='red'><b>,</b></font> ഭിക്ഷ ആക്കിത്തീര്‍ക്കുക
#
# beggarly: ദരിദ്രമായ<font color='red'><b>,</b></font> താണതരത്തിലുള്ള<font color='red'><b>,</b></font> വെറുക്കത്തക്ക<font color='red'><b>,</b></font> തുച്ഛമായ<font color='red'><b>,</b></font> നിര്‍ദ്ധനമായ<font color='red'><b>,</b></font> ബുദ്ധിഹീനമായ<font color='red'><b>,</b></font> അല്‌പം മാത്രമുള്ള<font color='red'><b>,</b></font> അല്പം മാത്രമുള്ള
#
# beginning: തുടക്കം<font color='red'><b>,</b></font> ആരംഭം<font color='red'><b>,</b></font> മൂലം<font color='red'><b>,</b></font> മൂലാധാരം<font color='red'><b>,</b></font> ആദികാരണം
#
# belated: വളരെ താമസിച്ചെത്തിയ<font color='red'><b>,</b></font> വൈകിയ<font color='red'><b>,</b></font> താമസിച്ച
#
# belief: നിശ്ചയം<font color='red'><b>,</b></font> ധാരണ<font color='red'><b>,</b></font> ശ്രദ്ധ<font color='red'><b>,</b></font> അഭിപ്രായം<font color='red'><b>,</b></font> വിശ്വാസം<font color='red'><b>,</b></font> മതവിശ്വാസം<font color='red'><b>,</b></font> വിശ്വാസംപ്രമാണം<font color='red'><b>,</b></font> വിചാരം<font color='red'><b>,</b></font> അഭിമതം<font color='red'><b>,</b></font> വാസ്‌തവമായംഗീകരക്കല്‍
#
# belittling: താഴ്‌ത്തിക്കെട്ടുക<font color='red'><b>,</b></font> നിസ്സാരമാക്കി കാണിക്കുക
#
# bellicose: കലഹപ്രിയനായ<font color='red'><b>,</b></font> ശണ്‌ഠകൂടുന്ന<font color='red'><b>,</b></font> യുദ്ധത്തില്‍ താല്‌പര്യം കാണിക്കുന്ന<font color='red'><b>,</b></font> ശണ്ഠകൂടുന്ന<font color='red'><b>,</b></font> യുദ്ധത്തില്‍ താല്പര്യം കാണിക്കുന്ന
#
# benediction: ശുഭാശംസ<font color='red'><b>,</b></font> പളളിയിലെ ഒരുതരം പ്രാര്‍ത്ഥന<font color='red'><b>,</b></font> അനുഗ്രഹം<font color='red'><b>,</b></font> ആശീര്‍വാദം<font color='red'><b>,</b></font> ശുഭാശംസ<font color='red'><b>,</b></font> ആശീര്‍വ്വാദം<font color='red'><b>,</b></font> പള്ളിയിലെ പ്രാര്‍ത്ഥനാചടങ്ങ്‌ അവസാനിക്കുന്ന നേരത്തുള്ള ശുഭാശംസ<font color='red'><b>,</b></font> ആഹാരത്തിനു മുമ്പ്‌ നടത്തുന്ന വാഴ്‌ത്ത്‌<font color='red'><b>,</b></font> ധന്യവാദം<font color='red'><b>,</b></font> മംഗളാചരണം<font color='red'><b>,</b></font> പള്ളിയിലെ പ്രാര്‍ത്ഥനാചടങ്ങ് അവസാനിക്കുന്ന നേരത്തുള്ള ശുഭാശംസ<font color='red'><b>,</b></font> ആഹാരത്തിനു മുന്പ് നടത്തുന്ന വാഴ്ത്ത്
#
# benefactor: അഭ്യുദയകാംക്ഷി<font color='red'><b>,</b></font> ഉപകാരി<font color='red'><b>,</b></font> ധനസഹായി<font color='red'><b>,</b></font> ഉപകര്‍ത്താവ്‌<font color='red'><b>,</b></font> ഹിതകരന്‍<font color='red'><b>,</b></font> ഹിതകാരി<font color='red'><b>,</b></font> ധര്‍മ്മിഷ്‌ഠന്‍<font color='red'><b>,</b></font> ഉപകര്‍ത്താവ്<font color='red'><b>,</b></font> ധര്‍മ്മിഷ്ഠന്‍
#
# beneficent: ദാനശീലമുള്ള<font color='red'><b>,</b></font> ഉദാരപ്രകൃതിയായ
#
# beneficial: പ്രയോജനകരമായ<font color='red'><b>,</b></font> അനുകൂലമായ<font color='red'><b>,</b></font> ഗുണപ്രദമായ<font color='red'><b>,</b></font> ഉപകാരപ്രദമായ<font color='red'><b>,</b></font> സ്വത്തിന്റെ അവകാശവും ഗുണവും അനുഭവിക്കുന്ന<font color='red'><b>,</b></font> ഉപകാരമുള്ളത്<font color='red'><b>,</b></font> പ്രയോജനകരമായ<font color='red'><b>,</b></font> സ്വത്തിന്‍റെ അവകാശവും ഗുണവും അനുഭവിക്കുന്ന
#
# benefit: ആനുകൂല്യം<font color='red'><b>,</b></font> വേതനം<font color='red'><b>,</b></font> ആദായം<font color='red'><b>,</b></font> പ്രയോജനം<font color='red'><b>,</b></font> അനുഗ്രഹം<font color='red'><b>,</b></font> ലാഭം<font color='red'><b>,</b></font> ബത്ത<font color='red'><b>,</b></font> ഉപകാരം<font color='red'><b>,</b></font> നന്മ<font color='red'><b>,</b></font> പ്രയോജനം<font color='red'><b>,</b></font> ജോലിയില്‍ നിന്നു മാറിയവര്‍ക്കോ അസുഖം ബാധിച്ചവര്‍ക്കോ നല്‍കുന്ന സഹായധനം<font color='red'><b>,</b></font> ജോലിയില്‍ നിന്നു മാറിയവര്‍ക്കോ അസുഖം ബാധിച്ചവര്‍ക്കോ നല്‍കുന്ന സഹായധനം<font color='red'><b>,</b></font> ഉപകരിക്കുക<font color='red'><b>,</b></font> അനുകൂലിക്കുക<font color='red'><b>,</b></font> അനുഗ്രഹിക്കുക<font color='red'><b>,</b></font> നന്‍മചെയ്യുക<font color='red'><b>,</b></font> ആനുകൂല്യം ലഭിക്കുക<font color='red'><b>,</b></font> പ്രയോജനകീഭവിക്കുക<font color='red'><b>,</b></font> അഭിവൃദ്ധിയുണ്ടാകുക<font color='red'><b>,</b></font> ഉതക്കുക<font color='red'><b>,</b></font> പ്രയോജനം ചെയ്യുക
#
# benevolence: സംഭാവന<font color='red'><b>,</b></font> ഔദാര്യം<font color='red'><b>,</b></font> മനുഷ്യസ്‌നേഹം<font color='red'><b>,</b></font> പരോപകാരതത്‌പരത<font color='red'><b>,</b></font> ദയാശീലം<font color='red'><b>,</b></font> ഉദാരമനസ്‌കത<font color='red'><b>,</b></font> ഉദാരമനസ്കത
#
# benevolent: കരുണയുള്ള<font color='red'><b>,</b></font> ദയയുളള<font color='red'><b>,</b></font> ദയാലുവായ<font color='red'><b>,</b></font> ഉദാരമതിയായ<font color='red'><b>,</b></font> കൃപയുള്ള<font color='red'><b>,</b></font> ദയയുള്ള<font color='red'><b>,</b></font> നല്ല കാര്യം ഇച്ഛിക്കുന്ന<font color='red'><b>,</b></font> പ്രതിഫലേച്ഛ കൂടാതെ നല്ലകാര്യം ചെയ്യുന്ന<font color='red'><b>,</b></font> പരോപകാരബുദ്ധിയുള്ള<font color='red'><b>,</b></font> പരോപകാരബുദ്ധിയുള്ള
#
# benighted: ബുദ്ധിശൂന്യമായ<font color='red'><b>,</b></font> ഇരുട്ടിലകപ്പെട്ട<font color='red'><b>,</b></font> അജ്ഞാനാന്ധകാരത്തിലായ
#
# benign: കരുണയുള്ള<font color='red'><b>,</b></font> ദയയുളള<font color='red'><b>,</b></font> സൗമ്യമായ<font color='red'><b>,</b></font> അനുകമ്പയുള്ള<font color='red'><b>,</b></font> ദയയുള്ള<font color='red'><b>,</b></font> ഹിതകരമായ<font color='red'><b>,</b></font> കരുണാമയമായ<font color='red'><b>,</b></font> അപകടകരമല്ലാത്ത<font color='red'><b>,</b></font> തീവ്രമല്ലാത്ത
#
# benignant: കാരുണ്യമുള്ള<font color='red'><b>,</b></font> ഹിതകാരിയായ
#
# bent: പ്രവണത<font color='red'><b>,</b></font> വക്രത<font color='red'><b>,</b></font> ചായ്‌വ്‌<font color='red'><b>,</b></font> നിപുണത<font color='red'><b>,</b></font> അഭിരുചി<font color='red'><b>,</b></font> ജന്മനായുള്ള കഴിവ്‌<font color='red'><b>,</b></font> സ്വന്തം അഭിരുചിക്കനുസൃതമായി പ്രവര്‍ത്തിക്കുക<font color='red'><b>,</b></font> ആഭിമുഖ്യം<font color='red'><b>,</b></font> ചായ്‌വ്‌<font color='red'><b>,</b></font> വളഞ്ഞ<font color='red'><b>,</b></font> ആത്മാര്‍ത്ഥതയില്ലാത്ത<font color='red'><b>,</b></font> ദൃഢനിശ്ചയമുള്ള<font color='red'><b>,</b></font> വക്രതയുള്ള<font color='red'><b>,</b></font> സ്വവര്‍ഗ്ഗഭോഗിയായ<font color='red'><b>,</b></font> സ്വവര്‍ഗ്ഗഭോഗിയായ
#
# benumbed: അന്തര്‍ലീനമായ
#
# bereavement: നഷ്‌ടം<font color='red'><b>,</b></font> വിയോഗം<font color='red'><b>,</b></font> വിരഹം<font color='red'><b>,</b></font> മരണത്താലുണ്ടാകുന്ന വേര്‍പാട്‌<font color='red'><b>,</b></font> മരണവിയോഗം<font color='red'><b>,</b></font> മരണംകൊണ്ട്‌ പിരിയല്‍<font color='red'><b>,</b></font> മരണദുഃഖം
#
# beset: ചിരഭ്യസ്‌തപാപശീലം<font color='red'><b>,</b></font> വളഞ്ഞ് ആക്രമിക്കുക<font color='red'><b>,</b></font> അസഹ്യപ്പെടുത്തുക<font color='red'><b>,</b></font> ഞെരുക്കുക<font color='red'><b>,</b></font> ബുദ്ധിമുട്ടിക്കുക<font color='red'><b>,</b></font> ചുറ്റിവളയുക<font color='red'><b>,</b></font> അടയുക<font color='red'><b>,</b></font> ശല്യം ചെയ്യുക
#
# bestial: മൃഗീയമായ<font color='red'><b>,</b></font> മൃഗതുല്യമായ
#
# bestowing: നല്‍കല്‍
#
# bewildered: പേടിച്ചരണ്ട<font color='red'><b>,</b></font> ഞെട്ടല്‍<font color='red'><b>,</b></font> പരിഭ്രാന്തമായ
#
# bewilderment: സംഭ്രമം<font color='red'><b>,</b></font> അന്പരപ്പ്<font color='red'><b>,</b></font> ഞെട്ടല്‍<font color='red'><b>,</b></font> പരിഭ്രാന്തി<font color='red'><b>,</b></font> ആശ്ചര്യം  ഞെട്ടല്‍  ദു:ഖം തുടങ്ങി മാനസിക വികാരാധികളെ കുറിക്കുന്ന പദം
#
# bewitch: മയക്കുക<font color='red'><b>,</b></font> ആനന്ദിപ്പിക്കുക<font color='red'><b>,</b></font> വശീകരിക്കുക<font color='red'><b>,</b></font> അതിയായി ആനന്ദിപ്പിക്കുക<font color='red'><b>,</b></font> ആകര്‍ഷിക്കുക<font color='red'><b>,</b></font> മോഹിപ്പിക്കുക<font color='red'><b>,</b></font> ആഭിചാരത്താല്‍ സ്വാധീനിക്കുക<font color='red'><b>,</b></font> മന്ത്രവാദത്തിലൂടെ വശീകരിക്കുക
#
# bewitching: വശ്യമായ
#
# beyond: കൂടുതലായി<font color='red'><b>,</b></font> വിദൂരത്തില്‍<font color='red'><b>,</b></font> അഗോചരമായി<font color='red'><b>,</b></font> അതിദൂരത്തായി<font color='red'><b>,</b></font> അതീതമായി<font color='red'><b>,</b></font> കൂടുതലായി<font color='red'><b>,</b></font> അകലെ<font color='red'><b>,</b></font> അപ്പുറത്ത്‌<font color='red'><b>,</b></font> പുറമേ<font color='red'><b>,</b></font> മറുവശത്ത്‌<font color='red'><b>,</b></font> അതിരുകടന്ന്‌<font color='red'><b>,</b></font> ഉപരി<font color='red'><b>,</b></font> അപ്പുറം<font color='red'><b>,</b></font> മീതേ<font color='red'><b>,</b></font> പിന്നീട്<font color='red'><b>,</b></font> മനസ്സിലാക്കാനൊക്കാത്ത<font color='red'><b>,</b></font> കഴിഞ്ഞ്
#
# bibulous: മദ്യാസക്തനായ
#
# big-
#
# bigoted: മര്‍ക്കടമുഷ്‌ടിയുള്ള<font color='red'><b>,</b></font> സ്വാഭിപ്രായമുള്ള
#
# bigotry: മതഭ്രാന്ത്‌<font color='red'><b>,</b></font> ആശയഭ്രാന്ത്‌<font color='red'><b>,</b></font> മര്‍ക്കടമുഷ്‌ടി<font color='red'><b>,</b></font> എതിരഭിപ്രായം<font color='red'><b>,</b></font> വിമുഖത<font color='red'><b>,</b></font> മതഭ്രാന്ത്<font color='red'><b>,</b></font> ആശയഭ്രാന്ത്
#
# binding: പുസ്‌തകത്തിന്റെ തുന്നലും കെട്ടും<font color='red'><b>,</b></font> കെട്ട്‌<font color='red'><b>,</b></font> ബന്ധനം<font color='red'><b>,</b></font> ചട്ട<font color='red'><b>,</b></font> പുറംചട്ട<font color='red'><b>,</b></font> തടുക്കുന്ന<font color='red'><b>,</b></font> ബന്ധിക്കുന്ന<font color='red'><b>,</b></font> തടയുന്ന<font color='red'><b>,</b></font> വിലക്കുന്ന<font color='red'><b>,</b></font> നിര്‍ബന്ധമാക്കുന്ന<font color='red'><b>,</b></font> മുറുകിക്കിടക്കുന്ന<font color='red'><b>,</b></font> ബാധ്യസ്ഥനായ
#
# biography: ജീവചരിത്രം<font color='red'><b>,</b></font> ജന്തുവിജ്ഞാനീയം
#
# birth: ഉത്ഭവം<font color='red'><b>,</b></font> ഉത്‌പത്തി<font color='red'><b>,</b></font> പ്രസവം<font color='red'><b>,</b></font> തുടക്കം<font color='red'><b>,</b></font> ആരംഭം<font color='red'><b>,</b></font> ഉദയം<font color='red'><b>,</b></font> വംശം<font color='red'><b>,</b></font> കുലം<font color='red'><b>,</b></font> അവതാരം<font color='red'><b>,</b></font> ജനനം<font color='red'><b>,</b></font> കുലീനത്വം<font color='red'><b>,</b></font> ഉദ്‌ഭവം<font color='red'><b>,</b></font> കുടുംബന്ത്രണം<font color='red'><b>,</b></font> പിറവി<font color='red'><b>,</b></font> പുനര്‍ജ്ജനനം
#
# bite: മുറിവായ്‌<font color='red'><b>,</b></font> ദംശനം<font color='red'><b>,</b></font> കൊത്ത്‌<font color='red'><b>,</b></font> ചവയ്‌ക്കുക<font color='red'><b>,</b></font> നശിപ്പിക്കുക<font color='red'><b>,</b></font> കൊത്തുക<font color='red'><b>,</b></font> കടിക്കുക<font color='red'><b>,</b></font> വേദനപ്പെടുത്തുക<font color='red'><b>,</b></font> റാഞ്ചുക<font color='red'><b>,</b></font> അമ്ലം കൊണ്ട്‌ ദ്രവിപ്പിക്കുക<font color='red'><b>,</b></font> ശകാരിച്ചു വ്രണപ്പെടുത്തുക<font color='red'><b>,</b></font> കൊത്തുക<font color='red'><b>,</b></font> അമ്ലം കൊണ്ട് ദ്രവിപ്പിക്കുക
#
# bits: ശകലങ്ങള്‍
#
# bitter: കൊടിയ<font color='red'><b>,</b></font> കയ്പുരുചിയുളള<font color='red'><b>,</b></font> വേദനാപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> തീവ്രമായ<font color='red'><b>,</b></font> പരുഷമായ<font color='red'><b>,</b></font> കയ്‌പുരസമുള്ള<font color='red'><b>,</b></font> ചവര്‍പ്പുള്ള<font color='red'><b>,</b></font> കഠോരമായ<font color='red'><b>,</b></font> ദുഃഖപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> തിക്തമായ<font color='red'><b>,</b></font> ശോകമയമായ<font color='red'><b>,</b></font> ദേഷ്യം തോന്നുന്ന<font color='red'><b>,</b></font> കഠോരമായ<font color='red'><b>,</b></font> കയ്പുരസമുള്ള<font color='red'><b>,</b></font> ശോകമയമായ<font color='red'><b>,</b></font> ദേഷ്യം തോന്നുന്ന
#
# bitterness: കയ്‌പ്പ<font color='red'><b>,</b></font> ഒരു രുചി<font color='red'><b>,</b></font> വിദ്വേഷം<font color='red'><b>,</b></font> പാരുഷ്യം<font color='red'><b>,</b></font> കഠോരത<font color='red'><b>,</b></font> കടുപ്പം<font color='red'><b>,</b></font> കൈപ്പ്‌<font color='red'><b>,</b></font> തിക്തത<font color='red'><b>,</b></font> കയ്‌പ്‌<font color='red'><b>,</b></font> കഠോരത<font color='red'><b>,</b></font> കയ്പ്
#
# bizarre: വിചിത്രമായ<font color='red'><b>,</b></font> ഭ്രമാത്മകമായ
#
# black: മങ്ങിയ<font color='red'><b>,</b></font> കരിപുരണ്ട<font color='red'><b>,</b></font> കറുത്തവര്‍ഗക്കാര്‍<font color='red'><b>,</b></font> കരി<font color='red'><b>,</b></font> കറുത്ത<font color='red'><b>,</b></font> കറുപ്പുനിറം<font color='red'><b>,</b></font> കറുത്തവര്‍ഗ്ഗക്കാരന്‍<font color='red'><b>,</b></font> ഭയങ്കരമായ<font color='red'><b>,</b></font> ഇരുണ്ട<font color='red'><b>,</b></font> നിഷ്‌പ്രഭമായ<font color='red'><b>,</b></font> ഘോരമായ<font color='red'><b>,</b></font> ദുഷ്‌ടമായ<font color='red'><b>,</b></font> കറുത്ത<font color='red'><b>,</b></font> ഭീതിദമായ<font color='red'><b>,</b></font> ദുഷ്ടമായ<font color='red'><b>,</b></font> നിഷ്പ്രഭമായ
#
# blackness: അന്ധകാരം<font color='red'><b>,</b></font> കറുപ്പ്‌<font color='red'><b>,</b></font> കരിമ<font color='red'><b>,</b></font> കറുപ്പ്‌നിറം<font color='red'><b>,</b></font> കലിമ
#
# blameless: നിര്‍ദ്ദോഷമായ<font color='red'><b>,</b></font> കുറ്റമില്ലാത്ത
#
# blanched: വിളറിയ
#
# bland: സൗമ്യമായ<font color='red'><b>,</b></font> മൃദുവായ<font color='red'><b>,</b></font> രുചിയില്ലാത്ത<font color='red'><b>,</b></font> രൂക്ഷതയില്ലാത്ത<font color='red'><b>,</b></font> എരിവോ പുളിയോ ഇല്ലാത്ത (ഭക്ഷണം)<font color='red'><b>,</b></font> ശ്രദ്ധയില്‍പെടുന്നതായി ഒന്നുമില്ലാത്ത<font color='red'><b>,</b></font> പ്രസാദിപ്പിക്കുന്ന<font color='red'><b>,</b></font> എരിവോ പുളിയോ ഇല്ലാത്ത (ഭക്ഷണം)
#
# blandishment: മുഖസ്‌തുതി<font color='red'><b>,</b></font> മധുരവചനം<font color='red'><b>,</b></font> മുഖസ്തുതി<font color='red'><b>,</b></font> അനുനയം<font color='red'><b>,</b></font> പ്രലോഭനം
#
# blank: ഒരു പ്രതിഛായയെ മൊത്തമായോ ഭാഗികമായോ മറയ്‌ക്കുന്ന പ്രക്രിയക്ക്‌ കമ്പ്യൂട്ടര്‍ ഗ്രാഫിക്‌സില്‍ പറയുന്ന പേര്‌<font color='red'><b>,</b></font> ഒഴിഞ്ഞ സ്ഥലം<font color='red'><b>,</b></font> ലേഖാശൂന്യമായ പത്രം<font color='red'><b>,</b></font> സംഭവരഹിതമായ കാലം<font color='red'><b>,</b></font> എഴുതാത്ത<font color='red'><b>,</b></font> നിര്‍വ്വികാരമായ<font color='red'><b>,</b></font> ശൂന്യമായ<font color='red'><b>,</b></font> വെളുത്ത<font color='red'><b>,</b></font> വിവര്‍ണ്ണമായ<font color='red'><b>,</b></font> ഒന്നും എഴുതാത്ത<font color='red'><b>,</b></font> മനസ്സിലാകാത്ത<font color='red'><b>,</b></font> അച്ചടിക്കാത്ത<font color='red'><b>,</b></font> ശബ്‌ദമോ ചിത്രങ്ങളോ ഇല്ലാത്ത<font color='red'><b>,</b></font> ഒപ്പിടാനോ എഴുതിച്ചേര്‍ക്കാനോ സ്ഥലം വിട്ടിട്ടുള്ള<font color='red'><b>,</b></font> ശബ്ദമോ ചിത്രങ്ങളോ ഇല്ലാത്ത<font color='red'><b>,</b></font> ഒപ്പിടാനോ എഴുതിച്ചേര്‍ക്കാനോ സ്ഥലം വിട്ടിട്ടുള്ള
#
# blare: മുഴക്കം<font color='red'><b>,</b></font> ഗര്‍ജ്ജനം<font color='red'><b>,</b></font> കാഹളനാദം<font color='red'><b>,</b></font> ഉറക്കെ ശബ്ദം മുഴക്കുക<font color='red'><b>,</b></font> മുഴക്കുക<font color='red'><b>,</b></font> ശബ്‌ദമുണ്ടാക്കുക<font color='red'><b>,</b></font> കാഹളം പോലെ ശബ്‌ദിക്കുക<font color='red'><b>,</b></font> കാഹള സ്വരത്തില്‍ പറയുക<font color='red'><b>,</b></font> കാഹളം പോലെ ശബ്ദിക്കുക
#
# blasphemous: ദൈവദൂഷണം<font color='red'><b>,</b></font> നീചഭാഷണം
#
# blatant: തുറന്ന<font color='red'><b>,</b></font> പ്രകടമായ<font color='red'><b>,</b></font> ഉച്ചത്തിലുള്ള<font color='red'><b>,</b></font> നിര്‍ലജ്ജമായ<font color='red'><b>,</b></font> ശബ്‌ദബഹുലമായ<font color='red'><b>,</b></font> ഒച്ചപ്പാടുനിറഞ്ഞ<font color='red'><b>,</b></font> ലജ്ജാരഹിതമായ
#
# blaze: ദീപ്‌തി<font color='red'><b>,</b></font> വികാരങ്ങളുടെ വിസ്ഫോടനം<font color='red'><b>,</b></font> വികാരവിക്ഷോഭം<font color='red'><b>,</b></font> പ്രകാശം<font color='red'><b>,</b></font> പ്രഭ<font color='red'><b>,</b></font> അഗ്നിജ്വാല<font color='red'><b>,</b></font> വികാരവേഗം<font color='red'><b>,</b></font> ആളിക്കത്തല്‍<font color='red'><b>,</b></font> വര്‍ണ്ണോജ്ജ്വലത<font color='red'><b>,</b></font> തീകത്തല്‍<font color='red'><b>,</b></font> കടുത്ത സൂര്യപ്രകാശം<font color='red'><b>,</b></font> കുതിരയുടെയോ കാളയുടെയോ മുഖത്തുള്ള വലിയ മറുക്‌<font color='red'><b>,</b></font> ദീപ്തി<font color='red'><b>,</b></font> കുതിരയുടെയോ കാളയുടെയോ മുഖത്തുള്ള വലിയ മറുക്<font color='red'><b>,</b></font> വികാരവിക്ഷോഭം<font color='red'><b>,</b></font> ജ്വലിപ്പിക്കുക<font color='red'><b>,</b></font> ശോഭിക്കുക<font color='red'><b>,</b></font> ജ്വലിക്കുക<font color='red'><b>,</b></font> എരിയുക<font color='red'><b>,</b></font> പ്രകാശിക്കുക<font color='red'><b>,</b></font> വിളംബരം ചെയ്യുക<font color='red'><b>,</b></font> പ്രസിദ്ധമാക്കുക<font color='red'><b>,</b></font> പ്രഖ്യാപനം ചെയ്യുക<font color='red'><b>,</b></font> കത്തിക്കാളുക<font color='red'><b>,</b></font> തുടരെ വെടിവയ്‌ക്കുക<font color='red'><b>,</b></font> വികാരം പ്രകടിപ്പിക്കുക<font color='red'><b>,</b></font> സോത്സാഹം പ്രവര്‍ത്തിക്കുക
#
# blazing: ആളല്‍<font color='red'><b>,</b></font> കത്തിജ്ജ്വലിക്കുന്ന<font color='red'><b>,</b></font> ജ്വലിക്കുന്ന<font color='red'><b>,</b></font> കത്തുന്ന<font color='red'><b>,</b></font> ആളിക്കത്തുന്ന<font color='red'><b>,</b></font> കാളുന്ന
#
# bleak: ഒരു തരം പുഴമീന്‍<font color='red'><b>,</b></font> തണുപ്പുള്ള<font color='red'><b>,</b></font> തണുത്ത<font color='red'><b>,</b></font> നിറമില്ലാത്ത<font color='red'><b>,</b></font> വിരസമായ<font color='red'><b>,</b></font> ശൂന്യമായ<font color='red'><b>,</b></font> നിരുത്സാഹമായ<font color='red'><b>,</b></font> നിരാന്ദമായ<font color='red'><b>,</b></font> നിരുത്സാഹമായ<font color='red'><b>,</b></font> പ്രതീക്ഷയില്ലാത്ത<font color='red'><b>,</b></font> കാറ്റും മഴയും താങ്ങുന്ന<font color='red'><b>,</b></font> ഉത്സാഹമറ്റ<font color='red'><b>,</b></font> ഉത്സാഹശൂന്യമായ
#
# blend: മിശ്രണം<font color='red'><b>,</b></font> കലര്‍പ്പ്‌<font color='red'><b>,</b></font> മിശ്രിതവസ്‌തു<font color='red'><b>,</b></font> കൂട്ട്<font color='red'><b>,</b></font> ചേര്‍ക്കുക<font color='red'><b>,</b></font> കൂട്ടിക്കലര്‍ത്തുക<font color='red'><b>,</b></font> കലരുക<font color='red'><b>,</b></font> കുഴയ്‌ക്കുക<font color='red'><b>,</b></font> മിശ്രമാക്കുക<font color='red'><b>,</b></font> ചേരുക<font color='red'><b>,</b></font> കലര്‍ത്തുക<font color='red'><b>,</b></font> കുഴയുക<font color='red'><b>,</b></font> ഇടകലരുക
#
# blended: സംശ്ലേഷണം ചെയ്‌ത<font color='red'><b>,</b></font> കൂട്ടിക്കലര്‍ത്തപ്പെട്ട
#
# blending: കലരല്‍<font color='red'><b>,</b></font> ഒന്നിച്ചുകലരല്‍<font color='red'><b>,</b></font> കലര്‍ത്തല്‍<font color='red'><b>,</b></font> യോജിപ്പിക്കല്‍
#
# blessed: സ്വര്‍ഗ്ഗീയമായ<font color='red'><b>,</b></font> അനുഗ്രഹീതനായ<font color='red'><b>,</b></font> ധന്യനായ<font color='red'><b>,</b></font> അനുഗ്രഹീതനായ<font color='red'><b>,</b></font> ധന്യമായ<font color='red'><b>,</b></font> ദൈവാനുഗ്രഹമുള്ള<font color='red'><b>,</b></font> അനുഗൃഹീതനായ
#
# blessing: വരപ്രസാദം<font color='red'><b>,</b></font> അനുഗ്രഹം<font color='red'><b>,</b></font> ആശിസ്സ്‌<font color='red'><b>,</b></font> ആശീര്‍വാദം<font color='red'><b>,</b></font> കൃപ<font color='red'><b>,</b></font> ആശീര്‍വ്വാദം<font color='red'><b>,</b></font> ധന്യവാദം<font color='red'><b>,</b></font> സന്തോഷദായകമായ കാര്യം<font color='red'><b>,</b></font> സന്തോഷദായകമായ കാര്യം
#
# blighted: നശിച്ച
#
# blind: അന്ധകാരം<font color='red'><b>,</b></font> അന്ധന്‍<font color='red'><b>,</b></font> അന്ധര്‍<font color='red'><b>,</b></font> ജനല്‍ കര്‍ട്ടന്‍<font color='red'><b>,</b></font> മറയ്‌ക്കുക<font color='red'><b>,</b></font> ഇരുട്ടാക്കുക<font color='red'><b>,</b></font> അന്ധമാക്കുക<font color='red'><b>,</b></font> കണ്ണു കെട്ടുക<font color='red'><b>,</b></font> വഴി തെറ്റിക്കുക<font color='red'><b>,</b></font> അന്ധരാക്കുക<font color='red'><b>,</b></font> ഗൂഢമായ<font color='red'><b>,</b></font> വിവേകശൂന്യമായ<font color='red'><b>,</b></font> വിവേകമില്ലാത്ത<font color='red'><b>,</b></font> വകതിരിവില്ലാത്ത<font color='red'><b>,</b></font> കണ്ണുകാണാത്ത<font color='red'><b>,</b></font> അജ്ഞനായ<font color='red'><b>,</b></font> അന്ധമായ<font color='red'><b>,</b></font> കാഴ്‌ചയില്ലാത്ത<font color='red'><b>,</b></font> അടഞ്ഞ<font color='red'><b>,</b></font> സഫലമല്ലാത്ത<font color='red'><b>,</b></font> കുരുടായ<font color='red'><b>,</b></font> ഒളിപ്പിച്ചുവച്ച<font color='red'><b>,</b></font> കാഴ്ചയില്ലാത്ത
#
# blindly: അന്ധമായി<font color='red'><b>,</b></font> നോട്ടമില്ലാത്ത
#
# blinking: ഒന്നിടവിട്ട്‌ പ്രകാശിക്കുകയും മായുകയും ചെയ്യുക
#
# blissful: പരമാനന്ദമായ
#
# blistering: പൊള്ളല്‍<font color='red'><b>,</b></font> അമിതമായി വേവല്‍
#
# blithe: ഉല്ലാസമുള്ള<font color='red'><b>,</b></font> ആഹ്‌ളദം നിറഞ്ഞ<font color='red'><b>,</b></font> സന്തോഷമായ<font color='red'><b>,</b></font> വിനോദമുള്ള<font color='red'><b>,</b></font> ചിന്തിക്കാത്ത<font color='red'><b>,</b></font> സന്തോഷകരമായ<font color='red'><b>,</b></font> സന്തോഷമായ<font color='red'><b>,</b></font> വിനോദമുള്ള
#
# bloated: ചീര്‍ത്ത<font color='red'><b>,</b></font> അഹംഭാവമുള്ള<font color='red'><b>,</b></font> വികസിച്ച
#
# bloodless: നിര്‍വ്വികാരമായ<font color='red'><b>,</b></font> വിളറിയ<font color='red'><b>,</b></font> രക്തമില്ലാത്ത<font color='red'><b>,</b></font> വീര്യമില്ലാത്ത<font color='red'><b>,</b></font> ദുഷ്‌ടനായ<font color='red'><b>,</b></font> ഉത്സാഹമില്ലാത്ത<font color='red'><b>,</b></font> രക്തച്ചൊരിച്ചിലില്ലാത്ത<font color='red'><b>,</b></font> ദുഷ്ടനായ<font color='red'><b>,</b></font> രക്തച്ചൊരിച്ചിലില്ലാത്ത
#
# bloodshed: സംഹാരം<font color='red'><b>,</b></font> രക്തച്ചൊരിച്ചില്‍<font color='red'><b>,</b></font> പ്രാണഹാനി<font color='red'><b>,</b></font> കൊല<font color='red'><b>,</b></font> കൊല<font color='red'><b>,</b></font> രക്തച്ചൊരിച്ചില്‍
#
# blot: കളങ്കം<font color='red'><b>,</b></font> അപകീര്‍ത്തി<font color='red'><b>,</b></font> ദോഷം<font color='red'><b>,</b></font> അപഖ്യാതി<font color='red'><b>,</b></font> കറ<font color='red'><b>,</b></font> ദുഷ്‌കര്‍മ്മം<font color='red'><b>,</b></font> കറുത്തപുള്ളി<font color='red'><b>,</b></font> തുടപ്പ്‌<font color='red'><b>,</b></font> തുടപ്പ്<font color='red'><b>,</b></font> കളങ്കപ്പെടുത്തുക<font color='red'><b>,</b></font> അപകീര്‍ത്തിപ്പെടുത്തുക<font color='red'><b>,</b></font> മായ്‌ച്ചുകളയുക<font color='red'><b>,</b></font> (മഷിയും മറ്റും) ഒപ്പിയെടുക്കുക
#
# blows: അടി
#
# blue: പദവി<font color='red'><b>,</b></font> നീലിമ<font color='red'><b>,</b></font> ആകാശം<font color='red'><b>,</b></font> നീലനിറം<font color='red'><b>,</b></font> സമുദ്രം<font color='red'><b>,</b></font> സ്ഥാനം<font color='red'><b>,</b></font> നീലനിറമുള്ള<font color='red'><b>,</b></font> ഉദ്വേഗജനകമായ<font color='red'><b>,</b></font> നീലവസ്‌ത്രം ധരിച്ച<font color='red'><b>,</b></font> അശ്ലീലമായ<font color='red'><b>,</b></font> നീല നിറത്തിലുള്ള<font color='red'><b>,</b></font> ദുഃഖഭാവമുള്ള<font color='red'><b>,</b></font> നീലയായ
#
# blunder: മണ്ടത്തരം കാണിക്കുക<font color='red'><b>,</b></font> മണ്ടത്തരം<font color='red'><b>,</b></font> അപരാധം<font color='red'><b>,</b></font> പ്രമാദം<font color='red'><b>,</b></font> അബദ്ധം<font color='red'><b>,</b></font> അജാഗ്രതകൊണ്ടു പറ്റുന്ന അബദ്ധം<font color='red'><b>,</b></font> മഹാപ്രമാദം<font color='red'><b>,</b></font> ബുദ്ധിമോശം<font color='red'><b>,</b></font> പ്രമാദം പറ്റുക<font color='red'><b>,</b></font> കാലുതെറ്റുക<font color='red'><b>,</b></font> അബദ്ധം എഴുന്നെള്ളിക്കുക
#
# blunt: മൂര്‍ച്ചകളയുക<font color='red'><b>,</b></font> മന്ദബുദ്ധിയായ<font color='red'><b>,</b></font> മൂര്‍ച്ചയില്ലാത്ത<font color='red'><b>,</b></font> വായ്‌ത്തലയില്ലാത്ത<font color='red'><b>,</b></font> സൂക്ഷ്‌മഗ്രഹണശക്തിയില്ലാത്ത<font color='red'><b>,</b></font> വിട്ടുവീഴ്‌ചയ്‌ക്കു തയ്യാറാല്ലാത്ത<font color='red'><b>,</b></font> മുനയില്ലാത്ത<font color='red'><b>,</b></font> ഋജുപ്രകൃതിയായ<font color='red'><b>,</b></font> തുറന്നടിക്കുന്ന
#
# blurred: മങ്ങിയ<font color='red'><b>,</b></font> മലിനമായ
#
# blush: അരുണിമ<font color='red'><b>,</b></font> ലജ്ജകൊണ്ടും മറ്റുമുണ്ടാകുന്ന മുഖത്തുടുപ്പ്‌<font color='red'><b>,</b></font> (നാണംകൊണ്ട്) മുഖം ചുവക്കുക<font color='red'><b>,</b></font> ശോഭിക്കുക<font color='red'><b>,</b></font> വിഷമിപ്പിക്കുക<font color='red'><b>,</b></font> ലജ്ജിക്കുക<font color='red'><b>,</b></font> മുഖം വിവര്‍ണ്ണമാക്കുക<font color='red'><b>,</b></font> മുഖം ചുവക്കുക
#
# bluster: ഗര്‍ജ്ജനം<font color='red'><b>,</b></font> വീമ്പിളക്കുന്നയാള്‍<font color='red'><b>,</b></font> കോള്‌<font color='red'><b>,</b></font> ശക്തിയായ കാറ്റ്‌<font color='red'><b>,</b></font> വീമ്പു പറയല്‍<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറയുക<font color='red'><b>,</b></font> ആക്രാശിക്കുക<font color='red'><b>,</b></font> അലറുക<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറയുക<font color='red'><b>,</b></font> ഭര്‍ത്സിക്കുക<font color='red'><b>,</b></font> ഉച്ചത്തില്‍ പറയുക<font color='red'><b>,</b></font> ഇരമ്പുക<font color='red'><b>,</b></font> ഗര്‍ജ്ജിക്കുക<font color='red'><b>,</b></font> വീമ്പിളക്കുക<font color='red'><b>,</b></font> വമ്പു പറയുക<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറയുക<font color='red'><b>,</b></font> ആക്രോശിക്കുക<font color='red'><b>,</b></font> വന്പു പറയുക<font color='red'><b>,</b></font> ഇരന്പുക
#
# blustering: വിടുവായത്തം
#
# boast: പൊങ്ങച്ചം<font color='red'><b>,</b></font> ആത്മപ്രശംസ<font color='red'><b>,</b></font> വീമ്പ്‌<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറയുക<font color='red'><b>,</b></font> ആത്മപ്രശംസ ചെയ്യുക<font color='red'><b>,</b></font> വീമ്പടിക്കുക<font color='red'><b>,</b></font> വീരവാദം മുഴക്കുക<font color='red'><b>,</b></font> അഭിമാനിക്കുക
#
# boastful: ആത്മപ്രശംസാപരമായ<font color='red'><b>,</b></font> വീമ്പുപറയുന്ന<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറയുന്നതായ
#
# boasting: പൊങ്ങച്ചം പറയല്‍<font color='red'><b>,</b></font> വമ്പുപറച്ചില്‍<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറച്ചില്‍<font color='red'><b>,</b></font> വീമ്പ്‌<font color='red'><b>,</b></font> വീമ്പുപറച്ചില്‍<font color='red'><b>,</b></font> സ്വയംപുകഴ്‌ത്തിപ്പറയല്‍<font color='red'><b>,</b></font> വീമ്പിളക്കല്‍
#
# bodily: ശാരീരികമായ<font color='red'><b>,</b></font> ശരീരികമായ<font color='red'><b>,</b></font> ശരീരസംബന്ധമായ
#
# body: കൂട്ടം<font color='red'><b>,</b></font> സംഘം<font color='red'><b>,</b></font> ശവം<font color='red'><b>,</b></font> മൃതശരീരം<font color='red'><b>,</b></font> ശരീരം<font color='red'><b>,</b></font> ദേഹം<font color='red'><b>,</b></font> ഒരു വസ്‌തുവിന്റെ പ്രധാനഭാഗം<font color='red'><b>,</b></font> സംഘടന<font color='red'><b>,</b></font> ചട്ടക്കൂട്‌<font color='red'><b>,</b></font> ചട്ടക്കൂട്<font color='red'><b>,</b></font> മെയ്യ്‌<font color='red'><b>,</b></font> മേനി<font color='red'><b>,</b></font> ഗാത്രം<font color='red'><b>,</b></font> മെയ്യ്
#
# boisterous: ഉത്സാഹമുള്ള<font color='red'><b>,</b></font> കോലാഹലത്തോടു കൂടിയ പ്രക്ഷുബ്‌ധവസ്ഥയിലുള്ള പ്രചണ്‌ഡമായ<font color='red'><b>,</b></font> കോപമുള്ള<font color='red'><b>,</b></font> ശബ്‌ദമുഖരിതമായ<font color='red'><b>,</b></font> ഗര്‍ജ്ജിക്കുന്ന<font color='red'><b>,</b></font> ബഹളമുണ്ടാക്കുന്ന<font color='red'><b>,</b></font> പ്രക്ഷുബ്‌ധാവസ്ഥയിലുള്ള<font color='red'><b>,</b></font> ബഹളപൂര്‍ണ്ണമായ<font color='red'><b>,</b></font> കോപമുളള<font color='red'><b>,</b></font> ശബ്ദമുഖരിതമായ<font color='red'><b>,</b></font> പ്രക്ഷുബ്ധാവസ്ഥയിലുള്ള<font color='red'><b>,</b></font> കോപമുള്ള
#
# bold: വ്യക്തമായ<font color='red'><b>,</b></font> ധീരമായ<font color='red'><b>,</b></font> വിശദമായ<font color='red'><b>,</b></font> സ്‌പഷ്‌ടമായ<font color='red'><b>,</b></font> ആത്മവിശ്വാസമുള്ള<font color='red'><b>,</b></font> നിര്‍ല്ലജ്ജമായ<font color='red'><b>,</b></font> അതിവ്യക്തമായ<font color='red'><b>,</b></font> നിര്‍ഭയമായ
#
# boldness: ധൈര്യം<font color='red'><b>,</b></font> പേടിയില്ലായ്മ
#
# bombast: ശബ്‌ദാഡംബരം<font color='red'><b>,</b></font> വാഗ്‌ജാലം<font color='red'><b>,</b></font> വലിയവാക്കു പ്രയോഗിച്ചുള്ള നിസ്സാര സംഭാഷണം<font color='red'><b>,</b></font> നിരര്‍ത്ഥകമായ ശബ്‌ദധോരണി<font color='red'><b>,</b></font> നിരര്‍ത്ഥകമായ ശബ്ദോരണി<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറയുക
#
# bombastic: വാക്വൈഭവം<font color='red'><b>,</b></font> വിടുവായത്തം<font color='red'><b>,</b></font> ഡംഭുള്ള<font color='red'><b>,</b></font> വീമ്പുപറയുന്ന<font color='red'><b>,</b></font> വാഗ്വൈഭവമുള്ള<font color='red'><b>,</b></font> പൊങ്ങച്ചം നിറഞ്ഞതായ<font color='red'><b>,</b></font> പൊങ്ങച്ചം നിറഞ്ഞതായ
#
# bondage: അടിമത്തം<font color='red'><b>,</b></font> തടങ്കല്‍<font color='red'><b>,</b></font> ബന്ധനം<font color='red'><b>,</b></font> തടവ്‌<font color='red'><b>,</b></font> പരാധീനത<font color='red'><b>,</b></font> തടവ്
#
# bone: ശരീരം<font color='red'><b>,</b></font> എല്ല്‌<font color='red'><b>,</b></font> അസ്ഥി<font color='red'><b>,</b></font> ഭൗതികാവശിഷ്‌ടങ്ങള്‍<font color='red'><b>,</b></font> ദാര്‍ഢ്യം<font color='red'><b>,</b></font> തര്‍ക്കവിഷയം<font color='red'><b>,</b></font> സ്ഥൈര്യം<font color='red'><b>,</b></font> എല്ല<font color='red'><b>,</b></font> അøി<font color='red'><b>,</b></font> എല്ല്
#
# bookish: പുസ്‌തകജ്ഞാനം മാത്രമുള്ള<font color='red'><b>,</b></font> പ്രയോഗികജ്ഞാനം കുറഞ്ഞ
#
# boon: മനസ്സിനിണങ്ങിയ<font color='red'><b>,</b></font> ആനുകൂല്യം<font color='red'><b>,</b></font> അനുഗ്രഹം<font color='red'><b>,</b></font> പ്രീതി<font color='red'><b>,</b></font> പ്രാര്‍ത്ഥന<font color='red'><b>,</b></font> ഉപകാരം<font color='red'><b>,</b></font> വരം<font color='red'><b>,</b></font> വിനോദശീലനായ
#
# boorish: മര്യാദയില്ലാത്ത<font color='red'><b>,</b></font> പ്രാകൃതമായ<font color='red'><b>,</b></font> അപരിഷ്‌കൃതനായ<font color='red'><b>,</b></font> നിര്‍ദ്ദയനായ<font color='red'><b>,</b></font> വിലക്ഷണപ്രകൃതിയായ<font color='red'><b>,</b></font> വിലക്ഷണ പ്രകൃതിയുള്ള<font color='red'><b>,</b></font> മൂര്‍ഖമായ
#
# bored: തുളച്ച<font color='red'><b>,</b></font> തുരന്ന<font color='red'><b>,</b></font> മുഷിപ്പിക്കപ്പെടുന്ന<font color='red'><b>,</b></font> മുഷിവുള്ള
#
# boredom: വിരസത<font color='red'><b>,</b></font> മുഷിവ്‌<font color='red'><b>,</b></font> വൈരസ്യം<font color='red'><b>,</b></font> മുഷിപ്പ്‌
#
# borrowed: കൃത്രിമമായ<font color='red'><b>,</b></font> കടം വാങ്ങിയ
#
# bottomless: അഗാധമായ<font color='red'><b>,</b></font> ആധാരരഹിതമായ<font color='red'><b>,</b></font> അടിത്തട്ടില്ലാത്ത<font color='red'><b>,</b></font> നില കാണാത്ത<font color='red'><b>,</b></font> കീഴ്‌ഭാഗമില്ലാത്ത (വസ്‌ത്രം)<font color='red'><b>,</b></font> കീഴ്ഭാഗമില്ലാത്ത ( വസ്ത്രം )
#
# boundless: അതിരില്ലാത്ത<font color='red'><b>,</b></font> പരിധിയില്ലാത്ത<font color='red'><b>,</b></font> അപരിമിതമായ<font color='red'><b>,</b></font> നിസ്സീമമായ
#
# bountiful: സമ്പുഷ്‌ടമായ<font color='red'><b>,</b></font> ഔദാര്യമുള്ള<font color='red'><b>,</b></font> മഹാമനസ്‌ക്കതയുള്ള<font color='red'><b>,</b></font> ദാനശീലമുളള
#
# bourgeois: പൗരന്‍<font color='red'><b>,</b></font> ഇടത്തരക്കാരന്‍<font color='red'><b>,</b></font> യാഥാസ്ഥിതിക മനോഭാവം പുലര്‍ത്തുന്ന ഇടത്തരക്കാരന്‍
#
# boyish: ബാലസ്വഭാവമായ
#
# brace: വലയം<font color='red'><b>,</b></font> കെട്ട്‌<font color='red'><b>,</b></font> ചരട്‌<font color='red'><b>,</b></font> വളയം<font color='red'><b>,</b></font> താങ്ങ്‌<font color='red'><b>,</b></font> ചുമല്‍വാര്‍<font color='red'><b>,</b></font> ചര്‍മ്മബന്ധം<font color='red'><b>,</b></font> ദ്വന്ദ്വം<font color='red'><b>,</b></font> വാറ്‌<font color='red'><b>,</b></font> ദന്തനിരയൊപ്പിക്കാന്‍ ഇടുന്ന കമ്പി<font color='red'><b>,</b></font> കെട്ട്<font color='red'><b>,</b></font> വാറ്<font color='red'><b>,</b></font> ദന്തനിരയൊപ്പിക്കാന്‍ ഇടുന്ന കന്പി<font color='red'><b>,</b></font> ബന്ധിക്കുക<font color='red'><b>,</b></font> മുറുക്കുക<font color='red'><b>,</b></font> വലിച്ചു കെട്ടുക<font color='red'><b>,</b></font> ശക്തിവരുത്തുക<font color='red'><b>,</b></font> ദൃഢമാക്കുക<font color='red'><b>,</b></font> ചേര്‍ത്ത് കെട്ടുന്ന വസ്തു<font color='red'><b>,</b></font> ചേര്‍ത്ത് കെട്ടുക<font color='red'><b>,</b></font> തുളയ്ക്കുന്ന ഉപകരണം
#
# brag: ആത്മസ്‌തുതി<font color='red'><b>,</b></font> ആത്മപ്രശംസ നടത്തുക<font color='red'><b>,</b></font> പൊങ്ങച്ചം<font color='red'><b>,</b></font> ബഡായി<font color='red'><b>,</b></font> വമ്പുപറച്ചില്‍<font color='red'><b>,</b></font> പന്തയച്ചീട്ടുകളി<font color='red'><b>,</b></font> ആത്മസ്തുതി<font color='red'><b>,</b></font> വന്പുപറച്ചില്‍<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറയുക<font color='red'><b>,</b></font> ബഡായി
#
# braggadocio: പൊള്ളയായ വാക്കുകൾ പറയൽ<font color='red'><b>,</b></font> വീമ്പ് ഇളക്കൽ<font color='red'><b>,</b></font> പൊങ്ങച്ചം പറച്ചിൽ
#
# braggart: തന്നത്താന്‍ വാഴ്‌ത്തുന്നവന്‍
#
# brain: മസ്‌തിഷ്‌കം<font color='red'><b>,</b></font> അറിവ്‌<font color='red'><b>,</b></font> ബുദ്ധിശക്തി<font color='red'><b>,</b></font> മനസ്സ്‌<font color='red'><b>,</b></font> തലച്ചോര്‍<font color='red'><b>,</b></font> ബുദ്ധി<font color='red'><b>,</b></font> പ്രതിഭ<font color='red'><b>,</b></font> ബുദ്ധിമാന്‍<font color='red'><b>,</b></font> തലച്ചോറ്‌<font color='red'><b>,</b></font> ബുദ്ധിയുള്ള വ്യക്തി<font color='red'><b>,</b></font> അറിവ്<font color='red'><b>,</b></font> മനസ്സ്<font color='red'><b>,</b></font> തലച്ചോറ്<font color='red'><b>,</b></font> മസ്തിഷ്കം<font color='red'><b>,</b></font> തലയ്‌ക്കടിച്ചു കൊല്ലുക<font color='red'><b>,</b></font> തല്ലി തലച്ചോറെടുക്കുക<font color='red'><b>,</b></font> തലച്ചോറ
#
# bravado: ഗര്‍വ്വം<font color='red'><b>,</b></font> എല്ലാം പുല്ലാണെന്ന മട്ട്‌<font color='red'><b>,</b></font> ഗര്‍വ്വം<font color='red'><b>,</b></font> ധൈര്യം ഭാവിക്കല്‍<font color='red'><b>,</b></font> വീരസ്യം<font color='red'><b>,</b></font> ബഡായി<font color='red'><b>,</b></font> വീമ്പ്‌<font color='red'><b>,</b></font> പറയല്‍<font color='red'><b>,</b></font> പെരുമ പറയല്‍<font color='red'><b>,</b></font> വീന്പ്<font color='red'><b>,</b></font> ബഡായി<font color='red'><b>,</b></font> വീരവാദം<font color='red'><b>,</b></font> വീന്പിളക്കല്‍
#
# brave: സാഹസികനായ<font color='red'><b>,</b></font> ധൈര്യവാനായ<font color='red'><b>,</b></font> നേരിടുക<font color='red'><b>,</b></font> ധൈര്യമായി എതിര്‍ത്തു നില്‌ക്കുക<font color='red'><b>,</b></font> സാഹസികമായ<font color='red'><b>,</b></font> ഉല്‍കൃഷ്‌ടമായ<font color='red'><b>,</b></font> ധീരമായ<font color='red'><b>,</b></font> നിര്‍ഭയമായ<font color='red'><b>,</b></font> ധീരതയുള്ള<font color='red'><b>,</b></font> വിക്രമമുള്ള<font color='red'><b>,</b></font> ഓജസ്വിയായ<font color='red'><b>,</b></font> വേഷപ്പകിട്ടുള്ള<font color='red'><b>,</b></font> ഉല്‍കൃഷ്ടമായ
#
# bravely: ധൈര്യസമേതം
#
# bravery: ആഡംബരം<font color='red'><b>,</b></font> ശൗര്യം<font color='red'><b>,</b></font> പെരുമാറ്റം<font color='red'><b>,</b></font> ധീരത<font color='red'><b>,</b></font> ധൈര്യം<font color='red'><b>,</b></font> ധൈര്യപൂര്‍വ്വമായ
#
# braying: കഴുതയുടെ കരച്ചില്‍
#
# brazen: നാണംകെട്ട<font color='red'><b>,</b></font> മഞ്ഞനിറമുള്ള<font color='red'><b>,</b></font> നിര്‍ലജ്ജമായ<font color='red'><b>,</b></font> പിച്ചളമായ<font color='red'><b>,</b></font> പിച്ചള നിര്‍മ്മിതമായ<font color='red'><b>,</b></font> അഃിശക്തമായ<font color='red'><b>,</b></font> പിച്ചളയാല്‍ നിര്‍മ്മിച്ച
#
# breadth: വിസ്‌തൃതി<font color='red'><b>,</b></font> വിസ്തൃതി<font color='red'><b>,</b></font> വീതി<font color='red'><b>,</b></font> വിശാലത<font color='red'><b>,</b></font> വൈപുല്യം<font color='red'><b>,</b></font> അകലം<font color='red'><b>,</b></font> വിസ്‌താരം<font color='red'><b>,</b></font> ദൂരം<font color='red'><b>,</b></font> വിസ്‌തീര്‍ണ്ണം
#
# breathless: അമ്പരപ്പോടുകൂടി<font color='red'><b>,</b></font> ശ്വാസപിടിക്കുക<font color='red'><b>,</b></font> വാ പിളര്‍ക്കുക<font color='red'><b>,</b></font> നിര്‍ജ്ജീവമായ<font color='red'><b>,</b></font> വീര്‍പ്പുമുട്ടുന്ന<font color='red'><b>,</b></font> സ്‌തംഭിക്കുന്ന<font color='red'><b>,</b></font> ശ്വാസമറ്റ<font color='red'><b>,</b></font> അണയ്‌ക്കുന്ന<font color='red'><b>,</b></font> സ്തംഭിക്കുന്ന<font color='red'><b>,</b></font> അണയ്ക്കുന്ന
#
# breeding: ശിക്ഷണം<font color='red'><b>,</b></font> പാലനം<font color='red'><b>,</b></font> സ്വഭാവരൂപവല്‍ക്കരണം<font color='red'><b>,</b></font> സദാചാരം<font color='red'><b>,</b></font> പ്രജനനം<font color='red'><b>,</b></font> കന്നുകാലി വളര്‍ത്തല്‍<font color='red'><b>,</b></font> സൗശീല്യം<font color='red'><b>,</b></font> ഉന്നതകുലം<font color='red'><b>,</b></font> സാമുദായിക ജീവിതത്തിലെ പെരുമാറ്റം<font color='red'><b>,</b></font> പഠിത്തം<font color='red'><b>,</b></font> കന്നുകാലിവളര്‍ത്തല്‍
#
# breeze: ഇളംകാറ്റ്<font color='red'><b>,</b></font> കലഹം<font color='red'><b>,</b></font> മന്ദമാരുതന്‍<font color='red'><b>,</b></font> ഇളങ്കാറ്റ്‌<font color='red'><b>,</b></font> കോപപ്രകടനം<font color='red'><b>,</b></font> കിംവദന്തി<font color='red'><b>,</b></font> സംസാരം<font color='red'><b>,</b></font> ലഘുജോലി<font color='red'><b>,</b></font> ഇളങ്കാറ്റ്<font color='red'><b>,</b></font> ലഘുജോലി<font color='red'><b>,</b></font> തെന്നൽ<font color='red'><b>,</b></font> ഇളങ്കാറ്റുപോലെ നീങ്ങുക
#
# brevity: സംഗ്രഹം<font color='red'><b>,</b></font> സംക്ഷിപ്‌തത<font color='red'><b>,</b></font> ക്ഷണികത്വം<font color='red'><b>,</b></font> പദപ്രയോഗമിതത്വം<font color='red'><b>,</b></font> ഹസ്വമായ ജീവതികാലം<font color='red'><b>,</b></font> ഹ്രസ്വത<font color='red'><b>,</b></font> സംക്ഷിപ്തത
#
# bribery: കൈക്കൂലിപ്പണം<font color='red'><b>,</b></font> കോഴ കൊടുക്കല്‍<font color='red'><b>,</b></font> വാങ്ങല്‍ എന്നിവ<font color='red'><b>,</b></font> കോഴകൊടുക്കലോ വാങ്ങലോ
#
# brief: സംഗ്രഹം<font color='red'><b>,</b></font> ചുരുക്കം<font color='red'><b>,</b></font> സംക്ഷേപം<font color='red'><b>,</b></font> വക്കാലത്ത്‌<font color='red'><b>,</b></font> രത്‌നച്ചുരുക്കം<font color='red'><b>,</b></font> കേസു നടത്തുന്ന വക്കീലിന്റെ അറിവിനായി കുറിച്ചു കൊടുക്കുന്ന സംഗതിവിവരം<font color='red'><b>,</b></font> അടിവസ്‌ത്രം<font color='red'><b>,</b></font> വ്യവഹാരക്കുറിപ്പ്‌<font color='red'><b>,</b></font> കാര്യങ്ങളുടെ ചുരുക്കവിവരം<font color='red'><b>,</b></font> സംക്ഷിപ്‌തമായ<font color='red'><b>,</b></font> ചുരുങ്ങിയ<font color='red'><b>,</b></font> ക്ഷണികമായ<font color='red'><b>,</b></font> ലഘുവായ<font color='red'><b>,</b></font> ഹ്രസ്വമായ<font color='red'><b>,</b></font> അല്‍പകാലം മാത്രം നിലനില്‍ക്കുന്ന<font color='red'><b>,</b></font> സംക്ഷിപ്തമായ<font color='red'><b>,</b></font> അല്‌പകാലം നില്‌ക്കുന്ന<font color='red'><b>,</b></font> അല്പകാലം നില്ക്കുന്ന
#
# bright: വെളിച്ചം<font color='red'><b>,</b></font> സമര്‍ത്ഥമായ<font color='red'><b>,</b></font> പ്രകാശപൂരിതം<font color='red'><b>,</b></font> തെളിച്ചമാര്‍ന്ന<font color='red'><b>,</b></font> ശോഭമയമായ<font color='red'><b>,</b></font> പ്രസന്നമായ<font color='red'><b>,</b></font> കുശാഗ്രബുദ്ധിയായ<font color='red'><b>,</b></font> ജ്വലിക്കുന്ന<font color='red'><b>,</b></font> പ്രദീപ്‌തമായ<font color='red'><b>,</b></font> പ്രകാശമുള്ള<font color='red'><b>,</b></font> തേജസ്വിയായ
#
# brightness: തിളക്കം<font color='red'><b>,</b></font> ശോഭ<font color='red'><b>,</b></font> തെളിച്ചം<font color='red'><b>,</b></font> ബുദ്ധപ്രഭാവം
#
# brilliancy: തിളക്കം<font color='red'><b>,</b></font> ഉജ്ജ്വലത
#
# brilliant: കഴിവുള്ള<font color='red'><b>,</b></font> സമര്‍ത്ഥനായ<font color='red'><b>,</b></font> ഉö്വലമായ<font color='red'><b>,</b></font> ഭാസുരമായ<font color='red'><b>,</b></font> അത്യുജ്ജ്വലമായ<font color='red'><b>,</b></font> തോജോമയമായ<font color='red'><b>,</b></font> അതിബുദ്ധിമാനായ<font color='red'><b>,</b></font> തോജോമയമായ
#
# brisk: ചുണയുള്ള<font color='red'><b>,</b></font> ഊര്‍ജ്ജസ്വലതയോട് കൂടിയ<font color='red'><b>,</b></font> ഉത്സാഹമുള്ള<font color='red'><b>,</b></font> വേഗമുള്ള<font color='red'><b>,</b></font> ചുറുചുറുക്കുള്ള<font color='red'><b>,</b></font> ഉന്‍മേഷജനകമായ
#
# briskness: ചുറുചുറുക്ക്‌<font color='red'><b>,</b></font> ചടുലത
#
# bristling: രോമഹര്‍ഷം
#
# brittle: എളുപ്പത്തില്‍ പൊട്ടുന്ന<font color='red'><b>,</b></font> വേഗം ഒടിയുന്ന<font color='red'><b>,</b></font> എളുപ്പത്തില്‍ തകരുന്ന<font color='red'><b>,</b></font> പെട്ടെന്ന് പൊട്ടുന്ന
#
# broad: വ്യാപകമായ<font color='red'><b>,</b></font> സ്‌പഷ്‌ടമായ<font color='red'><b>,</b></font> വിസ്‌തൃതമായ<font color='red'><b>,</b></font> വിശാലമായ<font color='red'><b>,</b></font> വിസ്‌താരമുള്ള<font color='red'><b>,</b></font> വലിയ<font color='red'><b>,</b></font> കനത്ത<font color='red'><b>,</b></font> വീതിയുള്ള<font color='red'><b>,</b></font> മഹാമനസ്‌കതയുള്ള<font color='red'><b>,</b></font> വീതിയുളള
#
# broad-
#
# broaden: വിശാലമാക്കുക<font color='red'><b>,</b></font> വിസ്‌തൃതമാക്കുക<font color='red'><b>,</b></font> വീതികൂട്ടുക<font color='red'><b>,</b></font> സ്‌പഷടമായിത്തീരുക<font color='red'><b>,</b></font> വിശാലമാവുക<font color='red'><b>,</b></font> വീതി കൂട്ടുക
#
# broadening: വികസിപ്പിക്കല്‍
#
# broken: തകര്‍ന്ന<font color='red'><b>,</b></font> പൊട്ടിയ<font color='red'><b>,</b></font> നശിച്ചുപോയ<font color='red'><b>,</b></font> പൊട്ടിച്ച<font color='red'><b>,</b></font> തകര്‍ക്കപ്പെട്ട
#
# brooding: ആലോചനാമഗ്നമായ
#
# brotherhood: ഭ്രാതൃത്വം<font color='red'><b>,</b></font> സാഹോദര്യം
#
# brow: പുരികം<font color='red'><b>,</b></font> നെറ്റി<font color='red'><b>,</b></font> കുന്നിന്റെ കിഴുക്കാംതൂക്കായ ചെരിവ്‌<font color='red'><b>,</b></font> കല്‍ക്കരി ഖനിയിലെ പടവ്‌<font color='red'><b>,</b></font> കുന്നിന്‍റെ കിഴുക്കാംതൂക്കായ ചെരിവ്<font color='red'><b>,</b></font> കല്‍ക്കരി ഖനിയിലെ പടവ്
#
# brusqueness: മര്യാദകേട്‌<font color='red'><b>,</b></font> പാരുഷ്യം<font color='red'><b>,</b></font> പരുക്കന്‍മട്ട്‌<font color='red'><b>,</b></font> മര്യാദകേട്<font color='red'><b>,</b></font> പരുക്കന്‍മട്ട്
#
# brutal: ക്രൂരമായ<font color='red'><b>,</b></font> ഹീനമായ<font color='red'><b>,</b></font> നൃശംസമായ<font color='red'><b>,</b></font> മൃഗീയമായ<font color='red'><b>,</b></font> നിഷ്‌ഠൂരമായ<font color='red'><b>,</b></font> നിഷ്‌ഠുരനായ
#
# brutality: ക്രൂരത<font color='red'><b>,</b></font> മൃഗീയത<font color='red'><b>,</b></font> പൈശാചികത<font color='red'><b>,</b></font> നിഷ്‌ഠൂരത
#
# brutish: അസംസ്‌കൃതമായ<font color='red'><b>,</b></font> ക്രൂരമായ<font color='red'><b>,</b></font> ബുദ്ധിശൂന്യമായ<font color='red'><b>,</b></font> മൃഗീയമായ
#
# bubbling: കുമിളയാകുന്ന
#
# bucolic: അജപാലകാവ്യം<font color='red'><b>,</b></font> ഇടയവൃത്തിയെ സംബന്ധിച്ച<font color='red'><b>,</b></font> ഗ്രാമീണ ജീവിതത്തെ സംബന്ധിച്ച
#
# budding: വികാസം പ്രാപിക്കുക<font color='red'><b>,</b></font> വളരുന്ന<font color='red'><b>,</b></font> വളരുന്നതായ
#
# bulk: ആകൃതി<font color='red'><b>,</b></font> കൂമ്പാരം<font color='red'><b>,</b></font> പരിമാണം<font color='red'><b>,</b></font> വലിപ്പം<font color='red'><b>,</b></font> ഭീമകായനായ ആള്‍<font color='red'><b>,</b></font> ഭീമാംശം<font color='red'><b>,</b></font> മുഖ്യഭാഗം<font color='red'><b>,</b></font> സ്ഥൂലം<font color='red'><b>,</b></font> അധിപക്ഷം<font color='red'><b>,</b></font> വലുതായി തോന്നുക<font color='red'><b>,</b></font> ബഹുലമാവുക<font color='red'><b>,</b></font> ഭൂരിഭാഗം<font color='red'><b>,</b></font> വലുതാവുക<font color='red'><b>,</b></font> അളവ്
#
# bulky: ബൃഹത്തായ<font color='red'><b>,</b></font> തടിച്ച<font color='red'><b>,</b></font> അമിതമായ<font color='red'><b>,</b></font> മാംസളമായ<font color='red'><b>,</b></font> വലിപ്പമുള്ള<font color='red'><b>,</b></font> വലുപ്പമുള്ള
#
# bully: മറ്റുള്ളവരെ ഭയപ്പെടുത്തി ഭരിക്കാന്‍ സ്വന്തം ശക്തി ഉപയോഗിക്കുന്നവന്‍<font color='red'><b>,</b></font> വഴക്കാളി<font color='red'><b>,</b></font> മുഠാളന്‍<font color='red'><b>,</b></font> ഉപദ്രവിക്കുക<font color='red'><b>,</b></font> ഭീഷണിപ്പെടുത്തുക<font color='red'><b>,</b></font> കടുകൈ പ്രവര്‍ത്തിക്കുക<font color='red'><b>,</b></font> ഇത്തരത്തില്‍ പെരുമാറുക<font color='red'><b>,</b></font> തെമ്മാടി<font color='red'><b>,</b></font> വീമ്പു പറയുന്ന<font color='red'><b>,</b></font> മുഠാളത്തം കാണിക്കുന്ന<font color='red'><b>,</b></font> മറ്റുളളവരുമായി സദാ വഴക്കുണ്ടാക്കുന്നവന്‍<font color='red'><b>,</b></font> വീന്പു പറയുന്ന
#
# bulwark: പുറങ്കോട്ട<font color='red'><b>,</b></font> രക്ഷകന്‍<font color='red'><b>,</b></font> പ്രകാരം<font color='red'><b>,</b></font> കടല്‍ഭിത്തി<font color='red'><b>,</b></font> സമുദ്രച്ചുവര്‍<font color='red'><b>,</b></font> കപ്പലിന്റെ ചുറ്റുവരിപ്പലക<font color='red'><b>,</b></font> സംരക്ഷിക്കുന്നവന്‍<font color='red'><b>,</b></font> പുറങ്കോട്ട<font color='red'><b>,</b></font> കപ്പലിന്‍റെ ചുറ്റുവരിപ്പലക
#
# bumptious: ഉദ്ധതമായ<font color='red'><b>,</b></font> അഹംഭാവിയായ
#
# bungling: കഴിവുകേട്‌<font color='red'><b>,</b></font> അഭംഗി<font color='red'><b>,</b></font> വിലക്ഷണമായ<font color='red'><b>,</b></font> അസംബന്ധമായ<font color='red'><b>,</b></font> അഭംഗിയായ<font color='red'><b>,</b></font> ഭംഗികേടായ
#
# buoyant: ലഘുവായ<font color='red'><b>,</b></font> പൊങ്ങിക്കിടക്കുന്ന<font color='red'><b>,</b></font> പ്ലവനശീലമുള്ള<font color='red'><b>,</b></font> ഉത്സാഹഭരിതമായ<font color='red'><b>,</b></font> താങ്ങിനിറുത്തുന്ന<font color='red'><b>,</b></font> പറക്കുന്നതായ<font color='red'><b>,</b></font> പൊങ്ങിക്കിടക്കുന്ന<font color='red'><b>,</b></font> സന്തോഷഭരിതമായ
#
# burden: ക്ലേശം<font color='red'><b>,</b></font> സങ്കടം<font color='red'><b>,</b></font> ഭാരം<font color='red'><b>,</b></font> കര്‍ത്തവ്യം<font color='red'><b>,</b></font> ചുമതല<font color='red'><b>,</b></font> മാറാപ്പ്‌<font color='red'><b>,</b></font> കപ്പല്‍ച്ചരക്ക്‌<font color='red'><b>,</b></font> ഗാനത്തിന്റെ പല്ലവി<font color='red'><b>,</b></font> ചുമട്<font color='red'><b>,</b></font> പീഡഹേതു<font color='red'><b>,</b></font> പ്രയാസകരമായ ജോലി<font color='red'><b>,</b></font> പീഡിപ്പിക്കുക<font color='red'><b>,</b></font> ഞെരുക്കുക<font color='red'><b>,</b></font> ചുമത്തുക<font color='red'><b>,</b></font> ഭാരം കയറ്റുക
#
# burdensome: ക്ലേശകരമായ<font color='red'><b>,</b></font> ഭാരമേറിയ<font color='red'><b>,</b></font> ഭാരിച്ച
#
# burly: വീര്‍ത്ത<font color='red'><b>,</b></font> കരുത്തുളള<font color='red'><b>,</b></font> ദൃഢശരീരമുള്ള<font color='red'><b>,</b></font> പൊണ്ണത്തടിയനായ<font color='red'><b>,</b></font> സ്ഥൂലമായ
#
# burning: ആളിക്കത്തല്‍<font color='red'><b>,</b></font> ജ്വലിക്കല്‍<font color='red'><b>,</b></font> ഉജ്ജ്വലമായ<font color='red'><b>,</b></font> തീക്ഷ്‌ണമായ<font color='red'><b>,</b></font> രൂക്ഷമായ<font color='red'><b>,</b></font> ജ്വലിക്കുന്ന<font color='red'><b>,</b></font> തീക്ഷണമായ<font color='red'><b>,</b></font> ദീപ്‌തമായ<font color='red'><b>,</b></font> വെന്തുരുകുന്ന<font color='red'><b>,</b></font> തീക്ഷ്ണമായ<font color='red'><b>,</b></font> എരിഞ്ഞു പുകയുന്ന<font color='red'><b>,</b></font> പൊള്ളുന്നതായ<font color='red'><b>,</b></font> കത്തിക്കുന്നതായ<font color='red'><b>,</b></font> ഉണങ്ങുന്നതായ<font color='red'><b>,</b></font> അഗ്നിബാധിതമായ<font color='red'><b>,</b></font> ദീപ്തമായ<font color='red'><b>,</b></font> പൊള്ളുന്നതായ
#
# bursting: ചിതറല്‍<font color='red'><b>,</b></font> ഉടയല്‍<font color='red'><b>,</b></font> പൊട്ടിത്തെറി<font color='red'><b>,</b></font> ഞെട്ടുക
#
# business: വാണിജ്യം<font color='red'><b>,</b></font> കച്ചവടം<font color='red'><b>,</b></font> പ്രവൃത്തി<font color='red'><b>,</b></font> വ്യവഹാരം
#
# <font color='red'><b>,</b></font> ഇടപാട്‌<font color='red'><b>,</b></font> ഉദ്യോഗം<font color='red'><b>,</b></font> തൊഴില്‍<font color='red'><b>,</b></font> വ്യവസായം<font color='red'><b>,</b></font> കാര്യം<font color='red'><b>,</b></font> ഉപജീവനമാര്‍ഗ്ഗം<font color='red'><b>,</b></font> വ്യാപാരസംബന്ധമായ കൊടുക്കല്‍ വാങ്ങലുകള്‍<font color='red'><b>,</b></font> വ്യാപാരം
#
# <font color='red'><b>,</b></font> തൊഴില്‍<font color='red'><b>,</b></font> ഇടപാട്<font color='red'><b>,</b></font> വ്യാപാരസംബന്ധമായ കൊടുക്കല്‍ വാങ്ങലുകള്‍
#
# bustle: ഘോഷം<font color='red'><b>,</b></font> കോലാഹലം<font color='red'><b>,</b></font> ഇരമ്പല്‍<font color='red'><b>,</b></font> തിരക്ക്‌<font color='red'><b>,</b></font> തിക്കും തിരക്കും<font color='red'><b>,</b></font> ഒച്ചപ്പാട്‌<font color='red'><b>,</b></font> ത്വര<font color='red'><b>,</b></font> തിരക്കുക്കൂട്ടുക<font color='red'><b>,</b></font> ബദ്ധപ്പെട്ടു നടക്കുക<font color='red'><b>,</b></font> ഉത്സാഹം കാട്ടുക<font color='red'><b>,</b></font> കോലാഹലമുണ്ടാക്കുക<font color='red'><b>,</b></font> ഉത്സാഹിക്കുക
#
# busy: മുഴുകിയ<font color='red'><b>,</b></font> മുഷിഞ്ഞു പ്രവര്‍ത്തിക്കുക<font color='red'><b>,</b></font> വേലചെയ്യുക<font color='red'><b>,</b></font> നിരതമാകുക<font color='red'><b>,</b></font> ജോലിത്തിരക്കുള്ള<font color='red'><b>,</b></font> ഉത്സാഹിയായ<font color='red'><b>,</b></font> കാര്യബഹുലമായ<font color='red'><b>,</b></font> തിരക്കുപിടിച്ച<font color='red'><b>,</b></font> ഉത്സുകമായ<font color='red'><b>,</b></font> തിടുക്കമുള്ള<font color='red'><b>,</b></font> ജോലിത്തിരക്കുള്ള<font color='red'><b>,</b></font> ഏകാഗ്രതയോടെ
#
# butchery: കശാപ്പ്‌<font color='red'><b>,</b></font> കശാപ്പുശാല
#
# bygone: കഴിഞ്ഞുപോയ
#
# cadaverous: വിളറിയ
#
# cadence: താളം<font color='red'><b>,</b></font> താളാത്മക ചലനം<font color='red'><b>,</b></font> സ്വരാവരോഹം<font color='red'><b>,</b></font> ഗണപ്പൊരുത്തം
#
# calamitous: ദുഃഖകരമായ<font color='red'><b>,</b></font> ദുരന്തമായ<font color='red'><b>,</b></font> ആപത്കരമായ<font color='red'><b>,</b></font> ആപത്‌കരമായ<font color='red'><b>,</b></font> ആപത്‌ഗ്രസ്‌തമായ
#
# calamity: കൊടും ദുരിതം<font color='red'><b>,</b></font> അത്യാപത്ത്<font color='red'><b>,</b></font> അത്യാപത്ത്‌<font color='red'><b>,</b></font> വിപത്ത്‌<font color='red'><b>,</b></font> അത്യാഹിതം<font color='red'><b>,</b></font> ദുര്യോഗം
#
# calculated: യുക്തമായ<font color='red'><b>,</b></font> കണക്കാക്കപ്പെട്ട<font color='red'><b>,</b></font> കരുതിക്കൂട്ടിയുള്ള
#
# calculating: കുശാഗ്രബുദ്ധിയായ<font color='red'><b>,</b></font> വരും വരായ്‌മകള്‍ കണക്കിലെടുക്കുന്ന
#
# callous: കര്‍ക്കശം<font color='red'><b>,</b></font> കാഠിന്യമുള്ള<font color='red'><b>,</b></font> കഠോരമായ<font color='red'><b>,</b></font> നിര്‍ദ്ദയമായ<font color='red'><b>,</b></font> ക്രൂരമായ<font color='red'><b>,</b></font> ഹൃദയശൂന്യമായ<font color='red'><b>,</b></font> മരവിച്ച<font color='red'><b>,</b></font> കഠോരമായ<font color='red'><b>,</b></font> നിരന്തര ഉരസല്‍ കൊണ്ട്‌ ഞെരുങ്ങി കട്ടിയായ<font color='red'><b>,</b></font> തഴമ്പിച്ച<font color='red'><b>,</b></font> കഠോരമായ<font color='red'><b>,</b></font> നിരന്തര ഉരസല്‍ കൊണ്ട് ഞെരുങ്ങി കട്ടിയായ<font color='red'><b>,</b></font> തഴന്പിച്ച
#
# callousness: കഠിനഹൃദയത്വം
#
# callow: അനുഭവജ്ഞാനമില്ലാത്ത<font color='red'><b>,</b></font> ചിറകുവിരിഞ്ഞിട്ടില്ലാത്ത<font color='red'><b>,</b></font> തൂവലില്ലാത്ത<font color='red'><b>,</b></font> ചിറകുവിരിയാത്ത<font color='red'><b>,</b></font> മീശമുളയ്‌ക്കാത്ത<font color='red'><b>,</b></font> മീശമുളയ്ക്കാത്ത
#
# calm: അക്ഷോഭ്യത<font color='red'><b>,</b></font> നിശ്ചലത<font color='red'><b>,</b></font> പ്രശാന്തത<font color='red'><b>,</b></font> ആത്മവിശ്വാസമുളള<font color='red'><b>,</b></font> മനശ്ശാന്തി<font color='red'><b>,</b></font> അമര്‍ത്തുക<font color='red'><b>,</b></font> സാന്ത്വനപ്പെടുത്തുക<font color='red'><b>,</b></font> ശാന്തമാക്കുക<font color='red'><b>,</b></font> സാമാധാനപ്പെടുത്തുക<font color='red'><b>,</b></font> ആറ്റുക<font color='red'><b>,</b></font> പ്രസന്നമായ<font color='red'><b>,</b></font> ശാന്തമായ<font color='red'><b>,</b></font> നിശ്ചലമായ<font color='red'><b>,</b></font> ധിക്കാരിയായ<font color='red'><b>,</b></font> കാറ്റില്ലാത്ത<font color='red'><b>,</b></font> ക്ഷോഭമില്ലാത്ത<font color='red'><b>,</b></font> ചലനരഹിതമായ<font color='red'><b>,</b></font> നിശ്ചഞ്ചലമായ<font color='red'><b>,</b></font> നിശ്ശബ്ദമായ
#
# calmness: ശാന്തത<font color='red'><b>,</b></font> സമാധാനം
#
# calumny: ദുഷ്‌പ്രവാദം<font color='red'><b>,</b></font> ഏഷണി<font color='red'><b>,</b></font> ദോഷാരോപണം
#
# candid: നിര്‍മ്മലമായ<font color='red'><b>,</b></font> കപടമില്ലാത്ത<font color='red'><b>,</b></font> സത്യസന്ധമായ
#
# <font color='red'><b>,</b></font> നിഷ്കളങ്കമായ<font color='red'><b>,</b></font> സ്‌പഷ്‌ടമായ<font color='red'><b>,</b></font> യഥാര്‍ത്ഥമായ<font color='red'><b>,</b></font> നിര്‍വ്യാജമായ<font color='red'><b>,</b></font> മറച്ചുവയ്‌ക്കാത്ത<font color='red'><b>,</b></font> നിഷ്‌കളങ്കമായി തുറന്നു സംസാരിക്കുന്ന<font color='red'><b>,</b></font> പക്ഷപാതമില്ലാത്ത<font color='red'><b>,</b></font> തുറന്ന മനഃസ്ഥിതിയുള്ള<font color='red'><b>,</b></font> പരമാര്‍ത്ഥമായ<font color='red'><b>,</b></font> നിഷ്‌കളങ്കമായ
#
# candor: ആര്‍ജ്ജവം<font color='red'><b>,</b></font> നിഷ്‌ക്കളങ്കന്‍
#
# cant: കെഞ്ചല്‍<font color='red'><b>,</b></font> അപഭാഷഗുപ്‌തഭാഷ<font color='red'><b>,</b></font> പടുഭാഷണം<font color='red'><b>,</b></font> കപടഭാഷ<font color='red'><b>,</b></font> കേണുപറയല്‍<font color='red'><b>,</b></font> അപഭാഷ<font color='red'><b>,</b></font> അനാത്മാര്‍ത്തമായി സംസാരിക്കുക<font color='red'><b>,</b></font> ഗുപ്‌തഭാഷയില്‍ സംസാരിക്കുക<font color='red'><b>,</b></font> ചെരിഞ്ഞ നിലയിലാകുക<font color='red'><b>,</b></font> പെട്ടെന്നു തള്ളിമിറിക്കുക<font color='red'><b>,</b></font> ആത്മാര്‍ത്ഥതയില്ലാതെ സംസാരിക്കുക<font color='red'><b>,</b></font> കിണുകിണുങ്ങുക<font color='red'><b>,</b></font> ചുറുചുറുക്കുള്ള<font color='red'><b>,</b></font> വീര്യമുള്ള<font color='red'><b>,</b></font> ഗ്രാമ്യഭാഷാരീതിയിലുള്ള<font color='red'><b>,</b></font> കിണുങ്ങുക<font color='red'><b>,</b></font> നിരപരാധിയാണെന്നു ഭാവിച്ചു സംസാരിക്കുക
#
# cantankerous: കലഹപ്രിയനായ<font color='red'><b>,</b></font> ദുര്‍മ്മുഖം കാണിക്കുന്ന<font color='red'><b>,</b></font> ദുസ്സ്വഭാവമുള്ള<font color='red'><b>,</b></font> മുരട്ടുസ്വഭാവമുള്ള
#
# capable: പ്രാപ്‌തിയുള്ള<font color='red'><b>,</b></font> കഴിവുള്ള<font color='red'><b>,</b></font> പറ്റുന്ന<font color='red'><b>,</b></font> യോഗ്യതയുള്ള<font color='red'><b>,</b></font> കെല്‍പുള്ള<font color='red'><b>,</b></font> ത്രാണിയുള്ള<font color='red'><b>,</b></font> ശേഷിയുള്ള<font color='red'><b>,</b></font> പ്രാപ്‌തമായ<font color='red'><b>,</b></font> പറ്റത്തക്ക<font color='red'><b>,</b></font> പ്രാപ്തമായ
#
# capacious: പദവി<font color='red'><b>,</b></font> വിസ്‌തൃതമായ<font color='red'><b>,</b></font> വിശാലമായ<font color='red'><b>,</b></font> ധാരാളം കൊള്ളുന്ന
#
# capacity: പദവി<font color='red'><b>,</b></font> പരിമാണം<font color='red'><b>,</b></font> ത്രാണി<font color='red'><b>,</b></font> വിസ്‌തൃതി<font color='red'><b>,</b></font> പരപ്പ്‌<font color='red'><b>,</b></font> പ്രാപ്‌തി<font color='red'><b>,</b></font> ഇടം<font color='red'><b>,</b></font> വിസ്‌താരം<font color='red'><b>,</b></font> ഉള്‍കൊള്ളാനുള്ള ശക്തി<font color='red'><b>,</b></font> കോള്‍ത്രാണി<font color='red'><b>,</b></font> വിശാലം<font color='red'><b>,</b></font> മനശക്തി
#
# caprice: അസ്ഥിരബുദ്ധി<font color='red'><b>,</b></font> പെട്ടെന്നുള്ള അഭിപ്രായമാറ്റം<font color='red'><b>,</b></font> ഹേതുവില്ലാത്ത മാനസികമാറ്റമോ പെരുമാറ്റമോ<font color='red'><b>,</b></font> മനശ്ചാഞ്ചല്യം
#
# caprice: അസ്ഥിരബുദ്ധി<font color='red'><b>,</b></font> പെട്ടെന്നുള്ള അഭിപ്രായമാറ്റം<font color='red'><b>,</b></font> ഹേതുവില്ലാത്ത മാനസികമാറ്റമോ പെരുമാറ്റമോ<font color='red'><b>,</b></font> മനശ്ചാഞ്ചല്യം
#
# capricious: ചപലമായ<font color='red'><b>,</b></font> ചഞ്ചലപ്രകൃതിയായ<font color='red'><b>,</b></font> എളുപ്പം മസസ്സുമാറുന്ന സ്വാഭാവമുള്ള<font color='red'><b>,</b></font> പെട്ടെന്നു മനസ്സു മാറുന്ന സ്വഭാവമുള്ള<font color='red'><b>,</b></font> അസ്ഥിരചിത്ത<font color='red'><b>,</b></font> ചപല<font color='red'><b>,</b></font> ചപലപ്രകൃതിയായ<font color='red'><b>,</b></font> പെട്ടെന്ന് മനസ്സുമാറുന്ന<font color='red'><b>,</b></font> ചഞ്ചല മനസ്സോടു കൂടിയ
#
# captious: വൃഥാ ആക്ഷേപിക്കുന്ന<font color='red'><b>,</b></font> ദോഷൈകദൃക്കായ
#
# captivate: വശീകരിക്കുക<font color='red'><b>,</b></font> മോഹിപ്പിക്കുക<font color='red'><b>,</b></font> മനം കവരുക<font color='red'><b>,</b></font> പാട്ടിലാക്കുക
#
# captivating: മനോഹരമായ<font color='red'><b>,</b></font> മനം മയക്കുന്ന
#
# cardinal: കര്‍ദിനാള്‍<font color='red'><b>,</b></font> കര്‍ദ്ദിനാള്‍<font color='red'><b>,</b></font> കത്തോലിക്കാസഭയില്‍ പോപ്പിന്‍റെ തൊട്ടടുത്ത പദവി<font color='red'><b>,</b></font> റോമിലെ വൈദിക മേലദ്ധ്യക്ഷ സമിതയംഗം<font color='red'><b>,</b></font> മാര്‍പാപ്പ കഴിഞ്ഞാല്‍ റോമാസഭയിലെ ഏറ്റവും വലിയ സ്ഥാനി<font color='red'><b>,</b></font> വിശിഷ്‌ടമായ<font color='red'><b>,</b></font> പ്രധാനമായ<font color='red'><b>,</b></font> മൗലികമായ<font color='red'><b>,</b></font> അടിസ്ഥാനപരമായ
#
# care: ജാഗ്രത<font color='red'><b>,</b></font> ശ്രദ്ധ<font color='red'><b>,</b></font> സൂക്ഷ്‌മത<font color='red'><b>,</b></font> കരുതല്‍<font color='red'><b>,</b></font> ചിന്ത<font color='red'><b>,</b></font> ചിന്താകുലത<font color='red'><b>,</b></font> ജാഗരൂകത<font color='red'><b>,</b></font> അവധാനത<font color='red'><b>,</b></font> താത്‌പര്യം<font color='red'><b>,</b></font> ഉത്കണ്ഠ<font color='red'><b>,</b></font> ശ്രദ്ധിക്കുക<font color='red'><b>,</b></font> ഗൗനിക്കുക<font color='red'><b>,</b></font> പരിചരിക്കുക<font color='red'><b>,</b></font> ക്ലേശിക്കുക<font color='red'><b>,</b></font> തല്‍പരനായിരിക്കുക<font color='red'><b>,</b></font> ഉത്സുകനാകുക<font color='red'><b>,</b></font> ഉദക്കണ്‌ഠിതനാകുക<font color='red'><b>,</b></font> ദുഃഖിക്കുക<font color='red'><b>,</b></font> വിചാരപ്പെടുക
#
# career: കാലഗതി<font color='red'><b>,</b></font> ക്രമം<font color='red'><b>,</b></font> തൊഴില്‍<font color='red'><b>,</b></font> ജീവിതഗതി<font color='red'><b>,</b></font> ജീവിതചര്യ<font color='red'><b>,</b></font> ജീവാവസ്ഥ<font color='red'><b>,</b></font> ഔദ്യോഗികജീവിതം<font color='red'><b>,</b></font> പാഞ്ഞോടുക<font color='red'><b>,</b></font> വേഗത്തില്‍ ഓടുക<font color='red'><b>,</b></font> കുതിച്ചു പായുക
